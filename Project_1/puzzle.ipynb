# %%
import numpy as np
#Node_State = np.array([[1,0,3],[4,2,5],[7,8,6]]) #working_instant
Node_State4 = np.array([[2,8,3],[1,6,4],[7,0,5]]) #takes_lot_of_time
Node_State1 = np.array([[2,4,3],[7,8,0],[6,1,5]])  #working_maybe_a_min
Node_State2 = np.array([[1,0,2],[4,6,8],[7,3,5]]) #working_instant
Node_State3 = np.array([[4,8,1],[5,2,0],[7,6,3]]) #working_instant
Node_State = np.array([[7,2,3],[1,5,6],[4,8,0]]) #working_maybe_a_min



Goal_Node = np.array([[1,2,3],[4,5,6],[7,8,0]])
ParentNodes = {}
ParentNodes = {1:0}
AllNodes ={}
AllNodes = {1:Node_State}

NewNode1 = Node_State.copy()
NewNode2 = Node_State.copy()
NewNode3 = Node_State.copy()
NewNode4 = Node_State.copy()

a = 1
b = 1
next_node =1
flag = 1
clean =1

# %%
[i,j] = BlankTileLocation(Node_State)

# %%
[i,j]
# Out:
# [0, 1]

# %%
def BlankTileLocation(state):
    for i in range(0,len(Node_State[1])):
        for j in range(0,len(Node_State[1])):
            if state[i,j] == 0:
                return[i,j]
            
            
def ActionMoveLeft(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if j == 0:
                    print("cannot perform left movement")
                    return[0, state]
                else:
                    print("left movement performed")
                    New_state[i,j-1], New_state[i,j] = New_state[i,j], New_state[i,j-1]
                    return[1, New_state]
            
            
def ActionMoveRight(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if j == 2:
                    print("cannot perform Right movement")
                    return[0, state]
                    
                else:
                    print("right movement performed")
                    New_state[i,j+1], New_state[i,j] = New_state[i,j], New_state[i,j+1]
                    return[1, New_state]

def ActionMoveUp(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if i == 0:
                    print("cannot perform Up movement")
                    return[0, state]
                    
                else:
                    print("up movement performed")
                    New_state[i-1,j], New_state[i,j] = New_state[i,j], New_state[i-1,j]
                    return[1, New_state]
            
def ActionMoveDown(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if i == 2:
                    print("cannot perform Down movement")
                    return[0, state]
                    
                else:
                    print("Down movement performed")
                    New_state[i+1,j], New_state[i,j] = New_state[i,j], New_state[i+1,j]
                    return[1, New_state]
                
#def AddNode(New_N):
#    global a
#    global b
#    for values in AllNodes.values():
#        if (values == New_N).all():
#           print("present")
#            break
#        else:
#            print("absent")
#            a = a+1
#            AllNodes[a] = New_N
#            ParentNodes[a] = b
#            break
            
            
def AddNode(New_N):
    global a
    global b
    global flag 
    flag = 1
    
    for values in AllNodes.values():
        if (values == New_N).all():
            flag = 0
            print("present_do not add")
    
    if(flag == 1):
        print("Not present_do add")
        a = a+1
        AllNodes[a] = New_N
        ParentNodes[a] = b

            

def Check_and_Add(state1):
    global b
    global NewNode1
    global NewNode2
    global NewNode3
    global NewNode4
    [Status, NewNode] = ActionMoveLeft(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode1 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveUp(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode2 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveRight(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode3 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveDown(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    print("Next Iteration")
    print("")
    NewNode4 = NewNode.copy()
    b = b+1

# %%
def get_key(val): 
    for key, value in AllNodes.items(): 
         if (val == value).all(): 
             return key 
  
    return "key doesn't exist"

def clean_AddNode(AllNodes):
    key = get_key(Goal_Node)
    length = len(AllNodes)
    while(key != length):
        key = key + 1
        AllNodes.pop(key, None)

# %%
while((not(np.array_equal(NewNode1, Goal_Node))) and (not(np.array_equal(NewNode2, Goal_Node))) and (not(np.array_equal(NewNode3, Goal_Node))) and (not(np.array_equal(NewNode4, Goal_Node)))):
    global next_node 
    Check_and_Add(AllNodes[next_node])
    next_node = next_node +1
# Out:
# left movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 5 3]
#  [0 7 6]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 5 3]
#  [7 6 0]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 3]
#  [7 4 6]
#  [1 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[5 7 3]
#  [0 2 6]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [5 2 0]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [5 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 6 8]
#  [1 0 4]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 4 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [5 4 0]
#  [1 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 1 0]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [0 7 6]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 6 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 5 6]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 4 6]
#  [5 1 8]]
# present_do not add
#
# up movement performed
# [[7 0 3]
#  [4 2 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 6 0]
#  [5 1 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 1 0]
#  [5 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[1 0 3]
#  [2 7 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [2 6 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 5 6]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [4 2 6]
#  [5 0 8]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [0 1 2]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 0 6]
#  [1 3 2]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [1 5 2]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 2 8]
#  [4 0 5]]
# Not present_do add
#
# up movement performed
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 7 2]
#  [0 6 3]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 6 2]
#  [0 1 3]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 6 2]
#  [1 3 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 6 2]
#  [1 5 3]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 6 8]
#  [1 4 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 1 8]
#  [4 6 5]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [1 2 8]
#  [4 6 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 3 5]
#  [7 1 0]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [0 7 5]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 5 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 8 5]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 4 5]
#  [8 1 6]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [4 2 5]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 5 0]
#  [8 1 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 1 0]
#  [8 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 0 3]
#  [2 7 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [2 5 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 8 5]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [4 2 5]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [0 1 2]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 0 5]
#  [1 3 2]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 8 2]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 2 6]
#  [4 0 8]]
# Not present_do add
#
# up movement performed
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 8 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[7 0 3]
#  [8 2 5]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [8 5 0]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [8 4 5]
#  [1 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [1 8 3]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 0 2]
#  [5 7 3]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[1 7 2]
#  [5 3 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [5 8 3]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [4 5 3]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[5 0 2]
#  [7 1 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 2]
#  [4 1 3]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 0 5]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 3 6]
#  [4 0 8]]
# Not present_do add
#
# up movement performed
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [0 8 3]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [1 8 0]
#  [4 6 3]]
# Not present_do add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [7 0 5]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 5 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 5 3]
#  [0 7 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 5 3]
#  [2 7 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 5 3]
#  [1 7 6]
#  [0 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[2 5 0]
#  [7 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Right movement
# [[2 5 3]
#  [7 6 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 5 3]
#  [7 6 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 5 3]
#  [7 4 6]
#  [0 1 8]]
# Not present_do add
#
# up movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 5 3]
#  [7 4 6]
#  [1 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 5 3]
#  [7 4 6]
#  [1 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 7 3]
#  [0 2 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[5 7 3]
#  [2 0 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[5 7 3]
#  [1 2 6]
#  [0 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [5 0 2]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 6]
#  [5 2 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [5 2 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [5 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [5 0 3]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 6 8]
#  [0 1 4]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [5 0 8]
#  [1 6 4]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 6 8]
#  [1 0 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 4 6]
#  [5 1 8]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 4 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 0 4]
#  [1 8 6]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [5 4 3]
#  [1 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 4 0]
#  [1 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [7 0 1]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 6]
#  [7 1 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 1 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 1 3]
#  [0 7 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 1 3]
#  [2 7 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [4 7 6]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[2 1 0]
#  [7 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[2 1 3]
#  [7 6 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [7 6 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 5 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 5 6]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 1 3]
#  [7 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [4 2 6]
#  [5 1 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [4 2 6]
#  [5 1 8]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [4 2 6]
#  [5 1 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [4 6 3]
#  [5 1 8]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 6 0]
#  [5 1 8]]
# present_do not add
# Down movement performed
# [[7 2 3]
#  [4 6 8]
#  [5 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 1]
#  [5 8 6]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [4 1 3]
#  [5 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 0]
#  [5 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 1 3]
#  [2 7 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[1 0 3]
#  [2 7 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 3 0]
#  [2 7 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[1 7 0]
#  [2 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[1 7 3]
#  [2 6 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [2 6 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 5 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 5 6]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [2 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [4 0 6]
#  [5 2 8]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [4 2 6]
#  [5 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 6]
#  [5 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 3 6]
#  [0 1 2]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [7 1 2]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [4 1 2]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 6]
#  [1 3 2]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 6]
#  [1 3 2]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 6 0]
#  [1 3 2]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 5 2]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 3 6]
#  [1 5 2]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 3 6]
#  [1 5 2]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 2 8]
#  [0 4 5]]
# Not present_do add
#
# up movement performed
# [[7 3 6]
#  [1 0 8]
#  [4 2 5]]
# Not present_do add
#
# right movement performed
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 6]
#  [1 2 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 2]
#  [0 6 3]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [6 0 3]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [4 6 3]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 6 2]
#  [0 1 3]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [7 1 3]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [4 1 3]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[7 6 0]
#  [1 3 2]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 6 2]
#  [1 3 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [1 3 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 6 2]
#  [1 5 3]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 6 2]
#  [1 5 3]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 6 2]
#  [1 5 3]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 6 8]
#  [1 4 5]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 6 8]
#  [1 4 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [6 0 8]
#  [1 4 5]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 1 8]
#  [4 6 5]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 1 8]
#  [4 6 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 8]
#  [0 6 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [1 2 8]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [1 2 8]
#  [4 6 5]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [1 2 8]
#  [4 6 5]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 5]
#  [7 0 1]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 5]
#  [7 1 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 3 5]
#  [7 1 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 1 3]
#  [0 7 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 1 3]
#  [2 7 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [4 7 5]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[2 1 0]
#  [7 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[2 1 3]
#  [7 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [7 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 8 5]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 8 5]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 1 3]
#  [7 8 5]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 4 5]
#  [8 1 6]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 4 5]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [8 4 5]
#  [0 1 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [4 2 5]
#  [8 1 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [4 2 5]
#  [8 1 6]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [4 2 5]
#  [8 1 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [4 5 3]
#  [8 1 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 5 0]
#  [8 1 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 5 6]
#  [8 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 1]
#  [8 6 5]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [4 1 3]
#  [8 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 0]
#  [8 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 1 3]
#  [2 7 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[1 0 3]
#  [2 7 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 3 0]
#  [2 7 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 0]
#  [2 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[1 7 3]
#  [2 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [2 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 8 5]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 8 5]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [2 8 5]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [4 0 5]
#  [8 2 6]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [4 2 5]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 5]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 3 5]
#  [0 1 2]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 3 5]
#  [7 1 2]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [4 1 2]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 5]
#  [1 3 2]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 5]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 8 2]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 3 5]
#  [1 8 2]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 3 5]
#  [1 8 2]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 2 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 3 5]
#  [1 0 6]
#  [4 2 8]]
# Not present_do add
#
# right movement performed
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 5]
#  [1 2 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 8 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[2 8 3]
#  [7 0 5]
#  [1 4 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [8 2 5]
#  [1 4 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [8 2 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [8 2 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [8 5 3]
#  [1 4 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [8 5 0]
#  [1 4 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [8 5 6]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [8 4 5]
#  [0 1 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [8 4 5]
#  [1 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [8 4 5]
#  [1 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [1 8 3]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 8 2]
#  [1 0 3]
#  [4 6 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [5 7 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [5 7 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [5 7 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 0]
#  [5 3 2]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[1 7 2]
#  [5 3 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 2]
#  [5 3 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [5 8 3]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [5 8 3]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 2]
#  [5 8 3]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 2]
#  [4 0 3]
#  [8 5 6]]
# Not present_do add
#
# right movement performed
# [[1 7 2]
#  [4 5 3]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 2]
#  [4 5 3]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[5 0 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[5 2 0]
#  [7 1 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[5 1 2]
#  [7 0 3]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [4 0 3]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [4 1 3]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 5 2]
#  [4 1 3]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 3 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 5 2]
#  [1 0 6]
#  [4 3 8]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 3 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [0 8 3]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[0 5 2]
#  [7 8 3]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [8 0 3]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 0 8]
#  [4 6 3]]
# Not present_do add
#
# up movement performed
# [[7 5 0]
#  [1 8 2]
#  [4 6 3]]
# Not present_do add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 8 0]
#  [4 6 3]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [0 7 5]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[2 0 6]
#  [7 3 5]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 4 5]
#  [1 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [7 5 8]
#  [1 0 4]]
# Not present_do add
#
# up movement performed
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 6]
#  [7 5 8]
#  [1 4 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 3 6]
#  [7 5 8]
#  [1 4 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 5 3]
#  [2 7 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 5 3]
#  [2 7 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[5 0 3]
#  [2 7 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 3]
#  [0 7 6]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 5 3]
#  [1 7 6]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[2 5 3]
#  [0 7 6]
# ...
# [[3 4 6]
#  [0 2 5]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[0 4 6]
#  [3 2 5]
#  [7 1 8]]
# Not present_do add
#
# right movement performed
# [[3 4 6]
#  [2 0 5]
#  [7 1 8]]
# present_do not add
#
# Down movement performed
# [[3 4 6]
#  [7 2 5]
#  [0 1 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 4 6]
#  [2 0 5]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[3 4 0]
#  [2 5 6]
#  [7 1 8]]
# Not present_do add
#
# cannot perform Right movement
# [[3 4 6]
#  [2 5 0]
#  [7 1 8]]
# present_do not add
#
# Down movement performed
# [[3 4 6]
#  [2 5 8]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 4 6]
#  [2 1 5]
#  [0 7 8]]
# Not present_do add
#
# up movement performed
# [[3 4 6]
#  [2 0 5]
#  [7 1 8]]
# present_do not add
#
# right movement performed
# [[3 4 6]
#  [2 1 5]
#  [7 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[3 4 6]
#  [2 1 5]
#  [7 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 2 6]
#  [0 3 5]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[0 2 6]
#  [4 3 5]
#  [7 1 8]]
# present_do not add
#
# right movement performed
# [[4 2 6]
#  [3 0 5]
#  [7 1 8]]
# Not present_do add
#
# Down movement performed
# [[4 2 6]
#  [7 3 5]
#  [0 1 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 6 5]
#  [4 0 3]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[2 6 0]
#  [4 3 5]
#  [7 1 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 6 5]
#  [4 3 0]
#  [7 1 8]]
# present_do not add
#
# Down movement performed
# [[2 6 5]
#  [4 3 8]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [4 5 8]
#  [0 7 1]]
# Not present_do add
#
# up movement performed
# [[2 3 6]
#  [4 0 8]
#  [7 5 1]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [4 5 8]
#  [7 1 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 3 6]
#  [4 5 8]
#  [7 0 1]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [4 0 1]
#  [7 8 5]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [4 1 6]
#  [7 8 5]]
# Not present_do add
#
# cannot perform Right movement
# [[2 3 6]
#  [4 1 0]
#  [7 8 5]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [4 1 5]
#  [7 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 3 6]
#  [2 7 4]
#  [1 8 5]]
# present_do not add
#
# cannot perform Up movement
# [[3 0 6]
#  [2 7 4]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[3 6 0]
#  [2 7 4]
#  [1 8 5]]
# Not present_do add
#
# Down movement performed
# [[3 7 6]
#  [2 0 4]
#  [1 8 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [1 7 4]
#  [0 8 5]]
# present_do not add
#
# up movement performed
# [[2 3 6]
#  [1 0 4]
#  [8 7 5]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [1 7 4]
#  [8 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 3 6]
#  [1 7 4]
#  [8 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 6]
#  [0 3 4]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[0 2 6]
#  [7 3 4]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[7 2 6]
#  [3 0 4]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[7 2 6]
#  [1 3 4]
#  [0 8 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 6 4]
#  [7 0 3]
#  [1 8 5]]
# Not present_do add
#
# up movement performed
# [[2 6 0]
#  [7 3 4]
#  [1 8 5]]
# present_do not add
#
# cannot perform Right movement
# [[2 6 4]
#  [7 3 0]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[2 6 4]
#  [7 3 5]
#  [1 8 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 3 6]
#  [0 8 4]
#  [7 1 5]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [2 8 4]
#  [7 1 5]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [8 0 4]
#  [7 1 5]]
# Not present_do add
#
# Down movement performed
# [[2 3 6]
#  [7 8 4]
#  [0 1 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 4 6]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 4 6]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [4 0 6]
#  [1 8 5]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 4 6]
#  [0 8 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 4 3]
#  [0 7 6]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[0 4 3]
#  [2 7 6]
#  [1 8 5]]
# Not present_do add
#
# right movement performed
# [[2 4 3]
#  [7 0 6]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[2 4 3]
#  [1 7 6]
#  [0 8 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 4 3]
#  [7 0 6]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[2 4 0]
#  [7 6 3]
#  [1 8 5]]
# Not present_do add
#
# cannot perform Right movement
# [[2 4 3]
#  [7 6 0]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[2 4 3]
#  [7 6 5]
#  [1 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 4 3]
#  [7 8 6]
#  [0 1 5]]
# Not present_do add
#
# up movement performed
# [[2 4 3]
#  [7 0 6]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[2 4 3]
#  [7 8 6]
#  [1 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 4 3]
#  [7 8 6]
#  [1 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[3 6 8]
#  [2 0 5]
#  [7 1 4]]
# Not present_do add
#
# up movement performed
# [[3 6 0]
#  [2 5 8]
#  [7 1 4]]
# present_do not add
#
# cannot perform Right movement
# [[3 6 8]
#  [2 5 0]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[3 6 8]
#  [2 5 4]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[3 5 6]
#  [0 2 8]
#  [7 1 4]]
# present_do not add
#
# up movement performed
# [[0 5 6]
#  [3 2 8]
#  [7 1 4]]
# Not present_do add
#
# right movement performed
# [[3 5 6]
#  [2 0 8]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[3 5 6]
#  [7 2 8]
#  [0 1 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 5 6]
#  [2 0 8]
#  [7 1 4]]
# present_do not add
#
# up movement performed
# [[3 5 0]
#  [2 8 6]
#  [7 1 4]]
# Not present_do add
#
# cannot perform Right movement
# [[3 5 6]
#  [2 8 0]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[3 5 6]
#  [2 8 4]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 5 6]
#  [2 1 8]
#  [0 7 4]]
# Not present_do add
#
# up movement performed
# [[3 5 6]
#  [2 0 8]
#  [7 1 4]]
# present_do not add
#
# right movement performed
# [[3 5 6]
#  [2 1 8]
#  [7 4 0]]
# Not present_do add
#
# cannot perform Down movement
# [[3 5 6]
#  [2 1 8]
#  [7 0 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 2 6]
#  [0 3 8]
#  [7 1 4]]
# present_do not add
#
# up movement performed
# [[0 2 6]
#  [5 3 8]
#  [7 1 4]]
# present_do not add
#
# right movement performed
# [[5 2 6]
#  [3 0 8]
#  [7 1 4]]
# Not present_do add
#
# Down movement performed
# [[5 2 6]
#  [7 3 8]
#  [0 1 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 6 8]
#  [5 0 3]
#  [7 1 4]]
# Not present_do add
#
# up movement performed
# [[2 6 0]
#  [5 3 8]
#  [7 1 4]]
# present_do not add
#
# cannot perform Right movement
# [[2 6 8]
#  [5 3 0]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[2 6 8]
#  [5 3 4]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [5 8 6]
#  [7 1 4]]
# Not present_do add
#
# cannot perform Up movement
# [[2 0 3]
#  [5 8 6]
#  [7 1 4]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [5 8 6]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[2 8 3]
#  [5 0 6]
#  [7 1 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [5 8 4]
#  [0 7 1]]
# Not present_do add
#
# up movement performed
# [[2 3 6]
#  [5 0 4]
#  [7 8 1]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [5 8 4]
#  [7 1 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 3 6]
#  [5 8 4]
#  [7 0 1]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 3 6]
#  [0 1 8]
#  [5 7 4]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [2 1 8]
#  [5 7 4]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [1 0 8]
#  [5 7 4]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [5 1 8]
#  [0 7 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[3 6 8]
#  [2 0 7]
#  [1 5 4]]
# Not present_do add
#
# up movement performed
# [[3 6 0]
#  [2 7 8]
#  [1 5 4]]
# present_do not add
#
# cannot perform Right movement
# [[3 6 8]
#  [2 7 0]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[3 6 8]
#  [2 7 4]
#  [1 5 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[3 7 6]
#  [0 2 8]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[0 7 6]
#  [3 2 8]
#  [1 5 4]]
# Not present_do add
#
# right movement performed
# [[3 7 6]
#  [2 0 8]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[3 7 6]
#  [1 2 8]
#  [0 5 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 7 6]
#  [2 0 8]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[3 7 0]
#  [2 8 6]
#  [1 5 4]]
# Not present_do add
#
# cannot perform Right movement
# [[3 7 6]
#  [2 8 0]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[3 7 6]
#  [2 8 4]
#  [1 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 6]
#  [1 3 8]
#  [5 7 4]]
# Not present_do add
#
# cannot perform Up movement
# [[2 0 6]
#  [1 3 8]
#  [5 7 4]]
# present_do not add
#
# right movement performed
# [[2 6 0]
#  [1 3 8]
#  [5 7 4]]
# Not present_do add
#
# Down movement performed
# [[2 3 6]
#  [1 0 8]
#  [5 7 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [1 0 8]
#  [5 7 4]]
# present_do not add
#
# up movement performed
# [[2 3 0]
#  [1 8 6]
#  [5 7 4]]
# Not present_do add
#
# cannot perform Right movement
# [[2 3 6]
#  [1 8 0]
#  [5 7 4]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [1 8 4]
#  [5 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [1 0 7]
#  [5 4 8]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [1 7 6]
#  [5 4 8]]
# Not present_do add
#
# cannot perform Right movement
# [[2 3 6]
#  [1 7 0]
#  [5 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [1 7 8]
#  [5 4 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 6]
#  [3 2 8]
#  [1 5 4]]
# present_do not add
#
# cannot perform Up movement
# [[7 0 6]
#  [3 2 8]
#  [1 5 4]]
# present_do not add
#
# right movement performed
# [[7 6 0]
#  [3 2 8]
#  [1 5 4]]
# Not present_do add
#
# Down movement performed
# [[7 2 6]
#  [3 0 8]
#  [1 5 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 6]
#  [3 0 8]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [3 8 6]
#  [1 5 4]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 6]
#  [3 8 0]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[7 2 6]
#  [3 8 4]
#  [1 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 6]
#  [1 3 8]
#  [0 5 4]]
# present_do not add
#
# up movement performed
# [[7 2 6]
#  [1 0 8]
#  [5 3 4]]
# Not present_do add
#
# right movement performed
# [[7 2 6]
#  [1 3 8]
#  [5 4 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 6]
#  [1 3 8]
#  [5 0 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 6 8]
#  [0 7 3]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[0 6 8]
#  [2 7 3]
#  [1 5 4]]
# Not present_do add
#
# right movement performed
# [[2 6 8]
#  [7 0 3]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[2 6 8]
#  [1 7 3]
#  [0 5 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 8]
#  [7 6 3]
#  [1 5 4]]
# Not present_do add
#
# cannot perform Up movement
# [[2 0 8]
#  [7 6 3]
#  [1 5 4]]
# present_do not add
#
# right movement performed
# [[2 8 0]
#  [7 6 3]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[2 6 8]
#  [7 0 3]
#  [1 5 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 6 8]
#  [7 5 3]
#  [0 1 4]]
# Not present_do add
#
# up movement performed
# [[2 6 8]
#  [7 0 3]
#  [1 5 4]]
# present_do not add
#
# right movement performed
# [[2 6 8]
#  [7 5 3]
#  [1 4 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 6 8]
#  [7 5 3]
#  [1 0 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 6 8]
#  [7 3 4]
#  [0 1 5]]
# Not present_do add
#
# up movement performed
# [[2 6 8]
#  [7 0 4]
#  [1 3 5]]
# Not present_do add
#
# right movement performed
# [[2 6 8]
#  [7 3 4]
#  [1 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 6 8]
#  [7 3 4]
#  [1 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 3 6]
#  [5 2 7]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[3 0 6]
#  [5 2 7]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[3 6 0]
#  [5 2 7]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[3 2 6]
#  [5 0 7]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [1 2 7]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[5 3 6]
#  [1 0 7]
#  [4 2 8]]
# present_do not add
#
# right movement performed
# [[5 3 6]
#  [1 2 7]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[5 3 6]
#  [1 2 7]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 5 6]
#  [0 3 7]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 5 6]
#  [2 3 7]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 5 6]
#  [3 0 7]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 6]
#  [1 3 7]
#  [0 4 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[5 3 6]
#  [0 4 7]
#  [2 1 8]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [5 4 7]
#  [2 1 8]]
# Not present_do add
#
# right movement performed
# [[5 3 6]
#  [4 0 7]
#  [2 1 8]]
# Not present_do add
#
# Down movement performed
# [[5 3 6]
#  [2 4 7]
#  [0 1 8]]
# present_do not add
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [2 0 4]
#  [1 8 7]]
# Not present_do add
#
# up movement performed
# [[5 3 0]
#  [2 4 6]
#  [1 8 7]]
# Not present_do add
#
# cannot perform Right movement
# [[5 3 6]
#  [2 4 0]
#  [1 8 7]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [2 4 7]
#  [1 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 3 6]
#  [0 7 8]
#  [2 1 4]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [5 7 8]
#  [2 1 4]]
# Not present_do add
#
# right movement performed
# [[5 3 6]
#  [7 0 8]
#  [2 1 4]]
# Not present_do add
#
# Down movement performed
# [[5 3 6]
#  [2 7 8]
#  [0 1 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 3 6]
#  [0 2 8]
#  [1 7 4]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [5 2 8]
#  [1 7 4]]
# Not present_do add
#
# right movement performed
# [[5 3 6]
#  [2 0 8]
#  [1 7 4]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [1 2 8]
#  [0 7 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 5 6]
#  [2 3 8]
#  [1 7 4]]
# Not present_do add
#
# cannot perform Up movement
# [[5 0 6]
#  [2 3 8]
#  [1 7 4]]
# present_do not add
#
# right movement performed
# [[5 6 0]
#  [2 3 8]
#  [1 7 4]]
# Not present_do add
#
# Down movement performed
# [[5 3 6]
#  [2 0 8]
#  [1 7 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [2 0 8]
#  [1 7 4]]
# present_do not add
#
# up movement performed
# [[5 3 0]
#  [2 8 6]
#  [1 7 4]]
# Not present_do add
#
# cannot perform Right movement
# [[5 3 6]
#  [2 8 0]
#  [1 7 4]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [2 8 4]
#  [1 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [2 0 1]
#  [4 7 8]]
# Not present_do add
#
# up movement performed
# [[5 3 0]
#  [2 1 6]
#  [4 7 8]]
# present_do not add
#
# cannot perform Right movement
# [[5 3 6]
#  [2 1 0]
#  [4 7 8]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [2 1 8]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[5 1 3]
#  [0 2 6]
#  [4 7 8]]
# present_do not add
#
# up movement performed
# [[0 1 3]
#  [5 2 6]
#  [4 7 8]]
# present_do not add
#
# right movement performed
# [[5 1 3]
#  [2 0 6]
#  [4 7 8]]
# present_do not add
#
# Down movement performed
# [[5 1 3]
#  [4 2 6]
#  [0 7 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 1 3]
#  [2 0 6]
#  [4 7 8]]
# present_do not add
#
# up movement performed
# [[5 1 0]
#  [2 6 3]
#  [4 7 8]]
# Not present_do add
#
# cannot perform Right movement
# [[5 1 3]
#  [2 6 0]
#  [4 7 8]]
# present_do not add
#
# Down movement performed
# [[5 1 3]
#  [2 6 8]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 1 3]
#  [2 7 6]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[5 1 3]
#  [2 0 6]
#  [4 7 8]]
# present_do not add
#
# right movement performed
# [[5 1 3]
#  [2 7 6]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[5 1 3]
#  [2 7 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# present_do not add
#
# up movement performed
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
# Not present_do add
#
# right movement performed
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# present_do not add
#
# Next Iteration

# %%
import numpy as np
import os 


#Node_State = np.array([[1,0,3],[4,2,5],[7,8,6]]) #working_instant
#Node_State = np.array([[2,8,3],[1,6,4],[7,0,5]]) #takes_lot_of_time
#Node_State = np.array([[2,4,3],[7,8,0],[6,1,5]])  #working_maybe_a_min
#Node_State = np.array([[1,0,2],[4,6,8],[7,3,5]]) #working_instant
#Node_State = np.array([[4,8,1],[5,2,0],[7,6,3]]) #working_instant
Node_State = np.array([[7,2,3],[1,5,6],[4,8,0]]) #working_maybe_a_min


Goal_Node = np.array([[1,2,3],[4,5,6],[7,8,0]])
ParentNodes = {}
ParentNodes = {1:0}
AllNodes ={}
AllNodes = {1:Node_State}
path = list()
notepad_path = list()

NewNode1 = Node_State.copy()
NewNode2 = Node_State.copy()
NewNode3 = Node_State.copy()
NewNode4 = Node_State.copy()

a = 1
b = 1
next_node =1
flag = 1
clean =1
note_path = 0

# %%
def BlankTileLocation(state):
    for i in range(0,len(Node_State[1])):
        for j in range(0,len(Node_State[1])):
            if state[i,j] == 0:
                return[i,j]
            
            
def ActionMoveLeft(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if j == 0:
                    print("cannot perform left movement")
                    return[0, state]
                else:
                    print("left movement performed")
                    New_state[i,j-1], New_state[i,j] = New_state[i,j], New_state[i,j-1]
                    return[1, New_state]
            
            
def ActionMoveRight(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if j == 2:
                    print("cannot perform Right movement")
                    return[0, state]
                    
                else:
                    print("right movement performed")
                    New_state[i,j+1], New_state[i,j] = New_state[i,j], New_state[i,j+1]
                    return[1, New_state]

def ActionMoveUp(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if i == 0:
                    print("cannot perform Up movement")
                    return[0, state]
                    
                else:
                    print("up movement performed")
                    New_state[i-1,j], New_state[i,j] = New_state[i,j], New_state[i-1,j]
                    return[1, New_state]
            
def ActionMoveDown(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if i == 2:
                    print("cannot perform Down movement")
                    return[0, state]
                    
                else:
                    print("Down movement performed")
                    New_state[i+1,j], New_state[i,j] = New_state[i,j], New_state[i+1,j]
                    return[1, New_state]
                
            
            
def AddNode(New_N):
    global a
    global b
    global flag 
    flag = 1
    
    for values in AllNodes.values():
        if (values == New_N).all():
            flag = 0
            print("present_do not add")
    
    if(flag == 1):
        print("Not present_do add")
        a = a+1
        AllNodes[a] = New_N
        ParentNodes[a] = b

            

def Check_and_Add(state1):
    global b
    global NewNode1
    global NewNode2
    global NewNode3
    global NewNode4
    [Status, NewNode] = ActionMoveLeft(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode1 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveUp(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode2 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveRight(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode3 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveDown(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    print("Next Iteration")
    print("")
    NewNode4 = NewNode.copy()
    b = b+1

# %%
def get_key_AllNodes(val): 
    for key, value in AllNodes.items(): 
         if (val == value).all(): 
             return key 
  
    return "key doesn't exist"


def get_key_ParentNodes(val): 
    for key, value in ParentNodes.items(): 
         if (val == value): 
             return key 
  
    return "key doesn't exist"


def clean_AllNodes(AllNodes):
    key = get_key_AllNodes(Goal_Node)
    length = len(AllNodes)
    while(key != length):
        key = key + 1
        AllNodes.pop(key, None)

# %%
def generate_path(p_nodes):
    
    Start_key = get_key_AllNodes(Node_State) 
    print("Start_key =")
    print(Start_key)
    print("")

    Goal_key = get_key_AllNodes(Goal_Node)
    print("Goal_key = ")
    print(Goal_key)
    print("") 
    
    Goal = 0
    
    path.insert(Goal, Goal_key)
    print("goal_path = ")
    
    while(path[Goal] != Start_key):
        Goal = Goal + 1
        path.insert(Goal, p_nodes[Goal_key])
        Goal_key = p_nodes[Goal_key]      
    path.sort()
    print(path)
    return(path)


def print_optimalpath(path):
    global note_path
    global notepad_path
    print("Optimal path from Start to Goal")
    for m in path:
        notepad_path.insert(note_path ,AllNodes[m])
        note_path = note_path + 1
        print(AllNodes[m])
        print("")

# %%
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for i in range(0,len(s[1])):
        for j in range(0,len(s[1])):
            str1 = str1 + str(s[j,i]) 
            
    str1=" ".join(str1)
    # return string   
    return str1

# %%
def nodePath_filegen(notepad_path):
        
## Creates the nodePath.txt File
  
    # Before creating 
    dir_list = os.listdir(path)   
  
    # Creates a new file 
    with open('nodePath.txt', 'w') as fp: 
        pass
        for m in notepad_path:
            fp.write(listToString(m))
            fp.write("\n")
  
    # After creating  
    dir_list = os.listdir(path) 
 

def NodesInfo_filegen(ParentNodes):

## Creates the NodesInfo.txt File
  
    # Before creating 
    dir_list = os.listdir(path)   
  
    # Creates a new file 
    with open('NodesInfo.txt', 'w') as fp: 
        pass
        for key, value in sorted(ParentNodes.items()):
            fp.write(str(key))
            fp.write(" ")
            fp.write(str(value))
            fp.write(" ")
            fp.write("0")
            fp.write("\n")

  
    # After creating  
    dir_list = os.listdir(path) 
    
    
def Nodes_filegen(AllNodes):

## Creates the Nodes.txt File
  
    # Before creating 
    dir_list = os.listdir(path)   
  
    # Creates a new file 
    with open('Nodes.txt', 'w') as fp: 
        pass
        for key, value in sorted(AllNodes.items()):
            fp.write(listToString(value))
            fp.write("\n")

  
    # After creating  
    dir_list = os.listdir(path)

# %%
while((not(np.array_equal(NewNode1, Goal_Node))) and (not(np.array_equal(NewNode2, Goal_Node))) and (not(np.array_equal(NewNode3, Goal_Node))) and (not(np.array_equal(NewNode4, Goal_Node)))):
    global next_node 
    Check_and_Add(AllNodes[next_node])
    next_node = next_node +1
# Out:
# left movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 5 0]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 0 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 0 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 6 0]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 0 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 0 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [5 0 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 7 3]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 3 0]
#  [1 2 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 7 3]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 3 0]
#  [1 2 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 8 5]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 8 5]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 7 2]
#  [1 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[7 5 2]
#  [1 0 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 5 3]
#  [0 7 6]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 5 3]
#  [7 6 0]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 3]
#  [7 4 6]
#  [1 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[5 7 3]
#  [0 2 6]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [5 2 0]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [5 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 6 8]
#  [1 0 4]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [5 6 0]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 4 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 0 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [5 4 0]
#  [1 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 1 0]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [0 7 6]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[2 0 3]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 6 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 5 6]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 4 6]
#  [5 1 8]]
# present_do not add
#
# up movement performed
# [[7 0 3]
#  [4 2 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 6 0]
#  [5 1 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 0 8]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 1 0]
#  [5 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[1 0 3]
#  [2 7 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [2 6 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 5 6]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [0 2 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [4 2 6]
#  [5 0 8]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [0 1 2]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 0 6]
#  [1 3 2]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [1 5 2]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 2 8]
#  [4 0 5]]
# Not present_do add
#
# up movement performed
# [[7 3 6]
#  [1 2 0]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 7 2]
#  [0 6 3]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 6 2]
#  [0 1 3]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[7 0 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 6 2]
#  [1 3 0]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 6 2]
#  [1 5 3]
#  [4 0 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [0 6 8]
#  [1 4 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 1 8]
#  [4 6 5]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [1 2 8]
#  [4 6 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 6 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 3 5]
#  [7 1 0]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [0 7 5]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[2 0 3]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 5 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[2 1 3]
#  [7 8 5]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 4 5]
#  [8 1 6]]
# Not present_do add
#
# up movement performed
# [[7 0 3]
#  [4 2 5]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 5 0]
#  [8 1 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 0 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [4 1 0]
#  [8 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 0 3]
#  [2 7 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [2 5 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 8 5]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [0 2 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [4 2 5]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [0 1 2]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[7 0 5]
#  [1 3 2]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 8 2]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 2 6]
#  [4 0 8]]
# Not present_do add
#
# up movement performed
# [[7 3 5]
#  [1 2 0]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[2 0 3]
#  [7 8 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [0 8 5]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[7 0 3]
#  [8 2 5]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [8 5 0]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [8 4 5]
#  [1 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 0 2]
#  [1 8 3]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# cannot perform Right movement
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [1 8 0]
#  [4 6 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 0 2]
#  [5 7 3]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[1 7 2]
#  [5 3 0]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [5 8 3]
#  [4 0 6]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 2]
#  [0 5 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [4 5 3]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[5 0 2]
#  [7 1 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [0 1 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 2]
#  [4 1 3]
#  [8 0 6]]
# Not present_do add
#
# cannot perform Down movement
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 0 5]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 3 6]
#  [4 0 8]]
# Not present_do add
#
# up movement performed
# [[7 5 2]
#  [1 3 0]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [0 8 3]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 0 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [1 8 0]
#  [4 6 3]]
# Not present_do add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [7 0 5]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [7 5 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 5 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 5 3]
#  [0 7 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 5 3]
#  [2 7 6]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 5 3]
#  [1 7 6]
#  [0 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[2 5 0]
#  [7 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Right movement
# [[2 5 3]
#  [7 6 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 5 3]
#  [7 6 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 5 3]
#  [7 4 6]
#  [0 1 8]]
# Not present_do add
#
# up movement performed
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 5 3]
#  [7 4 6]
#  [1 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 5 3]
#  [7 4 6]
#  [1 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 7 3]
#  [0 2 6]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 7 3]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[5 7 3]
#  [2 0 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[5 7 3]
#  [1 2 6]
#  [0 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [5 0 2]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[7 3 0]
#  [5 2 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 3 6]
#  [5 2 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [5 2 8]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [5 6 3]
#  [1 4 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [5 6 3]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [5 0 3]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 6 8]
#  [0 1 4]]
# Not present_do add
#
# up movement performed
# [[7 2 3]
#  [5 0 8]
#  [1 6 4]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [5 6 8]
#  [1 4 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 2 3]
#  [5 6 8]
#  [1 0 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 4 6]
#  [5 1 8]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 4 6]
#  [5 1 8]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 4 6]
#  [0 1 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [5 0 4]
#  [1 8 6]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [5 4 3]
#  [1 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [5 4 0]
#  [1 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [5 4 6]
#  [1 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [7 0 1]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [7 1 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 6]
#  [7 1 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 1 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 1 3]
#  [0 7 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 1 3]
#  [2 7 6]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [4 7 6]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[2 1 0]
#  [7 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[2 1 3]
#  [7 6 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [7 6 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 5 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[2 1 3]
#  [7 0 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 5 6]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 1 3]
#  [7 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [4 2 6]
#  [5 1 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [4 2 6]
#  [5 1 8]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [4 2 6]
#  [5 1 8]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 6]
#  [5 1 8]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [4 6 3]
#  [5 1 8]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 6 0]
#  [5 1 8]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 6 8]
#  [5 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 1]
#  [5 8 6]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [4 1 3]
#  [5 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 0]
#  [5 8 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 6]
#  [5 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 1 3]
#  [2 7 6]
#  [4 5 8]]
# present_do not add
#
# cannot perform Up movement
# [[1 0 3]
#  [2 7 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 3 0]
#  [2 7 6]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[1 7 0]
#  [2 6 3]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[1 7 3]
#  [2 6 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [2 6 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 5 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[1 7 3]
#  [2 0 6]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 5 6]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [2 5 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [4 2 6]
#  [0 5 8]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [4 0 6]
#  [5 2 8]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [4 2 6]
#  [5 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 6]
#  [5 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 3 6]
#  [0 1 2]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [7 1 2]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 3 6]
#  [4 1 2]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 6]
#  [1 3 2]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 6]
#  [1 3 2]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 6 0]
#  [1 3 2]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 5 2]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 3 6]
#  [1 0 2]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 3 6]
#  [1 5 2]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 3 6]
#  [1 5 2]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 6]
#  [1 2 8]
#  [0 4 5]]
# Not present_do add
#
# up movement performed
# [[7 3 6]
#  [1 0 8]
#  [4 2 5]]
# Not present_do add
#
# right movement performed
# [[7 3 6]
#  [1 2 8]
#  [4 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 6]
#  [1 2 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 7 2]
#  [0 6 3]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 7 2]
#  [1 6 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [6 0 3]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [4 6 3]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[7 6 2]
#  [0 1 3]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [7 1 3]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [4 1 3]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[7 6 0]
#  [1 3 2]
#  [4 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[7 6 2]
#  [1 3 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[7 6 2]
#  [1 3 8]
#  [4 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 6 2]
#  [1 5 3]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 6 2]
#  [1 0 3]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[7 6 2]
#  [1 5 3]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 6 2]
#  [1 5 3]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 6 8]
#  [1 4 5]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 6 8]
#  [1 4 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [6 0 8]
#  [1 4 5]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 6 8]
#  [0 4 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 1 8]
#  [4 6 5]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 1 8]
#  [4 6 5]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 8]
#  [0 6 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [1 2 8]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [1 2 8]
#  [4 6 5]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [1 2 8]
#  [4 6 5]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 0 8]
#  [4 6 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 5]
#  [7 0 1]
#  [4 8 6]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [7 1 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 5]
#  [7 1 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 3 5]
#  [7 1 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 1 3]
#  [0 7 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 1 3]
#  [2 7 5]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [4 7 5]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[2 1 0]
#  [7 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[2 1 3]
#  [7 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[2 1 3]
#  [7 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 1 3]
#  [7 8 5]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[2 1 3]
#  [7 0 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[2 1 3]
#  [7 8 5]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 1 3]
#  [7 8 5]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 4 5]
#  [8 1 6]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 4 5]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [8 4 5]
#  [0 1 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [4 2 5]
#  [8 1 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [4 2 5]
#  [8 1 6]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [4 2 5]
#  [8 1 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 5]
#  [8 1 6]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [4 5 3]
#  [8 1 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 5 0]
#  [8 1 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 5 6]
#  [8 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [4 0 1]
#  [8 6 5]]
# Not present_do add
#
# up movement performed
# [[7 2 0]
#  [4 1 3]
#  [8 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [4 1 0]
#  [8 6 5]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [4 1 5]
#  [8 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 1 3]
#  [2 7 5]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[1 0 3]
#  [2 7 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 3 0]
#  [2 7 5]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 0]
#  [2 5 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[1 7 3]
#  [2 5 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 3]
#  [2 5 6]
#  [4 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [2 8 5]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[1 7 3]
#  [2 0 5]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 3]
#  [2 8 5]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [2 8 5]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 3]
#  [4 2 5]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 3]
#  [4 0 5]
#  [8 2 6]]
# Not present_do add
#
# right movement performed
# [[1 7 3]
#  [4 2 5]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 3]
#  [4 2 5]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 3 5]
#  [0 1 2]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[0 3 5]
#  [7 1 2]
#  [4 8 6]]
# Not present_do add
#
# right movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [4 1 2]
#  [0 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 5]
#  [1 3 2]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 5]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 5 0]
#  [1 3 2]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 8 2]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[7 3 5]
#  [1 0 2]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[7 3 5]
#  [1 8 2]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 3 5]
#  [1 8 2]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 3 5]
#  [1 2 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 3 5]
#  [1 0 6]
#  [4 2 8]]
# Not present_do add
#
# right movement performed
# [[7 3 5]
#  [1 2 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 3 5]
#  [1 2 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 3]
#  [7 8 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [7 8 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[2 8 3]
#  [7 0 5]
#  [1 4 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 7 3]
#  [8 2 5]
#  [1 4 6]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 3]
#  [8 2 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[7 3 0]
#  [8 2 5]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [8 5 3]
#  [1 4 6]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 3]
#  [8 5 0]
#  [1 4 6]]
# present_do not add
#
# Down movement performed
# [[7 2 3]
#  [8 5 6]
#  [1 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 3]
#  [8 4 5]
#  [0 1 6]]
# present_do not add
#
# up movement performed
# [[7 2 3]
#  [8 0 5]
#  [1 4 6]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [8 4 5]
#  [1 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 3]
#  [8 4 5]
#  [1 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 2]
#  [1 8 3]
#  [4 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[7 0 2]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# right movement performed
# [[7 2 0]
#  [1 8 3]
#  [4 6 5]]
# present_do not add
#
# Down movement performed
# [[7 8 2]
#  [1 0 3]
#  [4 6 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [5 7 3]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [5 7 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [5 7 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 0]
#  [5 3 2]
#  [4 8 6]]
# Not present_do add
#
# cannot perform Right movement
# [[1 7 2]
#  [5 3 0]
#  [4 8 6]]
# present_do not add
#
# Down movement performed
# [[1 7 2]
#  [5 3 6]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [5 8 3]
#  [0 4 6]]
# Not present_do add
#
# up movement performed
# [[1 7 2]
#  [5 0 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[1 7 2]
#  [5 8 3]
#  [4 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 2]
#  [5 8 3]
#  [4 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 7 2]
#  [4 5 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[1 7 2]
#  [4 0 3]
#  [8 5 6]]
# Not present_do add
#
# right movement performed
# [[1 7 2]
#  [4 5 3]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 7 2]
#  [4 5 3]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 5 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# cannot perform Up movement
# [[5 0 2]
#  [7 1 3]
#  [4 8 6]]
# present_do not add
#
# right movement performed
# [[5 2 0]
#  [7 1 3]
#  [4 8 6]]
# Not present_do add
#
# Down movement performed
# [[5 1 2]
#  [7 0 3]
#  [4 8 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [4 1 3]
#  [0 8 6]]
# present_do not add
#
# up movement performed
# [[7 5 2]
#  [4 0 3]
#  [8 1 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [4 1 3]
#  [8 6 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 5 2]
#  [4 1 3]
#  [8 0 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 3 6]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[7 5 2]
#  [1 0 6]
#  [4 3 8]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [1 3 6]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[7 5 2]
#  [1 3 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 5 2]
#  [0 8 3]
#  [1 4 6]]
# present_do not add
#
# up movement performed
# [[0 5 2]
#  [7 8 3]
#  [1 4 6]]
# Not present_do add
#
# right movement performed
# [[7 5 2]
#  [8 0 3]
#  [1 4 6]]
# Not present_do add
#
# Down movement performed
# [[7 5 2]
#  [1 8 3]
#  [0 4 6]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 5 2]
#  [1 0 8]
#  [4 6 3]]
# Not present_do add
#
# up movement performed
# [[7 5 0]
#  [1 8 2]
#  [4 6 3]]
# Not present_do add
#
# cannot perform Right movement
# [[7 5 2]
#  [1 8 0]
#  [4 6 3]]
# present_do not add
#
# Down movement performed
# [[7 5 2]
#  [1 8 3]
#  [4 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [0 7 5]
#  [1 4 8]]
# Not present_do add
#
# up movement performed
# [[2 0 6]
#  [7 3 5]
#  [1 4 8]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [7 4 5]
#  [1 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [7 5 8]
#  [1 0 4]]
# Not present_do add
#
# up movement performed
# [[2 3 6]
#  [7 5 0]
#  [1 4 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 3 6]
#  [7 5 8]
#  [1 4 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 3 6]
#  [7 5 8]
#  [1 4 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 5 3]
#  [2 7 6]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[0 5 3]
#  [2 7 6]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[5 0 3]
#  [2 7 6]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 3]
#  [0 7 6]
#  [1 4 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 5 3]
#  [1 7 6]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[2 5 3]
#  [0 7 6]
# ...
# [[3 4 6]
#  [0 2 5]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[0 4 6]
#  [3 2 5]
#  [7 1 8]]
# Not present_do add
#
# right movement performed
# [[3 4 6]
#  [2 0 5]
#  [7 1 8]]
# present_do not add
#
# Down movement performed
# [[3 4 6]
#  [7 2 5]
#  [0 1 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 4 6]
#  [2 0 5]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[3 4 0]
#  [2 5 6]
#  [7 1 8]]
# Not present_do add
#
# cannot perform Right movement
# [[3 4 6]
#  [2 5 0]
#  [7 1 8]]
# present_do not add
#
# Down movement performed
# [[3 4 6]
#  [2 5 8]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 4 6]
#  [2 1 5]
#  [0 7 8]]
# Not present_do add
#
# up movement performed
# [[3 4 6]
#  [2 0 5]
#  [7 1 8]]
# present_do not add
#
# right movement performed
# [[3 4 6]
#  [2 1 5]
#  [7 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[3 4 6]
#  [2 1 5]
#  [7 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 2 6]
#  [0 3 5]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[0 2 6]
#  [4 3 5]
#  [7 1 8]]
# present_do not add
#
# right movement performed
# [[4 2 6]
#  [3 0 5]
#  [7 1 8]]
# Not present_do add
#
# Down movement performed
# [[4 2 6]
#  [7 3 5]
#  [0 1 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 6 5]
#  [4 0 3]
#  [7 1 8]]
# present_do not add
#
# up movement performed
# [[2 6 0]
#  [4 3 5]
#  [7 1 8]]
# present_do not add
#
# cannot perform Right movement
# [[2 6 5]
#  [4 3 0]
#  [7 1 8]]
# present_do not add
#
# Down movement performed
# [[2 6 5]
#  [4 3 8]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [4 5 8]
#  [0 7 1]]
# Not present_do add
#
# up movement performed
# [[2 3 6]
#  [4 0 8]
#  [7 5 1]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [4 5 8]
#  [7 1 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 3 6]
#  [4 5 8]
#  [7 0 1]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [4 0 1]
#  [7 8 5]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [4 1 6]
#  [7 8 5]]
# Not present_do add
#
# cannot perform Right movement
# [[2 3 6]
#  [4 1 0]
#  [7 8 5]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [4 1 5]
#  [7 8 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 3 6]
#  [2 7 4]
#  [1 8 5]]
# present_do not add
#
# cannot perform Up movement
# [[3 0 6]
#  [2 7 4]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[3 6 0]
#  [2 7 4]
#  [1 8 5]]
# Not present_do add
#
# Down movement performed
# [[3 7 6]
#  [2 0 4]
#  [1 8 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [1 7 4]
#  [0 8 5]]
# present_do not add
#
# up movement performed
# [[2 3 6]
#  [1 0 4]
#  [8 7 5]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [1 7 4]
#  [8 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 3 6]
#  [1 7 4]
#  [8 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 6]
#  [0 3 4]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[0 2 6]
#  [7 3 4]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[7 2 6]
#  [3 0 4]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[7 2 6]
#  [1 3 4]
#  [0 8 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 6 4]
#  [7 0 3]
#  [1 8 5]]
# Not present_do add
#
# up movement performed
# [[2 6 0]
#  [7 3 4]
#  [1 8 5]]
# present_do not add
#
# cannot perform Right movement
# [[2 6 4]
#  [7 3 0]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[2 6 4]
#  [7 3 5]
#  [1 8 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 3 6]
#  [0 8 4]
#  [7 1 5]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [2 8 4]
#  [7 1 5]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [8 0 4]
#  [7 1 5]]
# Not present_do add
#
# Down movement performed
# [[2 3 6]
#  [7 8 4]
#  [0 1 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[7 2 3]
#  [0 4 6]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [7 4 6]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[7 2 3]
#  [4 0 6]
#  [1 8 5]]
# Not present_do add
#
# Down movement performed
# [[7 2 3]
#  [1 4 6]
#  [0 8 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[2 4 3]
#  [0 7 6]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[0 4 3]
#  [2 7 6]
#  [1 8 5]]
# Not present_do add
#
# right movement performed
# [[2 4 3]
#  [7 0 6]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[2 4 3]
#  [1 7 6]
#  [0 8 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 4 3]
#  [7 0 6]
#  [1 8 5]]
# present_do not add
#
# up movement performed
# [[2 4 0]
#  [7 6 3]
#  [1 8 5]]
# Not present_do add
#
# cannot perform Right movement
# [[2 4 3]
#  [7 6 0]
#  [1 8 5]]
# present_do not add
#
# Down movement performed
# [[2 4 3]
#  [7 6 5]
#  [1 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 4 3]
#  [7 8 6]
#  [0 1 5]]
# Not present_do add
#
# up movement performed
# [[2 4 3]
#  [7 0 6]
#  [1 8 5]]
# present_do not add
#
# right movement performed
# [[2 4 3]
#  [7 8 6]
#  [1 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 4 3]
#  [7 8 6]
#  [1 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[3 6 8]
#  [2 0 5]
#  [7 1 4]]
# Not present_do add
#
# up movement performed
# [[3 6 0]
#  [2 5 8]
#  [7 1 4]]
# present_do not add
#
# cannot perform Right movement
# [[3 6 8]
#  [2 5 0]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[3 6 8]
#  [2 5 4]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[3 5 6]
#  [0 2 8]
#  [7 1 4]]
# present_do not add
#
# up movement performed
# [[0 5 6]
#  [3 2 8]
#  [7 1 4]]
# Not present_do add
#
# right movement performed
# [[3 5 6]
#  [2 0 8]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[3 5 6]
#  [7 2 8]
#  [0 1 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 5 6]
#  [2 0 8]
#  [7 1 4]]
# present_do not add
#
# up movement performed
# [[3 5 0]
#  [2 8 6]
#  [7 1 4]]
# Not present_do add
#
# cannot perform Right movement
# [[3 5 6]
#  [2 8 0]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[3 5 6]
#  [2 8 4]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 5 6]
#  [2 1 8]
#  [0 7 4]]
# Not present_do add
#
# up movement performed
# [[3 5 6]
#  [2 0 8]
#  [7 1 4]]
# present_do not add
#
# right movement performed
# [[3 5 6]
#  [2 1 8]
#  [7 4 0]]
# Not present_do add
#
# cannot perform Down movement
# [[3 5 6]
#  [2 1 8]
#  [7 0 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 2 6]
#  [0 3 8]
#  [7 1 4]]
# present_do not add
#
# up movement performed
# [[0 2 6]
#  [5 3 8]
#  [7 1 4]]
# present_do not add
#
# right movement performed
# [[5 2 6]
#  [3 0 8]
#  [7 1 4]]
# Not present_do add
#
# Down movement performed
# [[5 2 6]
#  [7 3 8]
#  [0 1 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 6 8]
#  [5 0 3]
#  [7 1 4]]
# Not present_do add
#
# up movement performed
# [[2 6 0]
#  [5 3 8]
#  [7 1 4]]
# present_do not add
#
# cannot perform Right movement
# [[2 6 8]
#  [5 3 0]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[2 6 8]
#  [5 3 4]
#  [7 1 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 3]
#  [5 8 6]
#  [7 1 4]]
# Not present_do add
#
# cannot perform Up movement
# [[2 0 3]
#  [5 8 6]
#  [7 1 4]]
# present_do not add
#
# right movement performed
# [[2 3 0]
#  [5 8 6]
#  [7 1 4]]
# present_do not add
#
# Down movement performed
# [[2 8 3]
#  [5 0 6]
#  [7 1 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [5 8 4]
#  [0 7 1]]
# Not present_do add
#
# up movement performed
# [[2 3 6]
#  [5 0 4]
#  [7 8 1]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [5 8 4]
#  [7 1 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 3 6]
#  [5 8 4]
#  [7 0 1]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 3 6]
#  [0 1 8]
#  [5 7 4]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [2 1 8]
#  [5 7 4]]
# Not present_do add
#
# right movement performed
# [[2 3 6]
#  [1 0 8]
#  [5 7 4]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [5 1 8]
#  [0 7 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[3 6 8]
#  [2 0 7]
#  [1 5 4]]
# Not present_do add
#
# up movement performed
# [[3 6 0]
#  [2 7 8]
#  [1 5 4]]
# present_do not add
#
# cannot perform Right movement
# [[3 6 8]
#  [2 7 0]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[3 6 8]
#  [2 7 4]
#  [1 5 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[3 7 6]
#  [0 2 8]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[0 7 6]
#  [3 2 8]
#  [1 5 4]]
# Not present_do add
#
# right movement performed
# [[3 7 6]
#  [2 0 8]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[3 7 6]
#  [1 2 8]
#  [0 5 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 7 6]
#  [2 0 8]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[3 7 0]
#  [2 8 6]
#  [1 5 4]]
# Not present_do add
#
# cannot perform Right movement
# [[3 7 6]
#  [2 8 0]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[3 7 6]
#  [2 8 4]
#  [1 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 6]
#  [1 3 8]
#  [5 7 4]]
# Not present_do add
#
# cannot perform Up movement
# [[2 0 6]
#  [1 3 8]
#  [5 7 4]]
# present_do not add
#
# right movement performed
# [[2 6 0]
#  [1 3 8]
#  [5 7 4]]
# Not present_do add
#
# Down movement performed
# [[2 3 6]
#  [1 0 8]
#  [5 7 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [1 0 8]
#  [5 7 4]]
# present_do not add
#
# up movement performed
# [[2 3 0]
#  [1 8 6]
#  [5 7 4]]
# Not present_do add
#
# cannot perform Right movement
# [[2 3 6]
#  [1 8 0]
#  [5 7 4]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [1 8 4]
#  [5 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 3 6]
#  [1 0 7]
#  [5 4 8]]
# Not present_do add
#
# up movement performed
# [[2 3 0]
#  [1 7 6]
#  [5 4 8]]
# Not present_do add
#
# cannot perform Right movement
# [[2 3 6]
#  [1 7 0]
#  [5 4 8]]
# present_do not add
#
# Down movement performed
# [[2 3 6]
#  [1 7 8]
#  [5 4 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 7 6]
#  [3 2 8]
#  [1 5 4]]
# present_do not add
#
# cannot perform Up movement
# [[7 0 6]
#  [3 2 8]
#  [1 5 4]]
# present_do not add
#
# right movement performed
# [[7 6 0]
#  [3 2 8]
#  [1 5 4]]
# Not present_do add
#
# Down movement performed
# [[7 2 6]
#  [3 0 8]
#  [1 5 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[7 2 6]
#  [3 0 8]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[7 2 0]
#  [3 8 6]
#  [1 5 4]]
# Not present_do add
#
# cannot perform Right movement
# [[7 2 6]
#  [3 8 0]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[7 2 6]
#  [3 8 4]
#  [1 5 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[7 2 6]
#  [1 3 8]
#  [0 5 4]]
# present_do not add
#
# up movement performed
# [[7 2 6]
#  [1 0 8]
#  [5 3 4]]
# Not present_do add
#
# right movement performed
# [[7 2 6]
#  [1 3 8]
#  [5 4 0]]
# Not present_do add
#
# cannot perform Down movement
# [[7 2 6]
#  [1 3 8]
#  [5 0 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 6 8]
#  [0 7 3]
#  [1 5 4]]
# present_do not add
#
# up movement performed
# [[0 6 8]
#  [2 7 3]
#  [1 5 4]]
# Not present_do add
#
# right movement performed
# [[2 6 8]
#  [7 0 3]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[2 6 8]
#  [1 7 3]
#  [0 5 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 2 8]
#  [7 6 3]
#  [1 5 4]]
# Not present_do add
#
# cannot perform Up movement
# [[2 0 8]
#  [7 6 3]
#  [1 5 4]]
# present_do not add
#
# right movement performed
# [[2 8 0]
#  [7 6 3]
#  [1 5 4]]
# present_do not add
#
# Down movement performed
# [[2 6 8]
#  [7 0 3]
#  [1 5 4]]
# present_do not add
# Next Iteration
#
# left movement performed
# [[2 6 8]
#  [7 5 3]
#  [0 1 4]]
# Not present_do add
#
# up movement performed
# [[2 6 8]
#  [7 0 3]
#  [1 5 4]]
# present_do not add
#
# right movement performed
# [[2 6 8]
#  [7 5 3]
#  [1 4 0]]
# Not present_do add
#
# cannot perform Down movement
# [[2 6 8]
#  [7 5 3]
#  [1 0 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 6 8]
#  [7 3 4]
#  [0 1 5]]
# Not present_do add
#
# up movement performed
# [[2 6 8]
#  [7 0 4]
#  [1 3 5]]
# Not present_do add
#
# right movement performed
# [[2 6 8]
#  [7 3 4]
#  [1 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[2 6 8]
#  [7 3 4]
#  [1 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 3 6]
#  [5 2 7]
#  [1 4 8]]
# present_do not add
#
# cannot perform Up movement
# [[3 0 6]
#  [5 2 7]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[3 6 0]
#  [5 2 7]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[3 2 6]
#  [5 0 7]
#  [1 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [1 2 7]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[5 3 6]
#  [1 0 7]
#  [4 2 8]]
# present_do not add
#
# right movement performed
# [[5 3 6]
#  [1 2 7]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[5 3 6]
#  [1 2 7]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[2 5 6]
#  [0 3 7]
#  [1 4 8]]
# present_do not add
#
# up movement performed
# [[0 5 6]
#  [2 3 7]
#  [1 4 8]]
# present_do not add
#
# right movement performed
# [[2 5 6]
#  [3 0 7]
#  [1 4 8]]
# Not present_do add
#
# Down movement performed
# [[2 5 6]
#  [1 3 7]
#  [0 4 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[5 3 6]
#  [0 4 7]
#  [2 1 8]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [5 4 7]
#  [2 1 8]]
# Not present_do add
#
# right movement performed
# [[5 3 6]
#  [4 0 7]
#  [2 1 8]]
# Not present_do add
#
# Down movement performed
# [[5 3 6]
#  [2 4 7]
#  [0 1 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [2 0 4]
#  [1 8 7]]
# Not present_do add
#
# up movement performed
# [[5 3 0]
#  [2 4 6]
#  [1 8 7]]
# Not present_do add
#
# cannot perform Right movement
# [[5 3 6]
#  [2 4 0]
#  [1 8 7]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [2 4 7]
#  [1 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 3 6]
#  [0 7 8]
#  [2 1 4]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [5 7 8]
#  [2 1 4]]
# Not present_do add
#
# right movement performed
# [[5 3 6]
#  [7 0 8]
#  [2 1 4]]
# Not present_do add
#
# Down movement performed
# [[5 3 6]
#  [2 7 8]
#  [0 1 4]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[5 3 6]
#  [0 2 8]
#  [1 7 4]]
# present_do not add
#
# up movement performed
# [[0 3 6]
#  [5 2 8]
#  [1 7 4]]
# Not present_do add
#
# right movement performed
# [[5 3 6]
#  [2 0 8]
#  [1 7 4]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [1 2 8]
#  [0 7 4]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 5 6]
#  [2 3 8]
#  [1 7 4]]
# Not present_do add
#
# cannot perform Up movement
# [[5 0 6]
#  [2 3 8]
#  [1 7 4]]
# present_do not add
#
# right movement performed
# [[5 6 0]
#  [2 3 8]
#  [1 7 4]]
# Not present_do add
#
# Down movement performed
# [[5 3 6]
#  [2 0 8]
#  [1 7 4]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [2 0 8]
#  [1 7 4]]
# present_do not add
#
# up movement performed
# [[5 3 0]
#  [2 8 6]
#  [1 7 4]]
# Not present_do add
#
# cannot perform Right movement
# [[5 3 6]
#  [2 8 0]
#  [1 7 4]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [2 8 4]
#  [1 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 3 6]
#  [2 0 1]
#  [4 7 8]]
# Not present_do add
#
# up movement performed
# [[5 3 0]
#  [2 1 6]
#  [4 7 8]]
# present_do not add
#
# cannot perform Right movement
# [[5 3 6]
#  [2 1 0]
#  [4 7 8]]
# present_do not add
#
# Down movement performed
# [[5 3 6]
#  [2 1 8]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[5 1 3]
#  [0 2 6]
#  [4 7 8]]
# present_do not add
#
# up movement performed
# [[0 1 3]
#  [5 2 6]
#  [4 7 8]]
# present_do not add
#
# right movement performed
# [[5 1 3]
#  [2 0 6]
#  [4 7 8]]
# present_do not add
#
# Down movement performed
# [[5 1 3]
#  [4 2 6]
#  [0 7 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 1 3]
#  [2 0 6]
#  [4 7 8]]
# present_do not add
#
# up movement performed
# [[5 1 0]
#  [2 6 3]
#  [4 7 8]]
# Not present_do add
#
# cannot perform Right movement
# [[5 1 3]
#  [2 6 0]
#  [4 7 8]]
# present_do not add
#
# Down movement performed
# [[5 1 3]
#  [2 6 8]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[5 1 3]
#  [2 7 6]
#  [0 4 8]]
# present_do not add
#
# up movement performed
# [[5 1 3]
#  [2 0 6]
#  [4 7 8]]
# present_do not add
#
# right movement performed
# [[5 1 3]
#  [2 7 6]
#  [4 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[5 1 3]
#  [2 7 6]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# present_do not add
#
# up movement performed
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
# Not present_do add
#
# right movement performed
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# present_do not add
#
# Next Iteration

# %%
clean_AllNodes(AllNodes)

# %%
print(ParentNodes)
# Out:
# {1: 0, 2: 1, 3: 1, 4: 2, 5: 2, 6: 3, 7: 3, 8: 4, 9: 5, 10: 5, 11: 5, 12: 6, 13: 6, 14: 6, 15: 7, 16: 8, 17: 8, 18: 9, 19: 9, 20: 10, 21: 10, 22: 11, 23: 11, 24: 12, 25: 12, 26: 13, 27: 13, 28: 14, 29: 14, 30: 15, 31: 15, 32: 16, 33: 17, 34: 17, 35: 17, 36: 18, 37: 19, 38: 20, 39: 21, 40: 22, 41: 23, 42: 24, 43: 25, 44: 26, 45: 27, 46: 28, 47: 29, 48: 30, 49: 31, 50: 31, 51: 31, 52: 32, 53: 32, 54: 33, 55: 33, 56: 34, 57: 34, 58: 35, 59: 35, 60: 36, 61: 36, 62: 37, 63: 37, 64: 38, 65: 38, 66: 39, 67: 39, 68: 40, 69: 40, 70: 41, 71: 41, 72: 42, 73: 42, 74: 43, 75: 43, 76: 44, 77: 44, 78: 45, 79: 45, 80: 46, 81: 46, 82: 47, 83: 48, 84: 48, 85: 49, 86: 49, 87: 50, 88: 50, 89: 51, 90: 51, 91: 52, 92: 53, 93: 53, 94: 53, 95: 54, 96: 55, 97: 56, 98: 57, 99: 58, 100: 59, 101: 60, 102: 61, 103: 61, 104: 61, 105: 62, 106: 62, 107: 63, 108: 64, 109: 64, 110: 64, 111: 65, 112: 66, 113: 66, 114: 66, 115: 67, 116: 68, 117: 69, 118: 69, 119: 69, 120: 70, 121: 71, 122: 71, 123: 72, 124: 73, 125: 73, 126: 73, 127: 74, 128: 74, 129: 74, 130: 75, 131: 76, 132: 76, 133: 76, 134: 77, 135: 78, 136: 78, 137: 78, 138: 79, 139: 80, 140: 81, 141: 81, 142: 81, 143: 82, 144: 83, 145: 83, 146: 83, 147: 84, 148: 85, 149: 86, 150: 88, 151: 89, 152: 90, 153: 91, 154: 91, 155: 92, 156: 92, 157: 93, 158: 93, 159: 94, 160: 94, 161: 95, 162: 95, 163: 96, 164: 96, 165: 97, 166: 97, 167: 98, 168: 98, 169: 99, 170: 100, 171: 100, 172: 101, 173: 101, 174: 102, 175: 102, 176: 103, 177: 103, 178: 104, 179: 104, 180: 105, 181: 105, 182: 106, 183: 106, 184: 107, 185: 107, 186: 108, 187: 109, 188: 109, 189: 110, 190: 110, 191: 111, 192: 111, 193: 112, 194: 112, 195: 113, 196: 113, 197: 114, 198: 114, 199: 115, 200: 115, 201: 116, 202: 116, 203: 117, 204: 117, 205: 118, 206: 119, 207: 119, 208: 120, 209: 120, 210: 121, 211: 121, 212: 122, 213: 122, 214: 123, 215: 123, 216: 124, 217: 124, 218: 125, 219: 126, 220: 126, 221: 127, 222: 127, 223: 128, 224: 128, 225: 129, 226: 129, 227: 130, 228: 130, 229: 131, 230: 132, 231: 133, 232: 133, 233: 134, 234: 134, 235: 135, 236: 135, 237: 136, 238: 137, 239: 137, 240: 138, 241: 138, 242: 139, 243: 139, 244: 140, 245: 140, 246: 141, 247: 141, 248: 142, 249: 143, 250: 143, 251: 144, 252: 144, 253: 145, 254: 145, 255: 146, 256: 146, 257: 147, 258: 147, 259: 148, 260: 148, 261: 149, 262: 149, 263: 150, 264: 150, 265: 151, 266: 151, 267: 152, 268: 152, 269: 153, 270: 153, 271: 153, 272: 154, 273: 155, 274: 156, 275: 157, 276: 158, 277: 159, 278: 160, 279: 161, 280: 161, 281: 162, 282: 163, 283: 163, 284: 163, 285: 164, 286: 165, 287: 166, 288: 166, 289: 166, 290: 167, 291: 168, 292: 168, 293: 168, 294: 169, 295: 170, 296: 170, 297: 170, 298: 171, 299: 172, 300: 172, 301: 172, 302: 173, 303: 175, 304: 176, 305: 177, 306: 178, 307: 180, 308: 181, 309: 182, 310: 183, 311: 184, 312: 184, 313: 184, 314: 185, 315: 186, 316: 187, 317: 188, 318: 189, 319: 191, 320: 191, 321: 191, 322: 192, 323: 193, 324: 194, 325: 195, 326: 198, 327: 199, 328: 200, 329: 200, 330: 200, 331: 201, 332: 201, 333: 201, 334: 202, 335: 203, 336: 204, 337: 205, 338: 207, 339: 208, 340: 209, 341: 209, 342: 209, 343: 210, 344: 211, 345: 212, 346: 213, 347: 214, 348: 214, 349: 214, 350: 215, 351: 217, 352: 218, 353: 219, 354: 220, 355: 221, 356: 223, 357: 224, 358: 225, 359: 226, 360: 227, 361: 227, 362: 227, 363: 228, 364: 229, 365: 230, 366: 231, 367: 232, 368: 233, 369: 233, 370: 233, 371: 234, 372: 235, 373: 236, 374: 237, 375: 238, 376: 239, 377: 240, 378: 241, 379: 241, 380: 241, 381: 242, 382: 243, 383: 243, 384: 243, 385: 244, 386: 245, 387: 246, 388: 247, 389: 248, 390: 249, 391: 250, 392: 250, 393: 250, 394: 251, 395: 252, 396: 253, 397: 254, 398: 255, 399: 256, 400: 257, 401: 257, 402: 257, 403: 258, 404: 259, 405: 260, 406: 260, 407: 261, 408: 261, 409: 262, 410: 263, 411: 264, 412: 264, 413: 264, 414: 265, 415: 266, 416: 266, 417: 267, 418: 267, 419: 267, 420: 268, 421: 269, 422: 269, 423: 270, 424: 270, 425: 271, 426: 271, 427: 272, 428: 272, 429: 273, 430:  ...

# %%
print(AllNodes)
# Out:
# {1: array([[7, 2, 3],
#        [1, 5, 6],
#        [4, 8, 0]]), 2: array([[7, 2, 3],
#        [1, 5, 6],
#        [4, 0, 8]]), 3: array([[7, 2, 3],
#        [1, 5, 0],
#        [4, 8, 6]]), 4: array([[7, 2, 3],
#        [1, 5, 6],
#        [0, 4, 8]]), 5: array([[7, 2, 3],
#        [1, 0, 6],
#        [4, 5, 8]]), 6: array([[7, 2, 3],
#        [1, 0, 5],
#        [4, 8, 6]]), 7: array([[7, 2, 0],
#        [1, 5, 3],
#        [4, 8, 6]]), 8: array([[7, 2, 3],
#        [0, 5, 6],
#        [1, 4, 8]]), 9: array([[7, 2, 3],
#        [0, 1, 6],
#        [4, 5, 8]]), 10: array([[7, 0, 3],
#        [1, 2, 6],
#        [4, 5, 8]]), 11: array([[7, 2, 3],
#        [1, 6, 0],
#        [4, 5, 8]]), 12: array([[7, 2, 3],
#        [0, 1, 5],
#        [4, 8, 6]]), 13: array([[7, 0, 3],
#        [1, 2, 5],
#        [4, 8, 6]]), 14: array([[7, 2, 3],
#        [1, 8, 5],
#        [4, 0, 6]]), 15: array([[7, 0, 2],
#        [1, 5, 3],
#        [4, 8, 6]]), 16: array([[0, 2, 3],
#        [7, 5, 6],
#        [1, 4, 8]]), 17: array([[7, 2, 3],
#        [5, 0, 6],
#        [1, 4, 8]]), 18: array([[0, 2, 3],
#        [7, 1, 6],
#        [4, 5, 8]]), 19: array([[7, 2, 3],
#        [4, 1, 6],
#        [0, 5, 8]]), 20: array([[0, 7, 3],
#        [1, 2, 6],
#        [4, 5, 8]]), 21: array([[7, 3, 0],
#        [1, 2, 6],
#        [4, 5, 8]]), 22: array([[7, 2, 0],
#        [1, 6, 3],
#        [4, 5, 8]]), 23: array([[7, 2, 3],
#        [1, 6, 8],
#        [4, 5, 0]]), 24: array([[0, 2, 3],
#        [7, 1, 5],
#        [4, 8, 6]]), 25: array([[7, 2, 3],
#        [4, 1, 5],
#        [0, 8, 6]]), 26: array([[0, 7, 3],
#        [1, 2, 5],
#        [4, 8, 6]]), 27: array([[7, 3, 0],
#        [1, 2, 5],
#        [4, 8, 6]]), 28: array([[7, 2, 3],
#        [1, 8, 5],
#        [0, 4, 6]]), 29: array([[7, 2, 3],
#        [1, 8, 5],
#        [4, 6, 0]]), 30: array([[0, 7, 2],
#        [1, 5, 3],
#        [4, 8, 6]]), 31: array([[7, 5, 2],
#        [1, 0, 3],
#        [4, 8, 6]]), 32: array([[2, 0, 3],
#        [7, 5, 6],
#        [1, 4, 8]]), 33: array([[7, 0, 3],
#        [5, 2, 6],
#        [1, 4, 8]]), 34: array([[7, 2, 3],
#        [5, 6, 0],
#        [1, 4, 8]]), 35: array([[7, 2, 3],
#        [5, 4, 6],
#        [1, 0, 8]]), 36: array([[2, 0, 3],
#        [7, 1, 6],
#        [4, 5, 8]]), 37: array([[7, 2, 3],
#        [4, 1, 6],
#        [5, 0, 8]]), 38: array([[1, 7, 3],
#        [0, 2, 6],
#        [4, 5, 8]]), 39: array([[7, 3, 6],
#        [1, 2, 0],
#        [4, 5, 8]]), 40: array([[7, 0, 2],
#        [1, 6, 3],
#        [4, 5, 8]]), 41: array([[7, 2, 3],
#        [1, 6, 8],
#        [4, 0, 5]]), 42: array([[2, 0, 3],
#        [7, 1, 5],
#        [4, 8, 6]]), 43: array([[7, 2, 3],
#        [4, 1, 5],
#        [8, 0, 6]]), 44: array([[1, 7, 3],
#        [0, 2, 5],
#        [4, 8, 6]]), 45: array([[7, 3, 5],
#        [1, 2, 0],
#        [4, 8, 6]]), 46: array([[7, 2, 3],
#        [0, 8, 5],
#        [1, 4, 6]]), 47: array([[7, 2, 3],
#        [1, 8, 0],
#        [4, 6, 5]]), 48: array([[1, 7, 2],
#        [0, 5, 3],
#        [4, 8, 6]]), 49: array([[7, 5, 2],
#        [0, 1, 3],
#        [4, 8, 6]]), 50: array([[7, 5, 2],
#        [1, 3, 0],
#        [4, 8, 6]]), 51: array([[7, 5, 2],
#        [1, 8, 3],
#        [4, 0, 6]]), 52: array([[2, 3, 0],
#        [7, 5, 6],
#        [1, 4, 8]]), 53: array([[2, 5, 3],
#        [7, 0, 6],
#        [1, 4, 8]]), 54: array([[0, 7, 3],
#        [5, 2, 6],
#        [1, 4, 8]]), 55: array([[7, 3, 0],
#        [5, 2, 6],
#        [1, 4, 8]]), 56: array([[7, 2, 0],
#        [5, 6, 3],
#        [1, 4, 8]]), 57: array([[7, 2, 3],
#        [5, 6, 8],
#        [1, 4, 0]]), 58: array([[7, 2, 3],
#        [5, 4, 6],
#        [0, 1, 8]]), 59: array([[7, 2, 3],
#        [5, 4, 6],
#        [1, 8, 0]]), 60: array([[2, 3, 0],
#        [7, 1, 6],
#        [4, 5, 8]]), 61: array([[2, 1, 3],
#        [7, 0, 6],
#        [4, 5, 8]]), 62: array([[7, 2, 3],
#        [4, 0, 6],
#        [5, 1, 8]]), 63: array([[7, 2, 3],
#        [4, 1, 6],
#        [5, 8, 0]]), 64: array([[1, 7, 3],
#        [2, 0, 6],
#        [4, 5, 8]]), 65: array([[1, 7, 3],
#        [4, 2, 6],
#        [0, 5, 8]]), 66: array([[7, 3, 6],
#        [1, 0, 2],
#        [4, 5, 8]]), 67: array([[7, 3, 6],
#        [1, 2, 8],
#        [4, 5, 0]]), 68: array([[0, 7, 2],
#        [1, 6, 3],
#        [4, 5, 8]]), 69: array([[7, 6, 2],
#        [1, 0, 3],
#        [4, 5, 8]]), 70: array([[7, 2, 3],
#        [1, 6, 8],
#        [0, 4, 5]]), 71: array([[7, 2, 3],
#        [1, 0, 8],
#        [4, 6, 5]]), 72: array([[2, 3, 0],
#        [7, 1, 5],
#        [4, 8, 6]]), 73: array([[2, 1, 3],
#        [7, 0, 5],
#        [4, 8, 6]]), 74: array([[7, 2, 3],
#        [4, 0, 5],
#        [8, 1, 6]]), 75: array([[7, 2, 3],
#        [4, 1, 5],
#        [8, 6, 0]]), 76: array([[1, 7, 3],
#        [2, 0, 5],
#        [4, 8, 6]]), 77: array([[1, 7, 3],
#        [4, 2, 5],
#        [0, 8, 6]]), 78: array([[7, 3, 5],
#        [1, 0, 2],
#        [4, 8, 6]]), 79: array([[7, 3, 5],
#        [1, 2, 6],
#        [4, 8, 0]]), 80: array([[0, 2, 3],
#        [7, 8, 5],
#        [1, 4, 6]]), 81: array([[7, 2, 3],
#        [8, 0, 5],
#        [1, 4, 6]]), 82: array([[7, 2, 0],
#        [1, 8, 3],
#        [4, 6, 5]]), 83: array([[1, 7, 2],
#        [5, 0, 3],
#        [4, 8, 6]]), 84: array([[1, 7, 2],
#        [4, 5, 3],
#        [0, 8, 6]]), 85: array([[0, 5, 2],
#        [7, 1, 3],
#        [4, 8, 6]]), 86: array([[7, 5, 2],
#        [4, 1, 3],
#        [0, 8, 6]]), 87: array([[7, 5, 0],
#        [1, 3, 2],
#        [4, 8, 6]]), 88: array([[7, 5, 2],
#        [1, 3, 6],
#        [4, 8, 0]]), 89: array([[7, 5, 2],
#        [1, 8, 3],
#        [0, 4, 6]]), 90: array([[7, 5, 2],
#        [1, 8, 3],
#        [4, 6, 0]]), 91: array([[2, 3, 6],
#        [7, 5, 0],
#        [1, 4, 8]]), 92: array([[2, 5, 3],
#        [0, 7, 6],
#        [1, 4, 8]]), 93: array([[2, 5, 3],
#        [7, 6, 0],
#        [1, 4, 8]]), 94: array([[2, 5, 3],
#        [7, 4, 6],
#        [1, 0, 8]]), 95: array([[5, 7, 3],
#        [0, 2, 6],
#        [1, 4, 8]]), 96: array([[7, 3, 6],
#        [5, 2, 0],
#        [1, 4, 8]]), 97: array([[7, 0, 2],
#        [5, 6, 3],
#        [1, 4, 8]]), 98: array([[7, 2, 3],
#        [5, 6, 8],
#        [1, 0, 4]]), 99: array([[7, 2, 3],
#        [0, 4, 6],
#        [5, 1, 8]]), 100: array([[7, 2, 3],
#        [5, 4, 0],
#        [1, 8, 6]]), 101: array([[2, 3, 6],
#        [7, 1, 0],
#        [4, 5, 8]]), 102: array([[2, 1, 3],
#        [0, 7, 6],
#        [4, 5, 8]]), 103: array([[2, 1, 3],
#        [7, 6, 0],
#        [4, 5, 8]]), 104: array([[2, 1, 3],
#        [7, 5, 6],
#        [4, 0, 8]]), 105: array([[7, 0, 3],
#        [4, 2, 6],
#        [5, 1, 8]]), 106: array([[7, 2, 3],
#        [4, 6, 0],
#        [5, 1, 8]]), 107: array([[7, 2, 3],
#        [4, 1, 0],
#        [5, 8, 6]]), 108: array([[1, 0, 3],
#        [2, 7, 6],
#        [4, 5, 8]]), 109: array([[1, 7, 3],
#        [2, 6, 0],
#        [4, 5, 8]]), 110: array([[1, 7, 3],
#        [2, 5, 6],
#        [4, 0, 8]]), 111: array([[1, 7, 3],
#        [4, 2, 6],
#        [5, 0, 8]]), 112: array([[7, 3, 6],
#        [0, 1, 2],
#        [4, 5, 8]]), 113: array([[7, 0, 6],
#        [1, 3, 2],
#        [4, 5, 8]]), 114: array([[7, 3, 6],
#        [1, 5, 2],
#        [4, 0, 8]]), 115: array([[7, 3, 6],
#        [1, 2, 8],
#        [4, 0, 5]]), 116: array([[1, 7, 2],
#        [0, 6, 3],
#        [4, 5, 8]]), 117: array([[7, 6, 2],
#        [0, 1, 3],
#        [4, 5, 8]]), 118: array([[7, 6, 2],
#        [1, 3, 0],
#        [4, 5, 8]]), 119: array([[7, 6, 2],
#        [1, 5, 3],
#        [4, 0, 8]]), 120: array([[7, 2, 3],
#        [0, 6, 8],
#        [1, 4, 5]]), 121: array([[7, 2, 3],
#        [0, 1, 8],
#        [4, 6, 5]]), 122: array([[7, 0, 3],
#        [1, 2, 8],
#        [4, 6, 5]]), 123: array([[2, 3, 5],
#        [7, 1, 0],
#        [4, 8, 6]]), 124: array([[2, 1, 3],
#        [0, 7, 5],
#        [4, 8, 6]]), 125: array([[2, 1, 3],
#        [7, 5, 0],
#        [4, 8, 6]]), 126: array([[2, 1, 3],
#        [7, 8, 5],
#        [4, 0, 6]]), 127: array([[7, 2, 3],
#        [0, 4, 5],
#        [8, 1, 6]]), 128: array([[7, 0, 3],
#        [4, 2, 5],
#        [8, 1, 6]]), 129: array([[7, 2, 3],
#        [4, 5, 0],
#        [8, 1, 6]]), 130: array([[7, 2, 3],
#        [4, 1, 0],
#        [8, 6, 5]]), 131: array([[1, 0, 3],
#        [2, 7, 5],
#        [4, 8, 6]]), 132: array([[1, 7, 3],
#        [2, 5, 0],
#        [4, 8, 6]]), 133: array([[1, 7, 3],
#        [2, 8, 5],
#        [4, 0, 6]]), 134: array([[1, 7, 3],
#        [4, 2, 5],
#        [8, 0, 6]]), 135: array([[7, 3, 5],
#        [0, 1, 2],
#        [4, 8, 6]]), 136: array([[7, 0, 5],
#        [1, 3, 2],
#        [4, 8, 6]]), 137: array([[7, 3, 5],
#        [1, 8, 2],
#        [4, 0, 6]]), 138: array([[7, 3, 5],
#        [1, 2, 6],
#        [4, 0, 8]]), 139: array([[2, 0, 3],
#        [7, 8, 5],
#        [1, 4, 6]]), 140: array([[7, 0, 3],
#        [8, 2, 5],
#        [1, 4, 6]]), 141: array([[7, 2, 3],
#        [8, 5, 0],
#        [1, 4, 6]]), 142: array([[7, 2, 3],
#        [8, 4, 5],
#        [1, 0, 6]]), 143: array([[7, 0, 2],
#        [1, 8, 3],
#        [4, 6, 5]]), 144: array([[1, 0, 2],
#        [5, 7, 3],
#        [4, 8, 6]]), 145: array([[1, 7, 2],
#        [5, 3, 0],
#        [4, 8, 6]]), 146: array([[1, 7, 2],
#        [5, 8, 3],
#        [4, 0, 6]]), 147: array([[1, 7, 2],
#        [4, 5, 3],
#        [8, 0, 6]]), 148: array([[5, 0, 2],
#        [7, 1, 3],
#        [4, 8, 6]]), 149: array([[7, 5, 2],
#        [4, 1, 3],
#        [8, 0, 6]]), 150: array([[7, 5, 2],
#        [1, 3, 6],
#        [4, 0, 8]]), 151: array([[7, 5, 2],
#        [0, 8, 3],
#        [1, 4, 6]]), 152: array([[7, 5, 2],
#        [1, 8, 0],
#        [4, 6, 3]]), 153: array([[2, 3, 6],
#        [7, 0, 5],
#        [1, 4, 8]]), 154: array([[2, 3, 6],
#        [7, 5, 8],
#        [1, 4, 0]]), 155: array([[0, 5, 3],
#        [2, 7, 6],
#        [1, 4, 8]]), 156: array([[2, 5, 3],
#        [1, 7, 6],
#        [0, 4, 8]]), 157: array([[2, 5, 0],
#        [7, 6, 3],
#        [1, 4, 8]]), 158: array([[2, 5, 3],
#        [7, 6, 8],
#        [1, 4, 0]]), 159: array([[2, 5, 3],
#        [7, 4, 6],
#        [0, 1, 8]]), 160: array([[2, 5, 3],
#        [7, 4, 6],
#        [1, 8, 0]]), 161: array([[5, 7, 3],
#        [2, 0, 6],
#        [1, 4, 8]]), 162: array([[5, 7, 3],
#        [1, 2, 6],
#        [0, 4, 8]]), 163: array([[7, 3, 6],
#        [5, 0, 2],
#        [1, 4, 8]]), 164: array([[7, 3, 6],
#        [5, 2, 8],
#        [1, 4, 0]]), 165: array([[0, 7, 2],
#        [5, 6, 3],
#        [1, 4, 8]]), 166: array([[7, 6, 2],
#        [5, 0, 3],
#        [1, 4, 8]]), 167: array([[7, 2, 3],
#        [5, 6, 8],
#        [0, 1, 4]]), 168: array([[7, 2, 3],
#        [5, 0, 8],
#        [1, 6, 4]]), 169: array([[0, 2, 3],
#        [7, 4, 6],
#        [5, 1, 8]]), 170: array([[7, 2, 3],
#        [5, 0, 4],
#        [1, 8, 6]]), 171: array([[7, 2, 0],
#        [5, 4, 3],
#        [1, 8, 6]]), 172: array([[2, 3, 6],
#        [7, 0, 1],
#        [4, 5, 8]]), 173: array([[2, 3, 6],
#        [7, 1, 8],
#        [4, 5, 0]]), 174: array([[0, 1, 3],
#        [2, 7, 6],
#        [4, 5, 8]]), 175: array([[2, 1, 3],
#        [4, 7, 6],
#        [0, 5, 8]]), 176: array([[2, 1, 0],
#        [7, 6, 3],
#        [4, 5, 8]]), 177: array([[2, 1, 3],
#        [7, 6, 8],
#        [4, 5, 0]]), 178: array([[2, 1, 3],
#        [7, 5, 6],
#        [0, 4, 8]]), 179: array([[2, 1, 3],
#        [7, 5, 6],
#        [4, 8, 0]]), 180: array([[0, 7, 3],
#        [4, 2, 6],
#        [5, 1, 8]]), 181: array([[7, 3, 0],
#        [4, 2, 6],
#        [5, 1, 8]]), 182: array([[7, 2, 0],
#        [4, 6, 3],
#        [5, 1, 8]]), 183: array([[7, 2, 3],
#        [4, 6, 8],
#        [5, 1, 0]]), 184: array([[7, 2, 3],
#        [4, 0, 1],
#        [5, 8, 6]]), 185: array([[7, 2, 0],
#        [4, 1, 3],
#        [5, 8, 6]]), 186: array([[1, 3, 0],
#        [2, 7, 6],
#        [4, 5, 8]]), 187: array([[1, 7, 0],
#        [2, 6, 3],
#        [4, 5, 8]]), 188: array([[1, 7, 3],
#        [2, 6, 8],
#        [4, 5, 0]]), 189: array([[1, 7, 3],
#        [2, 5, 6],
#        [0, 4, 8]]), 190: array([[1, 7, 3],
#        [2, 5, 6],
#        [4, 8, 0]]), 191: array([[1, 7, 3],
#        [4, 0, 6],
#        [5, 2, 8]]), 192: array([[1, 7, 3],
#        [4, 2, 6],
#        [5, 8, 0]]), 193: array([[0, 3, 6],
#        [7, 1, 2],
#        [4, 5, 8]]), 194: array([[7, 3, 6],
#        [4, 1, 2],
#        [0, 5, 8]]), 195: array([[0, 7, 6],
#        [1, 3, 2],
#        [4, 5, 8]]), 196: array([[7, 6, 0],
#        [1, 3, 2],
#        [4, 5, 8]]), 197: array([[7, 3, 6],
#        [1, 5, 2],
#        [0, 4, 8]]), 198: array([[7, 3, 6],
#        [1, 5, 2],
#        [4, 8, 0]]), 199: array([[7, 3, 6],
#        [1, 2, 8],
#        [0, 4, 5]]), 200: array([[7, 3, 6],
#        [1, 0, 8],
#        [4, 2, 5]]), 201: array([[1, 7, 2],
#        [6, 0, 3],
#        [4, 5, 8]]), 202: array([[1, 7, 2],
#        [4, 6, 3],
#        [0, 5, 8]]), 203: array([[0, 6, 2],
#        [7, 1, 3],
#        [4, 5, 8]]), 204: array([[7, 6, 2],
#        [4, 1, 3],
#        [0, 5, 8]]), 205: array([[7, 6, 2],
#        [1, 3, 8],
#        [4, 5, 0]]), 206: array([[7, 6, 2],
#        [1, 5, 3],
#        [0, 4, 8]]), 207: array([[7, 6, 2],
#        [1, 5, 3],
#        [4, 8, 0]]), 208: array([[0, 2, 3],
#        [7, 6, 8],
#        [1, 4, 5]]), 209: array([[7, 2, 3],
#        [6, 0, 8],
#        [1, 4, 5]]), 210: array([[0, 2, 3],
#        [7, 1, 8],
#        [4, 6, 5]]), 211: array([[7, 2, 3],
#        [4, 1, 8],
#        [0, 6, 5]]), 212: array([[0, 7, 3],
#        [1, 2, 8],
#        [4, 6, 5]]), 213: array([[7, 3, 0],
#        [1, 2, 8],
#        [4, 6, 5]]), 214: array([[2, 3, 5],
#        [7, 0, 1],
#        [4, 8, 6]]), 215: array([[2, 3, 5],
#        [7, 1, 6],
#        [4, 8, 0]]), 216: array([[0, 1, 3],
#        [2, 7, 5],
#        [4, 8, 6]]), 217: array([[2, 1, 3],
#        [4, 7, 5],
#        [0, 8, 6]]), 218: array([[2, 1, 0],
#        [7, 5, 3],
#        [4, 8, 6]]), 219: array([[2, 1, 3],
#        [7, 8, 5],
#        [0, 4, 6]]), 220: array([[2, 1, 3],
#        [7, 8, 5],
#        [4, 6, 0]]), 221: array([[0, 2, 3],
#        [7, 4, 5],
#        [8, 1, 6]]), 222: array([[7, 2, 3],
#        [8, 4, 5],
#        [0, 1, 6]]), 223: array([[0, 7, 3],
#        [4, 2, 5],
#        [8, 1, 6]]), 224: array([[7, 3, 0],
#        [4, 2, 5],
#        [8, 1, 6]]), 225: array([[7, 2, 0],
#        [4, 5, 3],
#        [8, 1, 6]]), 226: array([[7, 2, 3],
#        [4, 5, 6],
#        [8, 1, 0]]), 227: array([[7, 2, 3],
#        [4, 0, 1],
#        [8, 6, 5]]), 228: array([[7, 2, 0],
#        [4, 1, 3],
#        [8, 6, 5]]), 229: array([[1, 3, 0],
#        [2, 7, 5],
#        [4, 8, 6]]), 230: array([[1, 7, 0],
#        [2, 5, 3],
#        [4, 8, 6]]), 231: array([[1, 7, 3],
#        [2, 8, 5],
#        [0, 4, 6]]), 232: array([[1, 7, 3],
#        [2, 8, 5],
#        [4, 6, 0]]), 233: array([[1, 7, 3],
#        [4, 0, 5],
#        [8, 2, 6]]), 234: array([[1, 7, 3],
#        [4, 2, 5],
#        [8, 6, 0]]), 235: array([[0, 3, 5],
#        [7, 1, 2],
#        [4, 8, 6]]), 236: array([[7, 3, 5],
#        [4, 1, 2],
#        [0, 8, 6]]), 237: array([[0, 7, 5],
#        [1, 3, 2],
#        [4, 8, 6]]), 238: array([[7, 3, 5],
#        [1, 8, 2],
#        [0, 4, 6]]), 239: array([[7, 3, 5],
#        [1, 8, 2],
#        [4, 6, 0]]), 240: array([[7, 3, 5],
#        [1, 2, 6],
#        [0, 4, 8]]), 241: array([[7, 3, 5],
#        [1, 0, 6],
#        [4, 2, 8]]), 242: array([[2, 3, 0],
#        [7, 8, 5],
#        [1, 4, 6]]), 243: array([[2, 8, 3],
#        [7, 0, 5],
#        [1, 4, 6]]), 244: array([[0, 7, 3],
#        [8, 2, 5],
#        [1, 4, 6]]), 245: array([[7, 3, 0],
#        [8, 2, 5],
#        [1, 4, 6]]), 246: array([[7, 2, 0],
#        [8, 5, 3],
#        [1, 4, 6]]), 247: array([[7, 2, 3],
#        [8, 5, 6],
#        [1, 4, 0]]), 248: array([[7, 2, 3],
#        [8, 4, 5],
#        [1, 6, 0]]), 249: array([[0, 7, 2],
#        [1, 8, 3],
#        [4, 6, 5]]), 250: array([[7, 8, 2],
#        [1, 0, 3],
#        [4, 6, 5]]), 251: array([[0, 1, 2],
#        [5, 7, 3],
#        [4, 8, 6]]), 252: array([[1, 2, 0],
#        [5, 7, 3],
#        [4, 8, 6]]), 253: array([[1, 7, 0],
#        [5, 3, 2],
#        [4, 8, 6]]), 254: array([[1, 7, 2],
#        [5, 3, 6],
#        [4, 8, 0]]), 255: array([[1, 7, 2],
#        [5, 8, 3],
#        [0, 4, 6]]), 256: array([[1, 7, 2],
#        [5, 8, 3],
#        [4, 6, 0]]), 257: array([[1, 7, 2],
#        [4, 0, 3],
#        [8, 5, 6]]), 258: array([[1, 7, 2],
#        [4, 5, 3],
#        [8, 6, 0]]), 259: array([[5, 2, 0],
#        [7, 1, 3],
#        [4, 8, 6]]), 260: array([[5, 1, 2],
#        [7, 0, 3],
#        [4, 8, 6]]), 261: array([[7, 5, 2],
#        [4, 0, 3],
#        [8, 1, 6]]), 262: array([[7, 5, 2],
#        [4, 1, 3],
#        [8, 6, 0]]), 263: array([[7, 5, 2],
#        [1, 3, 6],
#        [0, 4, 8]]), 264: array([[7, 5, 2],
#        [1, 0, 6],
#        [4, 3, 8]]), 265: array([[0, 5, 2],
#        [7, 8, 3],
#        [1, 4, 6]]), 266: array([[7, 5, 2],
#        [8, 0, 3],
#        [1, 4, 6]]), 267: array([[7, 5, 2],
#        [1, 0, 8],
#        [4, 6, 3]]), 268: array([[7, 5, 0],
#        [1, 8, 2],
#        [4, 6, 3]]), 269: array([[2, 3, 6],
#        [0, 7, 5],
#        [1, 4, 8]]), 270: array([[2, 0, 6],
#        [7, 3, 5],
#        [1, 4, 8]]), 271: array([[2, 3, 6],
#        [7, 4, 5],
#        [1, 0, 8]]), 272: array([[2, 3, 6],
#        [7, 5, 8],
#        [1, 0, 4]]), 273: array([[5, 0, 3],
#        [2, 7, 6],
#        [1, 4, 8]]), 274: array([[2, 5, 3],
#        [1, 7, 6],
#        [4, 0, 8]]), 275: array([[2, 0, 5],
#        [7, 6, 3],
#        [1, 4, 8]]), 276: array([[2, 5, 3],
#        [7, 6, 8],
#        [1, 0, 4]]), 277: array([[2, 5, 3],
#        [0, 4, 6],
#        [7, 1, 8]]), 278: array([[2, 5, 3],
#        [7, 4, 0],
#        [1, 8, 6]]), 279: array([[5, 7, 3],
#        [2, 6, 0],
#        [1, 4, 8]]), 280: array([[5, 7, 3],
#        [2, 4, 6],
#        [1, 0, 8]]), 281: array([[5, 7, 3],
#        [1, 2, 6],
#        [4, 0, 8]]), 282: array([[7, 3, 6],
#        [0, 5, 2],
#        [1, 4, 8]]), 283: array([[7, 0, 6],
#        [5, 3, 2],
#        [1, 4, 8]]), 284: array([[7, 3, 6],
#        [5, 4, 2],
#        [1, 0, 8]]), 285: array([[7, 3, 6],
#        [5, 2, 8],
#        [1, 0, 4]]), 286: array([[5, 7, 2],
#        [0, 6, 3],
#        [1, 4, 8]]), 287: array([[7, 6, 2],
#        [0, 5, 3],
#        [1, 4, 8]]), 288: array([[7, 6, 2],
#        [5, 3, 0],
#        [1, 4, 8]]), 289: array([[7, 6, 2],
#        [5, 4, 3],
#        [1, 0, 8]]), 290: array([[7, 2, 3],
#        [0, 6, 8],
#        [5, 1, 4]]), 291: array([[7, 2, 3],
#        [0, 5, 8],
#        [1, 6, 4]]), 292: array([[7, 0, 3],
#        [5, 2, 8],
#        [1, 6, 4]]), 293: array([[7, 2, 3],
#        [5, 8, 0],
#        [1, 6, 4]]), 294: array([[2, 0, 3],
#        [7, 4, 6],
#        [5, 1, 8]]), 295: array([[7, 2, 3],
#        [0, 5, 4],
#        [1, 8, 6]]), 296: array([[7, 0, 3],
#        [5, 2, 4],
#        [1, 8, 6]]), 297: array([[7, 2, 3],
#        [5, 8, 4],
#        [1, 0, 6]]), 298: array([[7, 0, 2],
#        [5, 4, 3],
#        [1, 8, 6]]), 299: array([[2, 3, 6],
#        [0, 7, 1],
#        [4, 5, 8]]), 300: array([[2, 0, 6],
#        [7, 3, 1],
#        [4, 5, 8]]), 301: array([[2, 3, 6],
#        [7, 5, 1],
#        [4, 0, 8]]), 302: array([[2, 3, 6],
#        [7, 1, 8],
#        [4, 0, 5]]), 303: array([[2, 1, 3],
#        [4, 7, 6],
#        [5, 0, 8]]), 304: array([[2, 0, 1],
#        [7, 6, 3],
#        [4, 5, 8]]), 305: array([[2, 1, 3],
#        [7, 6, 8],
#        [4, 0, 5]]), 306: array([[2, 1, 3],
#        [0, 5, 6],
#        [7, 4, 8]]), 307: array([[4, 7, 3],
#        [0, 2, 6],
#        [5, 1, 8]]), 308: array([[7, 3, 6],
#        [4, 2, 0],
#        [5, 1, 8]]), 309: array([[7, 0, 2],
#        [4, 6, 3],
#        [5, 1, 8]]), 310: array([[7, 2, 3],
#        [4, 6, 8],
#        [5, 0, 1]]), 311: array([[7, 2, 3],
#        [0, 4, 1],
#        [5, 8, 6]]), 312: array([[7, 0, 3],
#        [4, 2, 1],
#        [5, 8, 6]]), 313: array([[7, 2, 3],
#        [4, 8, 1],
#        [5, 0, 6]]), 314: array([[7, 0, 2],
#        [4, 1, 3],
#        [5, 8, 6]]), 315: array([[1, 3, 6],
#        [2, 7, 0],
#        [4, 5, 8]]), 316: array([[1, 0, 7],
#        [2, 6, 3],
#        [4, 5, 8]]), 317: array([[1, 7, 3],
#        [2, 6, 8],
#        [4, 0, 5]]), 318: array([[1, 7, 3],
#        [0, 5, 6],
#        [2, 4, 8]]), 319: array([[1, 7, 3],
#        [0, 4, 6],
#        [5, 2, 8]]), 320: array([[1, 0, 3],
#        [4, 7, 6],
#        [5, 2, 8]]), 321: array([[1, 7, 3],
#        [4, 6, 0],
#        [5, 2, 8]]), 322: array([[1, 7, 3],
#        [4, 2, 0],
#        [5, 8, 6]]), 323: array([[3, 0, 6],
#        [7, 1, 2],
#        [4, 5, 8]]), 324: array([[7, 3, 6],
#        [4, 1, 2],
#        [5, 0, 8]]), 325: array([[1, 7, 6],
#        [0, 3, 2],
#        [4, 5, 8]]), 326: array([[7, 3, 6],
#        [1, 5, 0],
#        [4, 8, 2]]), 327: array([[7, 3, 6],
#        [0, 2, 8],
#        [1, 4, 5]]), 328: array([[7, 3, 6],
#        [0, 1, 8],
#        [4, 2, 5]]), 329: array([[7, 0, 6],
#        [1, 3, 8],
#        [4, 2, 5]]), 330: array([[7, 3, 6],
#        [1, 8, 0],
#        [4, 2, 5]]), 331: array([[1, 0, 2],
#        [6, 7, 3],
#        [4, 5, 8]]), 332: array([[1, 7, 2],
#        [6, 3, 0],
#        [4, 5, 8]]), 333: array([[1, 7, 2],
#        [6, 5, 3],
#        [4, 0, 8]]), 334: array([[1, 7, 2],
#        [4, 6, 3],
#        [5, 0, 8]]), 335: array([[6, 0, 2],
#        [7, 1, 3],
#        [4, 5, 8]]), 336: array([[7, 6, 2],
#        [4, 1, 3],
#        [5, 0, 8]]), 337: array([[7, 6, 2],
#        [1, 3, 8],
#        [4, 0, 5]]), 338: array([[7, 6, 2],
#        [1, 5, 0],
#        [4, 8, 3]]), 339: array([[2, 0, 3],
#        [7, 6, 8],
#        [1, 4, 5]]), 340: array([[7, 0, 3],
#        [6, 2, 8],
#        [1, 4, 5]]), 341: array([[7, 2, 3],
#        [6, 8, 0],
#        [1, 4, 5]]), 342: array([[7, 2, 3],
#        [6, 4, 8],
#        [1, 0, 5]]), 343: array([[2, 0, 3],
#        [7, 1, 8],
#        [4, 6, 5]]), 344: array([[7, 2, 3],
#        [4, 1, 8],
#        [6, 0, 5]]), 345: array([[1, 7, 3],
#        [0, 2, 8],
#        [4, 6, 5]]), 346: array([[7, 3, 8],
#        [1, 2, 0],
#        [4, 6, 5]]), 347: array([[2, 3, 5],
#        [0, 7, 1],
#        [4, 8, 6]]), 348: array([[2, 0, 5],
#        [7, 3, 1],
#        [4, 8, 6]]), 349: array([[2, 3, 5],
#        [7, 8, 1],
#        [4, 0, 6]]), 350: array([[2, 3, 5],
#        [7, 1, 6],
#        [4, 0, 8]]), 351: array([[2, 1, 3],
#        [4, 7, 5],
#        [8, 0, 6]]), 352: array([[2, 0, 1],
#        [7, 5, 3],
#        [4, 8, 6]]), 353: array([[2, 1, 3],
#        [0, 8, 5],
#        [7, 4, 6]]), 354: array([[2, 1, 3],
#        [7, 8, 0],
#        [4, 6, 5]]), 355: array([[2, 0, 3],
#        [7, 4, 5],
#        [8, 1, 6]]), 356: array([[4, 7, 3],
#        [0, 2, 5],
#        [8, 1, 6]]), 357: array([[7, 3, 5],
#        [4, 2, 0],
#        [8, 1, 6]]), 358: array([[7, 0, 2],
#        [4, 5, 3],
#        [8, 1, 6]]), 359: array([[7, 2, 3],
#        [4, 5, 6],
#        [8, 0, 1]]), 360: array([[7, 2, 3],
#        [0, 4, 1],
#        [8, 6, 5]]), 361: array([[7, 0, 3],
#        [4, 2, 1],
#        [8, 6, 5]]), 362: array([[7, 2, 3],
#        [4, 6, 1],
#        [8, 0, 5]]), 363: array([[7, 0, 2],
#        [4, 1, 3],
#        [8, 6, 5]]), 364: array([[1, 3, 5],
#        [2, 7, 0],
#        [4, 8, 6]]), 365: array([[1, 0, 7],
#        [2, 5, 3],
#        [4, 8, 6]]), 366: array([[1, 7, 3],
#        [0, 8, 5],
#        [2, 4, 6]]), 367: array([[1, 7, 3],
#        [2, 8, 0],
#        [4, 6, 5]]), 368: array([[1, 7, 3],
#        [0, 4, 5],
#        [8, 2, 6]]), 369: array([[1, 0, 3],
#        [4, 7, 5],
#        [8, 2, 6]]), 370: array([[1, 7, 3],
#        [4, 5, 0],
#        [8, 2, 6]]), 371: array([[1, 7, 3],
#        [4, 2, 0],
#        [8, 6, 5]]), 372: array([[3, 0, 5],
#        [7, 1, 2],
#        [4, 8, 6]]), 373: array([[7, 3, 5],
#        [4, 1, 2],
#        [8, 0, 6]]), 374: array([[1, 7, 5],
#        [0, 3, 2],
#        [4, 8, 6]]), 375: array([[7, 3, 5],
#        [0, 8, 2],
#        [1, 4, 6]]), 376: array([[7, 3, 5],
#        [1, 8, 0],
#        [4, 6, 2]]), 377: array([[7, 3, 5],
#        [0, 2, 6],
#        [1, 4, 8]]), 378: array([[7, 3, 5],
#        [0, 1, 6],
#        [4, 2, 8]]), 379: array([[7, 0, 5],
#        [1, 3, 6],
#        [4, 2, 8]]), 380: array([[7, 3, 5],
#        [1, 6, 0],
#        [4, 2, 8]]), 381: array([[2, 3, 5],
#        [7, 8, 0],
#        [1, 4, 6]]), 382: array([[2, 8, 3],
#        [0, 7, 5],
#        [1, 4, 6]]), 383: array([[2, 8, 3],
#        [7, 5, 0],
#        [1, 4, 6]]), 384: array([[2, 8, 3],
#        [7, 4, 5],
#        [1, 0, 6]]), 385: array([[8, 7, 3],
#        [0, 2, 5],
#        [1, 4, 6]]), 386: array([[7, 3, 5],
#        [8, 2, 0],
#        [1, 4, 6]]), 387: array([[7, 0, 2],
#        [8, 5, 3],
#        [1, 4, 6]]), 388: array([[7, 2, 3],
#        [8, 5, 6],
#        [1, 0, 4]]), 389: array([[7, 2, 3],
#        [8, 4, 0],
#        [1, 6, 5]]), 390: array([[1, 7, 2],
#        [0, 8, 3],
#        [4, 6, 5]]), 391: array([[7, 8, 2],
#        [0, 1, 3],
#        [4, 6, 5]]), 392: array([[7, 8, 2],
#        [1, 3, 0],
#        [4, 6, 5]]), 393: array([[7, 8, 2],
#        [1, 6, 3],
#        [4, 0, 5]]), 394: array([[5, 1, 2],
#        [0, 7, 3],
#        [4, 8, 6]]), 395: array([[1, 2, 3],
#        [5, 7, 0],
#        [4, 8, 6]]), 396: array([[1, 0, 7],
#        [5, 3, 2],
#        [4, 8, 6]]), 397: array([[1, 7, 2],
#        [5, 3, 6],
#        [4, 0, 8]]), 398: array([[1, 7, 2],
#        [0, 8, 3],
#        [5, 4, 6]]), 399: array([[1, 7, 2],
#        [5, 8, 0],
#        [4, 6, 3]]), 400: array([[1, 7, 2],
#        [0, 4, 3],
#        [8, 5, 6]]), 401: array([[1, 0, 2],
#        [4, 7, 3],
#        [8, 5, 6]]), 402: array([[1, 7, 2],
#        [4, 3, 0],
#        [8, 5, 6]]), 403: array([[1, 7, 2],
#        [4, 5, 0],
#        [8, 6, 3]]), 404: array([[5, 2, 3],
#        [7, 1, 0],
#        [4, 8, 6]]), 405: array([[5, 1, 2],
#        [7, 3, 0],
#        [4, 8, 6]]), 406: array([[5, 1, 2],
#        [7, 8, 3],
#        [4, 0, 6]]), 407: array([[7, 5, 2],
#        [0, 4, 3],
#        [8, 1, 6]]), 408: array([[7, 5, 2],
#        [4, 3, 0],
#        [8, 1, 6]]), 409: array([[7, 5, 2],
#        [4, 1, 0],
#        [8, 6, 3]]), 410: array([[7, 5, 2],
#        [0, 3, 6],
#        [1, 4, 8]]), 411: array([[7, 5, 2],
#        [0, 1, 6],
#        [4, 3, 8]]), 412: array([[7, 0, 2],
#        [1, 5, 6],
#        [4, 3, 8]]), 413: array([[7, 5, 2],
#        [1, 6, 0],
#        [4, 3, 8]]), 414: array([[5, 0, 2],
#        [7, 8, 3],
#        [1, 4, 6]]), 415: array([[7, 5, 2],
#        [8, 3, 0],
#        [1, 4, 6]]), 416: array([[7, 5, 2],
#        [8, 4, 3],
#        [1, 0, 6]]), 417: array([[7, 5, 2],
#        [0, 1, 8],
#        [4, 6, 3]]), 418: array([[7, 0, 2],
#        [1, 5, 8],
#        [4, 6, 3]]), 419: array([[7, 5, 2],
#        [1, 6, 8],
#        [4, 0, 3]]), 420: array([[7, 0, 5],
#        [1, 8, 2],
#        [4, 6, 3]]), 421: array([[0, 3, 6],
#        [2, 7, 5],
#        [1, 4, 8]]), 422: array([[2, 3, 6],
#        [1, 7, 5],
#        [0, 4, 8]]), 423: array([[0, 2, 6],
#        [7, 3, 5],
#        [1, 4, 8]]), 424: array([[2, 6, 0],
#        [7, 3, 5],
#        [1, 4, 8]]), 425: array([[2, 3, 6],
#        [7, 4, 5],
#        [0, 1, 8]]), 426: array([[2, 3, 6],
#        [7, 4, 5],
#        [1, 8, 0]]), 427: array([[2, 3, 6],
#        [7, 5, 8],
#        [0, 1, 4]]), 428: array([[2, 3, 6],
#        [7, 0, 8],
#        [1, 5, 4]]), 429: array([[5, 3, 0],
#        [2, 7, 6],
#        [1, 4, 8]]), 430: array([[2, 5, 3],
#        [1, 0, 6],
#        [4, 7, 8]]), 431: array([[2, 5, 3],
#        [1, 7, 6],
#        [4, 8, 0]]), 432: array([[0, 2, 5],
#        [7, 6, 3],
#        [1, 4, 8]]), 433: array([[2, 6, 5],
#        [7, 0, 3],
#        [1, 4, 8]]), 434: array([[2, 5, 3],
#        [7, 6, 8],
#        [0, 1, 4]]), 435: array([[2, 5, 3],
#        [7, 0, 8],
#        [1, 6, 4]]), 436: array([[0, 5, 3],
#        [2, 4, 6],
#        [7, 1, 8]]), 437: array([[2, 5, 3],
#        [4, 0, 6],
#        [7, 1, 8]]), 438: array([[2, 5, 3],
#        [7, 0, 4],
#        [1, 8, 6]]), 439: array([[2, 5, 0],
#        [7, 4, 3],
#        [1, 8, 6]]), 440: array([[5, 7, 0],
#        [2, 6, 3],
#        [1, 4, 8]]), 441: array([[5, 7, 3],
#        [2, 6, 8],
#        [1, 4, 0]]), 442: array([[5, 7, 3],
#        [2, 4, 6],
#        [0, 1, 8]]), 443: array([[5, 7, 3],
#        [2, 4, 6],
#        [1, 8, 0]]), 444: array([[5, 7, 3],
#        [1, 0, 6],
#        [4, 2, 8]]), 445: array([[5, 7, 3],
#        [1, 2, 6],
#        [4, 8, 0]]), 446: array([[0, 3, 6],
#        [7, 5, 2],
#        [1, 4, 8]]), 447: array([[0, 7, 6],
#        [5, 3, 2],
#        [1, 4, 8]]), 448: array([[7, 6, 0],
#        [5, 3, 2],
#        [1, 4, 8]]), 449: array([[7, 3, 6],
#        [5, 4, 2],
#        [0, 1, 8]]), 450: array([[7, 3, 6],
#        [5, 4, 2],
#        [1, 8, 0]]), 451: array([[7, 3, 6],
#        [5, 2, 8],
#        [0, 1, 4]]), 452: array([[7, 3, 6],
#        [5, 0, 8],
#        [1, 2, 4]]), 453: array([[5, 7, 2],
#        [6, 0, 3],
#        [1, 4, 8]]), 454: array([[5, 7, 2],
#        [1, 6, 3],
#        [0, 4, 8]]), 455: array([[0, 6, 2],
#        [7, 5, 3],
#        [1, 4, 8]]), 456: array([[7, 6, 2],
#        [5, 3, 8],
#        [1, 4, 0]]), 457: array([[7, 6, 2],
#        [5, 4, 3],
#        [0, 1, 8]]), 458: array([[7, 6, 2],
#        [5, 4, 3],
#        [1, 8, 0]]), 459: array([[0, 2, 3],
#        [7, 6, 8],
#        [5, 1, 4]]), 460: array([[7, 2, 3],
#        [6, 0, 8],
#        [5, 1, 4]]), 461: array([[0, 2, 3],
#        [7, 5, 8],
#        [1, 6, 4]]), 462: array([[7, 2, 3],
#        [1, 5, 8],
#        [0, 6, 4]]), 463: array([[0, 7, 3],
#        [5, 2, 8],
#        [1, 6, 4]]), 464: array([[7, 3, 0],
#        [5, 2, 8],
#        [1, 6, 4]]), 465: array([[7, 2, 0],
#        [5, 8, 3],
#        [1, 6, 4]]), 466: array([[7, 2, 3],
#        [5, 8, 4],
#        [1, 6, 0]]), 467: array([[2, 3, 0],
#        [7, 4, 6],
#        [5, 1, 8]]), 468: array([[2, 4, 3],
#        [7, 0, 6],
#        [5, 1, 8]]), 469: array([[0, 2, 3],
#        [7, 5, 4],
#        [1, 8, 6]]), 470: array([[7, 2, 3],
#        [1, 5, 4],
#        [0, 8, 6]]), 471: array([[0, 7, 3],
#        [5, 2, 4],
#        [1, 8, 6]]), 472: array([[7, 3, 0],
#        [5, 2, 4],
#        [1, 8, 6]]), 473: array([[7, 2, 3],
#        [5, 8, 4],
#        [0, 1, 6]]), 474: array([[0, 7, 2],
#        [5, 4, 3],
#        [1, 8, 6]]), 475: array([[7, 4, 2],
#        [5, 0, 3],
#        [1, 8, 6]]), 476: array([[0, 3, 6],
#        [2, 7, 1],
#        [4, 5, 8]]), 477: array([[2, 3, 6],
#        [4, 7, 1],
#        [0, 5, 8]]), 478: array([[0, 2, 6],
#        [7, 3, 1],
#        [4, 5, 8]]), 479: array([[2, 6, 0],
#        [7, 3, 1],
#        [4, 5, 8]]), 480: array([[2, 3, 6],
#        [7, 5, 1],
#        [0, 4, 8]]), 481: array([[2, 3, 6],
#        [7, 5, 1],
#        [4, 8, 0]]), 482: array([[2, 3, 6],
#        [7, 1, 8],
#        [0, 4, 5]]), 483: array([[2, 3, 6],
#        [7, 0, 8],
#        [4, 1, 5]]), 484: array([[2, 1, 3],
#        [4, 0, 6],
#        [5, 7, 8]]), 485: array([[2, 1, 3],
#        [4, 7, 6],
#        [5, 8, 0]]), 486: array([[0, 2, 1],
#        [7, 6, 3],
#        [4, 5, 8]]), 487: array([[2, 6, 1],
#        [7, 0, 3],
#        [4, 5, 8]]), 488: array([[2, 1, 3],
#        [7, 6, 8],
#        [0, 4, 5]]), 489: array([[2, 1, 3],
#        [7, 0, 8],
#        [4, 6, 5]]), 490: array([[0, 1, 3],
#        [2, 5, 6],
#        [7, 4, 8]]), 491: array([[2, 1, 3],
#        [5, 0, 6],
#        [7, 4, 8]]), 492: array([[4, 7, 3],
#        [2, 0, 6],
#        [5, 1, 8]]), 493: array([[4, 7, 3],
#        [5, 2, 6],
#        [0, 1, 8]]), 494: array([[7, 3, 6],
#        [4, 0, 2],
#        [5, 1, 8]]), 495: array([[7, 3, 6],
#        [4, 2, 8],
#        [5, 1, 0]]), 496: array([[0, 7, 2],
#        [4, 6, 3],
#        [5, 1, 8]]), 497: array([[7, 6, 2],
#        [4, 0, 3],
#        [5, 1, 8]]), 498: array([[7, 2, 3],
#        [4, 6, 8],
#        [0, 5, 1]]), 499: array([[7, 2, 3],
#        [4, 0, 8],
#        [5, 6, 1]]), 500: array([[0, 2, 3],
#        [7, 4, 1],
#        [5, 8, 6]]), 501: array([[7, 2, 3],
#        [5, 4, 1],
#        [0, 8, 6]]), 502: array([[0, 7, 3],
#        [4, 2, 1],
#        [5, 8, 6]]), 503: array([[7, 3, 0],
#        [4, 2, 1],
#        [5, 8, 6]]), 504: array([[7, 2, 3],
#        [4, 8, 1],
#        [0, 5, 6]]), 505: array([[7, 2, 3],
#        [4, 8, 1],
#        [5, 6, 0]]), 506: array([[0, 7, 2],
#        [4, 1, 3],
#        [5, 8, 6]]), 507: array([[7, 1, 2],
#        [4, 0, 3],
#        [5, 8, 6]]), 508: array([[1, 3, 6],
#        [2, 0, 7],
#        [4, 5, 8]]), 509: array([[1, 3, 6],
#        [2, 7, 8],
#        [4, 5, 0]]), 510: array([[0, 1, 7],
#        [2, 6, 3],
#        [4, 5, 8]]), 511: array([[1, 6, 7],
#        [2, 0, 3],
#        [4, 5, 8]]), 512: array([[1, 7, 3],
#        [2, 6, 8],
#        [0, 4, 5]]), 513: array([[1, 7, 3],
#        [2, 0, 8],
#        [4, 6, 5]]), 514: array([[0, 7, 3],
#        [1, 5, 6],
#        [2, 4, 8]]), 515: array([[1, 7, 3],
#        [5, 0, 6],
#        [2, 4, 8]]), 516: array([[0, 7, 3],
#        [1, 4, 6],
#        [5, 2, 8]]), 517: array([[1, 7, 3],
#        [5, 4, 6],
#        [0, 2, 8]]), 518: array([[0, 1, 3],
#        [4, 7, 6],
#        [5, 2, 8]]), 519: array([[1, 3, 0],
#        [4, 7, 6],
#        [5, 2, 8]]), 520: array([[1, 7, 0],
#        [4, 6, 3],
#        [5, 2, 8]]), 521: array([[1, 7, 3],
#        [4, 6, 8],
#        [5, 2, 0]]), 522: array([[1, 7, 3],
#        [4, 0, 2],
#        [5, 8, 6]]), 523: array([[1, 7, 0],
#        [4, 2, 3],
#        [5, 8, 6]]), 524: array([[3, 6, 0],
#        [7, 1, 2],
#        [4, 5, 8]]), 525: array([[3, 1, 6],
#        [7, 0, 2],
#        [4, 5, 8]]), 526: array([[7, 3, 6],
#        [4, 1, 2],
#        [5, 8, 0]]), 527: array([[1, 7, 6],
#        [3, 0, 2],
#        [4, 5, 8]]), 528: array([[1, 7, 6],
#        [4, 3, 2],
#        [0, 5, 8]]), 529: array([[7, 3, 6],
#        [1, 0, 5],
#        [4, 8, 2]]), 530: array([[7, 3, 0],
#        [1, 5, 6],
#        [4, 8, 2]]), 531: array([[0, 3, 6],
#        [7, 2, 8],
#        [1, 4, 5]]), 532: array([[7, 3, 6],
#        [2, 0, 8],
#        [1, 4, 5]]), 533: array([[0, 3, 6],
#        [7, 1, 8],
#        [4, 2, 5]]), 534: array([[7, 3, 6],
#        [4, 1, 8],
#        [0, 2, 5]]), 535: array([[0, 7, 6],
#        [1, 3, 8],
#        [4, 2, 5]]), 536: array([[7, 6, 0],
#        [1, 3, 8],
#        [4, 2, 5]]), 537: array([[7, 3, 0],
#        [1, 8, 6],
#        [4, 2, 5]]), 538: array([[7, 3, 6],
#        [1, 8, 5],
#        [4, 2, 0]]), 539: array([[0, 1, 2],
#        [6, 7, 3],
#        [4, 5, 8]]), 540: array([[1, 2, 0],
#        [6, 7, 3],
#        [4, 5, 8]]), 541: array([[1, 7, 0],
#        [6, 3, 2],
#        [4, 5, 8]]), 542: array([[1, 7, 2],
#        [6, 3, 8],
#        [4, 5, 0]]), 543: array([[1, 7, 2],
#        [6, 5, 3],
#        [0, 4, 8]]), 544: array([[1, 7, 2],
#        [6, 5, 3],
#        [4, 8, 0]]), 545: array([[1, 7, 2],
#        [4, 0, 3],
#        [5, 6, 8]]), 546: array([[1, 7, 2],
#        [4, 6, 3],
#        [5, 8, 0]]), 547: array([[6, 2, 0],
#        [7, 1, 3],
#        [4, 5, 8]]), 548: array([[6, 1, 2],
#        [7, 0, 3],
#        [4, 5, 8]]), 549: array([[7, 6, 2],
#        [4, 1, 3],
#        [5, 8, 0]]), 550: array([[7, 6, 2],
#        [1, 3, 8],
#        [0, 4, 5]]), 551: array([[7, 6, 2],
#        [1, 0, 8],
#        [4, 3, 5]]), 552: array([[7, 6, 2],
#        [1, 0, 5],
#        [4, 8, 3]]), 553: array([[7, 6, 0],
#        [1, 5, 2],
#        [4, 8, 3]]), 554: array([[2, 3, 0],
#        [7, 6, 8],
#        [1, 4, 5]]), 555: array([[2, 6, 3],
#        [7, 0, 8],
#        [1, 4, 5]]), 556: array([[0, 7, 3],
#        [6, 2, 8],
#        [1, 4, 5]]), 557: array([[7, 3, 0],
#        [6, 2, 8],
#        [1, 4, 5]]), 558: array([[7, 2, 0],
#        [6, 8, 3],
#        [1, 4, 5]]), 559: array([[7, 2, 3],
#        [6, 8, 5],
#        [1, 4, 0]]), 560: array([[7, 2, 3],
#        [6, 4, 8],
#        [0, 1, 5]]), 561: array([[7, 2, 3],
#        [6, 4, 8],
#        [1, 5, 0]]), 562: array([[2, 3, 0],
#        [7, 1, 8],
#        [4, 6, 5]]), 563: array([[7, 2, 3],
#        [4, 0, 8],
#        [6, 1, 5]]), 564: array([[7, 2, 3],
#        [4, 1, 8],
#        [6, 5, 0]]), 565: array([[1, 7, 3],
#        [4, 2, 8],
#        [0, 6, 5]]), 566: array([[7, 3, 8],
#        [1, 0, 2],
#        [4, 6, 5]]), 567: array([[7, 3, 8],
#        [1, 2, 5],
#        [4, 6, 0]]), 568: array([[0, 3, 5],
#        [2, 7, 1],
#        [4, 8, 6]]), 569: array([[2, 3, 5],
#        [4, 7, 1],
#        [0, 8, 6]]), 570: array([[0, 2, 5],
#        [7, 3, 1],
#        [4, 8, 6]]), 571: array([[2, 5, 0],
#        [7, 3, 1],
#        [4, 8, 6]]), 572: array([[2, 3, 5],
#        [7, 8, 1],
#        [0, 4, 6]]), 573: array([[2, 3, 5],
#        [7, 8, 1],
#        [4, 6, 0]]), 574: array([[2, 3, 5],
#        [7, 1, 6],
#        [0, 4, 8]]), 575: array([[2, 3, 5],
#        [7, 0, 6],
#        [4, 1, 8]]), 576: array([[2, 1, 3],
#        [4, 0, 5],
#        [8, 7, 6]]), 577: array([[2, 1, 3],
#        [4, 7, 5],
#        [8, 6, 0]]), 578: array([[0, 2, 1],
#        [7, 5, 3],
#        [4, 8, 6]]), 579: array([[2, 5, 1],
#        [7, 0, 3],
#        [4, 8, 6]]), 580: array([[0, 1, 3],
#        [2, 8, 5],
#        [7, 4, 6]]), 581: array([[2, 1, 3],
#        [8, 0, 5],
#        [7, 4, 6]]), 582: array([[2, 1, 0],
#        [7, 8, 3],
#        [4, 6, 5]]), 583: array([[2, 3, 0],
#        [7, 4, 5],
#        [8, 1, 6]]), 584: array([[2, 4, 3],
#        [7, 0, 5],
#        [8, 1, 6]]), 585: array([[4, 7, 3],
#        [2, 0, 5],
#        [8, 1, 6]]), 586: array([[4, 7, 3],
#        [8, 2, 5],
#        [0, 1, 6]]), 587: array([[7, 3, 5],
#        [4, 0, 2],
#        [8, 1, 6]]), 588: array([[7, 3, 5],
#        [4, 2, 6],
#        [8, 1, 0]]), 589: array([[0, 7, 2],
#        [4, 5, 3],
#        [8, 1, 6]]), 590: array([[7, 2, 3],
#        [4, 5, 6],
#        [0, 8, 1]]), 591: array([[7, 2, 3],
#        [4, 0, 6],
#        [8, 5, 1]]), 592: array([[0, 2, 3],
#        [7, 4, 1],
#        [8, 6, 5]]), 593: array([[7, 2, 3],
#        [8, 4, 1],
#        [0, 6, 5]]), 594: array([[0, 7, 3],
#        [4, 2, 1],
#        [8, 6, 5]]), 595: array([[7, 3, 0],
#        [4, 2, 1],
#        [8, 6, 5]]), 596: array([[7, 2, 3],
#        [4, 6, 1],
#        [0, 8, 5]]), 597: array([[7, 2, 3],
#        [4, 6, 1],
#        [8, 5, 0]]), 598: array([[0, 7, 2],
#        [4, 1, 3],
#        [8, 6, 5]]), 599: array([[7, 1, 2],
#        [4, 0, 3],
#        [8, 6, 5]]), 600: array([[1, 3, 5],
#        [2, 0, 7],
#        [4, 8, 6]]), 601: array([[1, 3, 5],
#        [2, 7, 6],
#        [4, 8, 0]]), 602: array([[0, 1, 7],
#        [2, 5, 3],
#        [4, 8, 6]]), 603: array([[1, 5, 7],
#        [2, 0, 3],
#        [4, 8, 6]]), 604: array([[0, 7, 3],
#        [1, 8, 5],
#        [2, 4, 6]]), 605: array([[1, 7, 3],
#        [8, 0, 5],
#        [2, 4, 6]]), 606: array([[1, 7, 0],
#        [2, 8, 3],
#        [4, 6, 5]]), 607: array([[0, 7, 3],
#        [1, 4, 5],
#        [8, 2, 6]]), 608: array([[1, 7, 3],
#        [8, 4, 5],
#        [0, 2, 6]]), 609: array([[0, 1, 3],
#        [4, 7, 5],
#        [8, 2, 6]]), 610: array([[1, 3, 0],
#        [4, 7, 5],
#        [8, 2, 6]]), 611: array([[1, 7, 0],
#        [4, 5, 3],
#        [8, 2, 6]]), 612: array([[1, 7, 3],
#        [4, 5, 6],
#        [8, 2, 0]]), 613: array([[1, 7, 3],
#        [4, 0, 2],
#        [8, 6, 5]]), 614: array([[1, 7, 0],
#        [4, 2, 3],
#        [8, 6, 5]]), 615: array([[3, 5, 0],
#        [7, 1, 2],
#        [4, 8, 6]]), 616: array([[3, 1, 5],
#        [7, 0, 2],
#        [4, 8, 6]]), 617: array([[7, 3, 5],
#        [4, 1, 2],
#        [8, 6, 0]]), 618: array([[1, 7, 5],
#        [3, 0, 2],
#        [4, 8, 6]]), 619: array([[1, 7, 5],
#        [4, 3, 2],
#        [0, 8, 6]]), 620: array([[0, 3, 5],
#        [7, 8, 2],
#        [1, 4, 6]]), 621: array([[7, 3, 5],
#        [8, 0, 2],
#        [1, 4, 6]]), 622: array([[7, 3, 5],
#        [1, 0, 8],
#        [4, 6, 2]]), 623: array([[7, 3, 0],
#        [1, 8, 5],
#        [4, 6, 2]]), 624: array([[0, 3, 5],
#        [7, 2, 6],
#        [1, 4, 8]]), 625: array([[7, 3, 5],
#        [2, 0, 6],
#        [1, 4, 8]]), 626: array([[0, 3, 5],
#        [7, 1, 6],
#        [4, 2, 8]]), 627: array([[7, 3, 5],
#        [4, 1, 6],
#        [0, 2, 8]]), 628: array([[0, 7, 5],
#        [1, 3, 6],
#        [4, 2, 8]]), 629: array([[7, 5, 0],
#        [1, 3, 6],
#        [4, 2, 8]]), 630: array([[7, 3, 0],
#        [1, 6, 5],
#        [4, 2, 8]]), 631: array([[7, 3, 5],
#        [1, 6, 8],
#        [4, 2, 0]]), 632: array([[2, 3, 5],
#        [7, 0, 8],
#        [1, 4, 6]]), 633: array([[2, 3, 5],
#        [7, 8, 6],
#        [1, 4, 0]]), 634: array([[0, 8, 3],
#        [2, 7, 5],
#        [1, 4, 6]]), 635: array([[2, 8, 3],
#        [1, 7, 5],
#        [0, 4, 6]]), 636: array([[2, 8, 0],
#        [7, 5, 3],
#        [1, 4, 6]]), 637: array([[2, 8, 3],
#        [7, 5, 6],
#        [1, 4, 0]]), 638: array([[2, 8, 3],
#        [7, 4, 5],
#        [0, 1, 6]]), 639: array([[2, 8, 3],
#        [7, 4, 5],
#        [1, 6, 0]]), 640: array([[8, 7, 3],
#        [2, 0, 5],
#        [1, 4, 6]]), 641: array([[8, 7, 3],
#        [1, 2, 5],
#        [0, 4, 6]]), 642: array([[7, 3, 5],
#        [8, 2, 6],
#        [1, 4, 0]]), 643: array([[0, 7, 2],
#        [8, 5, 3],
#        [1, 4, 6]]), 644: array([[7, 2, 3],
#        [8, 5, 6],
#        [0, 1, 4]]), 645: array([[7, 2, 3],
#        [8, 0, 6],
#        [1, 5, 4]]), 646: array([[7, 2, 3],
#        [8, 0, 4],
#        [1, 6, 5]]), 647: array([[7, 2, 0],
#        [8, 4, 3],
#        [1, 6, 5]]), 648: array([[1, 7, 2],
#        [8, 0, 3],
#        [4, 6, 5]]), 649: array([[1, 7, 2],
#        [4, 8, 3],
#        [0, 6, 5]]), 650: array([[0, 8, 2],
#        [7, 1, 3],
#        [4, 6, 5]]), 651: array([[7, 8, 2],
#        [4, 1, 3],
#        [0, 6, 5]]), 652: array([[7, 8, 0],
#        [1, 3, 2],
#        [4, 6, 5]]), 653: array([[7, 8, 2],
#        [1, 3, 5],
#        [4, 6, 0]]), 654: array([[7, 8, 2],
#        [1, 6, 3],
#        [0, 4, 5]]), 655: array([[7, 8, 2],
#        [1, 6, 3],
#        [4, 5, 0]]), 656: array([[5, 1, 2],
#        [4, 7, 3],
#        [0, 8, 6]]), 657: array([[1, 2, 3],
#        [5, 0, 7],
#        [4, 8, 6]]), 658: array([[1, 2, 3],
#        [5, 7, 6],
#        [4, 8, 0]]), 659: array([[0, 1, 7],
#        [5, 3, 2],
#        [4, 8, 6]]), 660: array([[1, 3, 7],
#        [5, 0, 2],
#        [4, 8, 6]]), 661: array([[1, 7, 2],
#        [5, 3, 6],
#        [0, 4, 8]]), 662: array([[1, 7, 2],
#        [5, 0, 6],
#        [4, 3, 8]]), 663: array([[0, 7, 2],
#        [1, 8, 3],
#        [5, 4, 6]]), 664: array([[1, 7, 2],
#        [8, 0, 3],
#        [5, 4, 6]]), 665: array([[1, 7, 2],
#        [5, 0, 8],
#        [4, 6, 3]]), 666: array([[1, 7, 0],
#        [5, 8, 2],
#        [4, 6, 3]]), 667: array([[0, 7, 2],
#        [1, 4, 3],
#        [8, 5, 6]]), 668: array([[1, 7, 2],
#        [8, 4, 3],
#        [0, 5, 6]]), 669: array([[0, 1, 2],
#        [4, 7, 3],
#        [8, 5, 6]]), 670: array([[1, 2, 0],
#        [4, 7, 3],
#        [8, 5, 6]]), 671: array([[1, 7, 0],
#        [4, 3, 2],
#        [8, 5, 6]]), 672: array([[1, 7, 2],
#        [4, 3, 6],
#        [8, 5, 0]]), 673: array([[1, 7, 2],
#        [4, 0, 5],
#        [8, 6, 3]]), 674: array([[1, 7, 0],
#        [4, 5, 2],
#        [8, 6, 3]]), 675: array([[5, 2, 3],
#        [7, 0, 1],
#        [4, 8, 6]]), 676: array([[5, 2, 3],
#        [7, 1, 6],
#        [4, 8, 0]]), 677: array([[5, 1, 0],
#        [7, 3, 2],
#        [4, 8, 6]]), 678: array([[5, 1, 2],
#        [7, 3, 6],
#        [4, 8, 0]]), 679: array([[5, 1, 2],
#        [7, 8, 3],
#        [0, 4, 6]]), 680: array([[5, 1, 2],
#        [7, 8, 3],
#        [4, 6, 0]]), 681: array([[0, 5, 2],
#        [7, 4, 3],
#        [8, 1, 6]]), 682: array([[7, 5, 2],
#        [8, 4, 3],
#        [0, 1, 6]]), 683: array([[7, 5, 0],
#        [4, 3, 2],
#        [8, 1, 6]]), 684: array([[7, 5, 2],
#        [4, 3, 6],
#        [8, 1, 0]]), 685: array([[7, 5, 2],
#        [4, 0, 1],
#        [8, 6, 3]]), 686: array([[7, 5, 0],
#        [4, 1, 2],
#        [8, 6, 3]]), 687: array([[0, 5, 2],
#        [7, 3, 6],
#        [1, 4, 8]]), 688: array([[7, 5, 2],
#        [3, 0, 6],
#        [1, 4, 8]]), 689: array([[0, 5, 2],
#        [7, 1, 6],
#        [4, 3, 8]]), 690: array([[7, 5, 2],
#        [4, 1, 6],
#        [0, 3, 8]]), 691: array([[0, 7, 2],
#        [1, 5, 6],
#        [4, 3, 8]]), 692: array([[7, 2, 0],
#        [1, 5, 6],
#        [4, 3, 8]]), 693: array([[7, 5, 0],
#        [1, 6, 2],
#        [4, 3, 8]]), 694: array([[7, 5, 2],
#        [1, 6, 8],
#        [4, 3, 0]]), 695: array([[5, 2, 0],
#        [7, 8, 3],
#        [1, 4, 6]]), 696: array([[5, 8, 2],
#        [7, 0, 3],
#        [1, 4, 6]]), 697: array([[7, 5, 0],
#        [8, 3, 2],
#        [1, 4, 6]]), 698: array([[7, 5, 2],
#        [8, 3, 6],
#        [1, 4, 0]]), 699: array([[7, 5, 2],
#        [8, 4, 3],
#        [1, 6, 0]]), 700: array([[0, 5, 2],
#        [7, 1, 8],
#        [4, 6, 3]]), 701: array([[7, 5, 2],
#        [4, 1, 8],
#        [0, 6, 3]]), 702: array([[0, 7, 2],
#        [1, 5, 8],
#        [4, 6, 3]]), 703: array([[7, 2, 0],
#        [1, 5, 8],
#        [4, 6, 3]]), 704: array([[7, 5, 2],
#        [1, 6, 8],
#        [0, 4, 3]]), 705: array([[0, 7, 5],
#        [1, 8, 2],
#        [4, 6, 3]]), 706: array([[7, 8, 5],
#        [1, 0, 2],
#        [4, 6, 3]]), 707: array([[3, 0, 6],
#        [2, 7, 5],
#        [1, 4, 8]]), 708: array([[2, 3, 6],
#        [1, 7, 5],
#        [4, 0, 8]]), 709: array([[7, 2, 6],
#        [0, 3, 5],
#        [1, 4, 8]]), 710: array([[2, 6, 5],
#        [7, 3, 0],
#        [1, 4, 8]]), 711: array([[2, 3, 6],
#        [0, 4, 5],
#        [7, 1, 8]]), 712: array([[2, 3, 6],
#        [7, 4, 0],
#        [1, 8, 5]]), 713: array([[2, 3, 6],
#        [0, 5, 8],
#        [7, 1, 4]]), 714: array([[2, 3, 6],
#        [0, 7, 8],
#        [1, 5, 4]]), 715: array([[2, 0, 6],
#        [7, 3, 8],
#        [1, 5, 4]]), 716: array([[2, 3, 6],
#        [7, 8, 0],
#        [1, 5, 4]]), 717: array([[5, 3, 6],
#        [2, 7, 0],
#        [1, 4, 8]]), 718: array([[2, 5, 3],
#        [0, 1, 6],
#        [4, 7, 8]]), 719: array([[2, 0, 3],
#        [1, 5, 6],
#        [4, 7, 8]]), 720: array([[2, 5, 3],
#        [1, 6, 0],
#        [4, 7, 8]]), 721: array([[2, 5, 3],
#        [1, 7, 0],
#        [4, 8, 6]]), 722: array([[7, 2, 5],
#        [0, 6, 3],
#        [1, 4, 8]]), 723: array([[2, 6, 5],
#        [0, 7, 3],
#        [1, 4, 8]]), 724: array([[2, 6, 5],
#        [7, 4, 3],
#        [1, 0, 8]]), 725: array([[2, 5, 3],
#        [0, 6, 8],
#        [7, 1, 4]]), 726: array([[2, 5, 3],
#        [0, 7, 8],
#        [1, 6, 4]]), 727: array([[2, 0, 3],
#        [7, 5, 8],
#        [1, 6, 4]]), 728: array([[2, 5, 3],
#        [7, 8, 0],
#        [1, 6, 4]]), 729: array([[5, 0, 3],
#        [2, 4, 6],
#        [7, 1, 8]]), 730: array([[2, 0, 3],
#        [4, 5, 6],
#        [7, 1, 8]]), 731: array([[2, 5, 3],
#        [4, 6, 0],
#        [7, 1, 8]]), 732: array([[2, 5, 3],
#        [4, 1, 6],
#        [7, 0, 8]]), 733: array([[2, 5, 3],
#        [0, 7, 4],
#        [1, 8, 6]]), 734: array([[2, 0, 3],
#        [7, 5, 4],
#        [1, 8, 6]]), 735: array([[2, 5, 3],
#        [7, 8, 4],
#        [1, 0, 6]]), 736: array([[2, 0, 5],
#        [7, 4, 3],
#        [1, 8, 6]]), 737: array([[5, 0, 7],
#        [2, 6, 3],
#        [1, 4, 8]]), 738: array([[5, 7, 3],
#        [2, 6, 8],
#        [1, 0, 4]]), 739: array([[5, 7, 3],
#        [0, 4, 6],
#        [2, 1, 8]]), 740: array([[5, 7, 3],
#        [2, 4, 0],
#        [1, 8, 6]]), 741: array([[5, 7, 3],
#        [0, 1, 6],
#        [4, 2, 8]]), 742: array([[5, 0, 3],
#        [1, 7, 6],
#        [4, 2, 8]]), 743: array([[5, 7, 3],
#        [1, 6, 0],
#        [4, 2, 8]]), 744: array([[5, 7, 3],
#        [1, 2, 0],
#        [4, 8, 6]]), 745: array([[3, 0, 6],
#        [7, 5, 2],
#        [1, 4, 8]]), 746: array([[5, 7, 6],
#        [0, 3, 2],
#        [1, 4, 8]]), 747: array([[7, 3, 6],
#        [0, 4, 2],
#        [5, 1, 8]]), 748: array([[7, 3, 6],
#        [5, 4, 0],
#        [1, 8, 2]]), 749: array([[7, 3, 6],
#        [0, 2, 8],
#        [5, 1, 4]]), 750: array([[7, 3, 6],
#        [0, 5, 8],
#        [1, 2, 4]]), 751: array([[7, 0, 6],
#        [5, 3, 8],
#        [1, 2, 4]]), 752: array([[7, 3, 6],
#        [5, 8, 0],
#        [1, 2, 4]]), 753: array([[5, 0, 2],
#        [6, 7, 3],
#        [1, 4, 8]]), 754: array([[5, 7, 2],
#        [6, 3, 0],
#        [1, 4, 8]]), 755: array([[5, 7, 2],
#        [6, 4, 3],
#        [1, 0, 8]]), 756: array([[5, 7, 2],
#        [1, 6, 3],
#        [4, 0, 8]]), 757: array([[6, 0, 2],
#        [7, 5, 3],
#        [1, 4, 8]]), 758: array([[7, 6, 2],
#        [5, 3, 8],
#        [1, 0, 4]]), 759: array([[7, 6, 2],
#        [0, 4, 3],
#        [5, 1, 8]]), 760: array([[7, 6, 2],
#        [5, 4, 0],
#        [1, 8, 3]]), 761: array([[2, 0, 3],
#        [7, 6, 8],
#        [5, 1, 4]]), 762: array([[7, 0, 3],
#        [6, 2, 8],
#        [5, 1, 4]]), 763: array([[7, 2, 3],
#        [6, 8, 0],
#        [5, 1, 4]]), 764: array([[7, 2, 3],
#        [6, 1, 8],
#        [5, 0, 4]]), 765: array([[7, 2, 3],
#        [1, 5, 8],
#        [6, 0, 4]]), 766: array([[5, 7, 3],
#        [0, 2, 8],
#        [1, 6, 4]]), 767: array([[7, 3, 8],
#        [5, 2, 0],
#        [1, 6, 4]]), 768: array([[7, 0, 2],
#        [5, 8, 3],
#        [1, 6, 4]]), 769: array([[2, 3, 6],
#        [7, 4, 0],
#        [5, 1, 8]]), 770: array([[2, 4, 3],
#        [0, 7, 6],
#        [5, 1, 8]]), 771: array([[2, 4, 3],
#        [7, 6, 0],
#        [5, 1, 8]]), 772: array([[2, 4, 3],
#        [7, 1, 6],
#        [5, 0, 8]]), 773: array([[7, 2, 3],
#        [1, 5, 4],
#        [8, 0, 6]]), 774: array([[5, 7, 3],
#        [0, 2, 4],
#        [1, 8, 6]]), 775: array([[7, 3, 4],
#        [5, 2, 0],
#        [1, 8, 6]]), 776: array([[7, 2, 3],
#        [0, 8, 4],
#        [5, 1, 6]]), 777: array([[5, 7, 2],
#        [0, 4, 3],
#        [1, 8, 6]]), 778: array([[7, 4, 2],
#        [0, 5, 3],
#        [1, 8, 6]]), 779: array([[7, 4, 2],
#        [5, 3, 0],
#        [1, 8, 6]]), 780: array([[7, 4, 2],
#        [5, 8, 3],
#        [1, 0, 6]]), 781: array([[3, 0, 6],
#        [2, 7, 1],
#        [4, 5, 8]]), 782: array([[2, 3, 6],
#        [4, 7, 1],
#        [5, 0, 8]]), 783: array([[7, 2, 6],
#        [0, 3, 1],
#        [4, 5, 8]]), 784: array([[2, 6, 1],
#        [7, 3, 0],
#        [4, 5, 8]]), 785: array([[2, 3, 6],
#        [0, 5, 1],
#        [7, 4, 8]]), 786: array([[2, 3, 6],
#        [7, 5, 0],
#        [4, 8, 1]]), 787: array([[2, 3, 6],
#        [0, 1, 8],
#        [7, 4, 5]]), 788: array([[2, 3, 6],
#        [0, 7, 8],
#        [4, 1, 5]]), 789: array([[2, 0, 6],
# ...
#        [4, 8, 1],
#        [3, 0, 6]]), 7167: array([[7, 0, 5],
#        [4, 1, 2],
#        [3, 8, 6]]), 7168: array([[2, 0, 6],
#        [7, 1, 5],
#        [4, 3, 8]]), 7169: array([[7, 2, 6],
#        [4, 1, 5],
#        [3, 0, 8]]), 7170: array([[1, 7, 6],
#        [0, 2, 5],
#        [4, 3, 8]]), 7171: array([[7, 2, 6],
#        [0, 5, 8],
#        [1, 4, 3]]), 7172: array([[7, 2, 6],
#        [0, 1, 8],
#        [4, 5, 3]]), 7173: array([[7, 0, 6],
#        [1, 2, 8],
#        [4, 5, 3]]), 7174: array([[1, 0, 5],
#        [6, 7, 2],
#        [4, 3, 8]]), 7175: array([[1, 7, 5],
#        [6, 2, 0],
#        [4, 3, 8]]), 7176: array([[1, 7, 5],
#        [6, 3, 2],
#        [4, 0, 8]]), 7177: array([[1, 7, 5],
#        [4, 6, 2],
#        [3, 0, 8]]), 7178: array([[6, 0, 5],
#        [7, 1, 2],
#        [4, 3, 8]]), 7179: array([[7, 6, 5],
#        [4, 1, 2],
#        [3, 0, 8]]), 7180: array([[7, 6, 5],
#        [1, 2, 8],
#        [4, 0, 3]]), 7181: array([[2, 0, 3],
#        [5, 7, 8],
#        [1, 4, 6]]), 7182: array([[5, 2, 3],
#        [1, 7, 8],
#        [4, 0, 6]]), 7183: array([[7, 5, 3],
#        [0, 2, 8],
#        [1, 4, 6]]), 7184: array([[5, 3, 8],
#        [7, 2, 0],
#        [1, 4, 6]]), 7185: array([[5, 2, 3],
#        [0, 4, 8],
#        [7, 1, 6]]), 7186: array([[5, 2, 3],
#        [7, 4, 0],
#        [1, 6, 8]]), 7187: array([[5, 2, 3],
#        [0, 8, 6],
#        [7, 1, 4]]), 7188: array([[5, 2, 3],
#        [0, 7, 6],
#        [1, 8, 4]]), 7189: array([[5, 0, 3],
#        [7, 2, 6],
#        [1, 8, 4]]), 7190: array([[5, 2, 3],
#        [7, 6, 0],
#        [1, 8, 4]]), 7191: array([[5, 8, 2],
#        [0, 1, 3],
#        [4, 7, 6]]), 7192: array([[5, 0, 2],
#        [1, 8, 3],
#        [4, 7, 6]]), 7193: array([[5, 8, 2],
#        [1, 3, 0],
#        [4, 7, 6]]), 7194: array([[5, 8, 2],
#        [1, 7, 0],
#        [4, 6, 3]]), 7195: array([[7, 5, 8],
#        [0, 3, 2],
#        [1, 4, 6]]), 7196: array([[5, 3, 8],
#        [0, 7, 2],
#        [1, 4, 6]]), 7197: array([[5, 3, 8],
#        [7, 4, 2],
#        [1, 0, 6]]), 7198: array([[5, 8, 2],
#        [0, 3, 6],
#        [7, 1, 4]]), 7199: array([[5, 8, 2],
#        [0, 7, 6],
#        [1, 3, 4]]), 7200: array([[5, 0, 2],
#        [7, 8, 6],
#        [1, 3, 4]]), 7201: array([[5, 8, 2],
#        [7, 6, 0],
#        [1, 3, 4]]), 7202: array([[8, 0, 2],
#        [5, 4, 3],
#        [7, 1, 6]]), 7203: array([[5, 0, 2],
#        [4, 8, 3],
#        [7, 1, 6]]), 7204: array([[5, 8, 2],
#        [4, 3, 0],
#        [7, 1, 6]]), 7205: array([[5, 8, 2],
#        [4, 1, 3],
#        [7, 0, 6]]), 7206: array([[5, 8, 2],
#        [0, 7, 4],
#        [1, 6, 3]]), 7207: array([[5, 0, 2],
#        [7, 8, 4],
#        [1, 6, 3]]), 7208: array([[5, 8, 2],
#        [7, 6, 4],
#        [1, 0, 3]]), 7209: array([[5, 0, 8],
#        [7, 4, 2],
#        [1, 6, 3]]), 7210: array([[5, 0, 2],
#        [7, 3, 6],
#        [8, 1, 4]]), 7211: array([[7, 0, 2],
#        [3, 5, 6],
#        [8, 1, 4]]), 7212: array([[7, 5, 2],
#        [3, 6, 0],
#        [8, 1, 4]]), 7213: array([[7, 5, 2],
#        [3, 1, 6],
#        [8, 0, 4]]), 7214: array([[7, 5, 2],
#        [1, 8, 6],
#        [3, 0, 4]]), 7215: array([[8, 7, 2],
#        [0, 5, 6],
#        [1, 3, 4]]), 7216: array([[7, 2, 6],
#        [8, 5, 0],
#        [1, 3, 4]]), 7217: array([[7, 0, 5],
#        [8, 6, 2],
#        [1, 3, 4]]), 7218: array([[7, 5, 2],
#        [1, 8, 4],
#        [6, 0, 3]]), 7219: array([[8, 7, 2],
#        [0, 5, 4],
#        [1, 6, 3]]), 7220: array([[7, 2, 4],
#        [8, 5, 0],
#        [1, 6, 3]]), 7221: array([[7, 5, 2],
#        [0, 6, 4],
#        [8, 1, 3]]), 7222: array([[8, 7, 5],
#        [0, 4, 2],
#        [1, 6, 3]]), 7223: array([[7, 4, 5],
#        [0, 8, 2],
#        [1, 6, 3]]), 7224: array([[7, 4, 5],
#        [8, 2, 0],
#        [1, 6, 3]]), 7225: array([[7, 4, 5],
#        [8, 6, 2],
#        [1, 0, 3]]), 7226: array([[5, 2, 8],
#        [0, 7, 1],
#        [4, 6, 3]]), 7227: array([[5, 0, 8],
#        [7, 2, 1],
#        [4, 6, 3]]), 7228: array([[5, 2, 8],
#        [7, 6, 1],
#        [4, 0, 3]]), 7229: array([[5, 2, 8],
#        [7, 1, 3],
#        [4, 0, 6]]), 7230: array([[5, 0, 2],
#        [7, 4, 8],
#        [6, 1, 3]]), 7231: array([[4, 7, 2],
#        [0, 5, 8],
#        [6, 1, 3]]), 7232: array([[7, 2, 8],
#        [4, 5, 0],
#        [6, 1, 3]]), 7233: array([[7, 0, 5],
#        [4, 8, 2],
#        [6, 1, 3]]), 7234: array([[7, 5, 2],
#        [4, 8, 3],
#        [6, 0, 1]]), 7235: array([[7, 5, 2],
#        [0, 4, 1],
#        [6, 3, 8]]), 7236: array([[7, 0, 2],
#        [4, 5, 1],
#        [6, 3, 8]]), 7237: array([[7, 5, 2],
#        [4, 3, 1],
#        [6, 0, 8]]), 7238: array([[7, 0, 5],
#        [4, 1, 2],
#        [6, 3, 8]]), 7239: array([[2, 0, 8],
#        [7, 1, 5],
#        [4, 6, 3]]), 7240: array([[7, 2, 8],
#        [4, 1, 5],
#        [6, 0, 3]]), 7241: array([[1, 7, 8],
#        [0, 2, 5],
#        [4, 6, 3]]), 7242: array([[7, 2, 8],
#        [0, 6, 5],
#        [1, 4, 3]]), 7243: array([[7, 2, 8],
#        [0, 1, 3],
#        [4, 5, 6]]), 7244: array([[7, 0, 8],
#        [1, 2, 3],
#        [4, 5, 6]]), 7245: array([[7, 2, 8],
#        [1, 3, 0],
#        [4, 5, 6]]), 7246: array([[5, 2, 8],
#        [7, 6, 0],
#        [1, 4, 3]]), 7247: array([[5, 6, 2],
#        [0, 7, 8],
#        [1, 4, 3]]), 7248: array([[5, 6, 2],
#        [7, 8, 0],
#        [1, 4, 3]]), 7249: array([[5, 6, 2],
#        [7, 4, 8],
#        [1, 0, 3]]), 7250: array([[6, 7, 2],
#        [0, 5, 8],
#        [1, 4, 3]]), 7251: array([[7, 2, 8],
#        [6, 5, 0],
#        [1, 4, 3]]), 7252: array([[7, 0, 5],
#        [6, 8, 2],
#        [1, 4, 3]]), 7253: array([[7, 5, 2],
#        [6, 8, 3],
#        [1, 0, 4]]), 7254: array([[7, 5, 2],
#        [6, 4, 0],
#        [1, 3, 8]]), 7255: array([[8, 1, 5],
#        [0, 7, 2],
#        [4, 6, 3]]), 7256: array([[1, 5, 2],
#        [8, 7, 0],
#        [4, 6, 3]]), 7257: array([[1, 0, 7],
#        [8, 2, 5],
#        [4, 6, 3]]), 7258: array([[1, 7, 5],
#        [8, 2, 3],
#        [4, 0, 6]]), 7259: array([[1, 7, 5],
#        [0, 6, 2],
#        [8, 4, 3]]), 7260: array([[1, 7, 5],
#        [8, 6, 0],
#        [4, 3, 2]]), 7261: array([[1, 7, 5],
#        [0, 4, 2],
#        [6, 8, 3]]), 7262: array([[1, 0, 5],
#        [4, 7, 2],
#        [6, 8, 3]]), 7263: array([[1, 7, 5],
#        [4, 2, 0],
#        [6, 8, 3]]), 7264: array([[1, 7, 5],
#        [4, 8, 0],
#        [6, 3, 2]]), 7265: array([[8, 5, 2],
#        [7, 1, 0],
#        [4, 6, 3]]), 7266: array([[8, 1, 5],
#        [7, 2, 0],
#        [4, 6, 3]]), 7267: array([[8, 1, 5],
#        [7, 6, 2],
#        [4, 0, 3]]), 7268: array([[7, 8, 5],
#        [0, 4, 2],
#        [6, 1, 3]]), 7269: array([[7, 8, 5],
#        [4, 2, 0],
#        [6, 1, 3]]), 7270: array([[7, 8, 5],
#        [4, 1, 0],
#        [6, 3, 2]]), 7271: array([[7, 8, 5],
#        [0, 2, 3],
#        [1, 4, 6]]), 7272: array([[7, 8, 5],
#        [0, 1, 3],
#        [4, 2, 6]]), 7273: array([[7, 0, 5],
#        [1, 8, 3],
#        [4, 2, 6]]), 7274: array([[8, 0, 5],
#        [7, 6, 2],
#        [1, 4, 3]]), 7275: array([[7, 8, 5],
#        [6, 2, 0],
#        [1, 4, 3]]), 7276: array([[7, 8, 5],
#        [6, 4, 2],
#        [1, 0, 3]]), 7277: array([[7, 8, 5],
#        [0, 1, 6],
#        [4, 3, 2]]), 7278: array([[7, 0, 5],
#        [1, 8, 6],
#        [4, 3, 2]]), 7279: array([[7, 8, 5],
#        [1, 3, 6],
#        [4, 0, 2]]), 7280: array([[0, 6, 5],
#        [3, 2, 7],
#        [1, 4, 8]]), 7281: array([[3, 6, 5],
#        [1, 2, 7],
#        [0, 4, 8]]), 7282: array([[0, 3, 5],
#        [2, 6, 7],
#        [1, 4, 8]]), 7283: array([[3, 5, 0],
#        [2, 6, 7],
#        [1, 4, 8]]), 7284: array([[3, 6, 5],
#        [2, 4, 7],
#        [0, 1, 8]]), 7285: array([[3, 6, 5],
#        [2, 4, 7],
#        [1, 8, 0]]), 7286: array([[3, 6, 5],
#        [2, 7, 8],
#        [0, 1, 4]]), 7287: array([[3, 6, 5],
#        [2, 0, 8],
#        [1, 7, 4]]), 7288: array([[3, 7, 6],
#        [1, 0, 5],
#        [4, 2, 8]]), 7289: array([[3, 7, 6],
#        [1, 2, 5],
#        [4, 8, 0]]), 7290: array([[0, 3, 7],
#        [2, 5, 6],
#        [1, 4, 8]]), 7291: array([[3, 5, 7],
#        [2, 0, 6],
#        [1, 4, 8]]), 7292: array([[3, 7, 6],
#        [2, 5, 8],
#        [0, 1, 4]]), 7293: array([[0, 7, 6],
#        [3, 4, 5],
#        [2, 1, 8]]), 7294: array([[3, 7, 6],
#        [4, 0, 5],
#        [2, 1, 8]]), 7295: array([[3, 7, 6],
#        [2, 0, 4],
#        [1, 8, 5]]), 7296: array([[3, 7, 0],
#        [2, 4, 6],
#        [1, 8, 5]]), 7297: array([[3, 6, 0],
#        [2, 1, 5],
#        [4, 7, 8]]), 7298: array([[3, 1, 6],
#        [2, 0, 5],
#        [4, 7, 8]]), 7299: array([[1, 2, 6],
#        [3, 0, 5],
#        [4, 7, 8]]), 7300: array([[1, 2, 6],
#        [4, 3, 5],
#        [0, 7, 8]]), 7301: array([[2, 6, 5],
#        [1, 3, 8],
#        [4, 7, 0]]), 7302: array([[2, 3, 6],
#        [1, 5, 8],
#        [0, 4, 7]]), 7303: array([[2, 3, 6],
#        [1, 0, 8],
#        [4, 5, 7]]), 7304: array([[0, 3, 6],
#        [2, 1, 7],
#        [4, 8, 5]]), 7305: array([[2, 3, 6],
#        [4, 1, 7],
#        [0, 8, 5]]), 7306: array([[0, 2, 6],
#        [1, 3, 7],
#        [4, 8, 5]]), 7307: array([[2, 6, 0],
#        [1, 3, 7],
#        [4, 8, 5]]), 7308: array([[2, 3, 6],
#        [1, 8, 7],
#        [0, 4, 5]]), 7309: array([[2, 3, 6],
#        [1, 8, 7],
#        [4, 5, 0]]), 7310: array([[0, 2, 3],
#        [1, 7, 6],
#        [4, 8, 5]]), 7311: array([[2, 7, 3],
#        [1, 0, 6],
#        [4, 8, 5]]), 7312: array([[7, 6, 5],
#        [3, 2, 8],
#        [1, 4, 0]]), 7313: array([[7, 2, 6],
#        [3, 5, 8],
#        [0, 1, 4]]), 7314: array([[0, 2, 6],
#        [7, 4, 5],
#        [3, 1, 8]]), 7315: array([[7, 2, 6],
#        [4, 0, 5],
#        [3, 1, 8]]), 7316: array([[7, 2, 6],
#        [3, 0, 4],
#        [1, 8, 5]]), 7317: array([[7, 2, 0],
#        [3, 4, 6],
#        [1, 8, 5]]), 7318: array([[7, 2, 6],
#        [1, 0, 3],
#        [4, 8, 5]]), 7319: array([[7, 2, 0],
#        [1, 3, 6],
#        [4, 8, 5]]), 7320: array([[0, 6, 5],
#        [2, 3, 8],
#        [7, 1, 4]]), 7321: array([[2, 6, 5],
#        [3, 0, 8],
#        [7, 1, 4]]), 7322: array([[0, 6, 5],
#        [2, 7, 8],
#        [1, 3, 4]]), 7323: array([[2, 6, 5],
#        [1, 7, 8],
#        [0, 3, 4]]), 7324: array([[0, 2, 5],
#        [7, 6, 8],
#        [1, 3, 4]]), 7325: array([[2, 5, 0],
#        [7, 6, 8],
#        [1, 3, 4]]), 7326: array([[2, 6, 0],
#        [7, 8, 5],
#        [1, 3, 4]]), 7327: array([[2, 6, 5],
#        [7, 8, 4],
#        [1, 3, 0]]), 7328: array([[3, 6, 5],
#        [2, 0, 4],
#        [7, 1, 8]]), 7329: array([[3, 6, 5],
#        [2, 4, 8],
#        [7, 1, 0]]), 7330: array([[0, 4, 6],
#        [3, 2, 5],
#        [7, 1, 8]]), 7331: array([[3, 4, 6],
#        [7, 2, 5],
#        [0, 1, 8]]), 7332: array([[3, 4, 0],
#        [2, 5, 6],
#        [7, 1, 8]]), 7333: array([[3, 4, 6],
#        [2, 5, 8],
#        [7, 1, 0]]), 7334: array([[3, 4, 6],
#        [2, 1, 5],
#        [0, 7, 8]]), 7335: array([[3, 4, 6],
#        [2, 1, 5],
#        [7, 8, 0]]), 7336: array([[4, 2, 6],
#        [3, 0, 5],
#        [7, 1, 8]]), 7337: array([[4, 2, 6],
#        [7, 3, 5],
#        [0, 1, 8]]), 7338: array([[2, 6, 5],
#        [4, 3, 8],
#        [7, 1, 0]]), 7339: array([[2, 3, 6],
#        [4, 5, 8],
#        [0, 7, 1]]), 7340: array([[2, 3, 6],
#        [4, 0, 8],
#        [7, 5, 1]]), 7341: array([[2, 3, 6],
#        [4, 0, 1],
#        [7, 8, 5]]), 7342: array([[2, 3, 0],
#        [4, 1, 6],
#        [7, 8, 5]]), 7343: array([[3, 6, 0],
#        [2, 7, 4],
#        [1, 8, 5]]), 7344: array([[2, 3, 6],
#        [1, 0, 4],
#        [8, 7, 5]]), 7345: array([[2, 3, 6],
#        [1, 7, 4],
#        [8, 5, 0]]), 7346: array([[7, 2, 6],
#        [1, 3, 4],
#        [0, 8, 5]]), 7347: array([[2, 6, 4],
#        [7, 0, 3],
#        [1, 8, 5]]), 7348: array([[2, 6, 4],
#        [7, 3, 5],
#        [1, 8, 0]]), 7349: array([[0, 3, 6],
#        [2, 8, 4],
#        [7, 1, 5]]), 7350: array([[2, 3, 6],
#        [8, 0, 4],
#        [7, 1, 5]]), 7351: array([[7, 2, 3],
#        [4, 0, 6],
#        [1, 8, 5]]), 7352: array([[7, 2, 3],
#        [1, 4, 6],
#        [0, 8, 5]]), 7353: array([[0, 4, 3],
#        [2, 7, 6],
#        [1, 8, 5]]), 7354: array([[2, 4, 3],
#        [1, 7, 6],
#        [0, 8, 5]]), 7355: array([[2, 4, 0],
#        [7, 6, 3],
#        [1, 8, 5]]), 7356: array([[2, 4, 3],
#        [7, 6, 5],
#        [1, 8, 0]]), 7357: array([[2, 4, 3],
#        [7, 8, 6],
#        [0, 1, 5]]), 7358: array([[2, 4, 3],
#        [7, 8, 6],
#        [1, 5, 0]]), 7359: array([[3, 6, 8],
#        [2, 0, 5],
#        [7, 1, 4]]), 7360: array([[3, 6, 8],
#        [2, 5, 4],
#        [7, 1, 0]]), 7361: array([[0, 5, 6],
#        [3, 2, 8],
#        [7, 1, 4]]), 7362: array([[3, 5, 6],
#        [7, 2, 8],
#        [0, 1, 4]]), 7363: array([[3, 5, 0],
#        [2, 8, 6],
#        [7, 1, 4]]), 7364: array([[3, 5, 6],
#        [2, 8, 4],
#        [7, 1, 0]]), 7365: array([[3, 5, 6],
#        [2, 1, 8],
#        [0, 7, 4]]), 7366: array([[3, 5, 6],
#        [2, 1, 8],
#        [7, 4, 0]]), 7367: array([[5, 2, 6],
#        [3, 0, 8],
#        [7, 1, 4]]), 7368: array([[5, 2, 6],
#        [7, 3, 8],
#        [0, 1, 4]]), 7369: array([[2, 6, 8],
#        [5, 0, 3],
#        [7, 1, 4]]), 7370: array([[2, 6, 8],
#        [5, 3, 4],
#        [7, 1, 0]]), 7371: array([[0, 2, 3],
#        [5, 8, 6],
#        [7, 1, 4]]), 7372: array([[2, 3, 6],
#        [5, 8, 4],
#        [0, 7, 1]]), 7373: array([[2, 3, 6],
#        [5, 0, 4],
#        [7, 8, 1]]), 7374: array([[0, 3, 6],
#        [2, 1, 8],
#        [5, 7, 4]]), 7375: array([[3, 6, 8],
#        [2, 0, 7],
#        [1, 5, 4]]), 7376: array([[3, 6, 8],
#        [2, 7, 4],
#        [1, 5, 0]]), 7377: array([[0, 7, 6],
#        [3, 2, 8],
#        [1, 5, 4]]), 7378: array([[3, 7, 6],
#        [1, 2, 8],
#        [0, 5, 4]]), 7379: array([[3, 7, 0],
#        [2, 8, 6],
#        [1, 5, 4]]), 7380: array([[3, 7, 6],
#        [2, 8, 4],
#        [1, 5, 0]]), 7381: array([[0, 2, 6],
#        [1, 3, 8],
#        [5, 7, 4]]), 7382: array([[2, 6, 0],
#        [1, 3, 8],
#        [5, 7, 4]]), 7383: array([[2, 3, 0],
#        [1, 8, 6],
#        [5, 7, 4]]), 7384: array([[2, 3, 6],
#        [1, 8, 4],
#        [5, 7, 0]]), 7385: array([[2, 3, 6],
#        [1, 0, 7],
#        [5, 4, 8]]), 7386: array([[2, 3, 0],
#        [1, 7, 6],
#        [5, 4, 8]]), 7387: array([[7, 6, 0],
#        [3, 2, 8],
#        [1, 5, 4]]), 7388: array([[7, 2, 0],
#        [3, 8, 6],
#        [1, 5, 4]]), 7389: array([[7, 2, 6],
#        [3, 8, 4],
#        [1, 5, 0]]), 7390: array([[7, 2, 6],
#        [1, 0, 8],
#        [5, 3, 4]]), 7391: array([[7, 2, 6],
#        [1, 3, 8],
#        [5, 4, 0]]), 7392: array([[0, 6, 8],
#        [2, 7, 3],
#        [1, 5, 4]]), 7393: array([[2, 6, 8],
#        [1, 7, 3],
#        [0, 5, 4]]), 7394: array([[0, 2, 8],
#        [7, 6, 3],
#        [1, 5, 4]]), 7395: array([[2, 6, 8],
#        [7, 5, 3],
#        [0, 1, 4]]), 7396: array([[2, 6, 8],
#        [7, 5, 3],
#        [1, 4, 0]]), 7397: array([[2, 6, 8],
#        [7, 3, 4],
#        [0, 1, 5]]), 7398: array([[2, 6, 8],
#        [7, 0, 4],
#        [1, 3, 5]]), 7399: array([[3, 6, 0],
#        [5, 2, 7],
#        [1, 4, 8]]), 7400: array([[3, 2, 6],
#        [5, 0, 7],
#        [1, 4, 8]]), 7401: array([[5, 3, 6],
#        [1, 2, 7],
#        [4, 8, 0]]), 7402: array([[2, 5, 6],
#        [3, 0, 7],
#        [1, 4, 8]]), 7403: array([[2, 5, 6],
#        [1, 3, 7],
#        [0, 4, 8]]), 7404: array([[0, 3, 6],
#        [5, 4, 7],
#        [2, 1, 8]]), 7405: array([[5, 3, 6],
#        [4, 0, 7],
#        [2, 1, 8]]), 7406: array([[5, 3, 6],
#        [2, 0, 4],
#        [1, 8, 7]]), 7407: array([[5, 3, 0],
#        [2, 4, 6],
#        [1, 8, 7]]), 7408: array([[0, 3, 6],
#        [5, 7, 8],
#        [2, 1, 4]]), 7409: array([[5, 3, 6],
#        [7, 0, 8],
#        [2, 1, 4]]), 7410: array([[0, 3, 6],
#        [5, 2, 8],
#        [1, 7, 4]]), 7411: array([[5, 3, 6],
#        [1, 2, 8],
#        [0, 7, 4]]), 7412: array([[0, 5, 6],
#        [2, 3, 8],
#        [1, 7, 4]]), 7413: array([[5, 6, 0],
#        [2, 3, 8],
#        [1, 7, 4]]), 7414: array([[5, 3, 0],
#        [2, 8, 6],
#        [1, 7, 4]]), 7415: array([[5, 3, 6],
#        [2, 8, 4],
#        [1, 7, 0]]), 7416: array([[5, 3, 6],
#        [2, 0, 1],
#        [4, 7, 8]]), 7417: array([[5, 3, 6],
#        [2, 1, 8],
#        [4, 7, 0]]), 7418: array([[5, 1, 3],
#        [4, 2, 6],
#        [0, 7, 8]]), 7419: array([[5, 1, 0],
#        [2, 6, 3],
#        [4, 7, 8]]), 7420: array([[5, 1, 3],
#        [2, 6, 8],
#        [4, 7, 0]]), 7421: array([[5, 1, 3],
#        [2, 7, 6],
#        [4, 8, 0]]), 7422: array([[1, 2, 3],
#        [4, 0, 6],
#        [7, 5, 8]]), 7423: array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 0]])}

# %%
goal_path = generate_path(ParentNodes)
# Out:
# Start_key =
# 1
#
# Goal_key =
# 7423
#
# goal_path =
# [1, 2, 4, 8, 16, 32, 53, 92, 156, 274, 430, 719, 1126, 1886, 2936, 4846, 7423]

# %%
print_optimalpath(goal_path)
# Out:
# Optimal path from Start to Goal
# [[7 2 3]
#  [1 5 6]
#  [4 8 0]]
#
# [[7 2 3]
#  [1 5 6]
#  [4 0 8]]
#
# [[7 2 3]
#  [1 5 6]
#  [0 4 8]]
#
# [[7 2 3]
#  [0 5 6]
#  [1 4 8]]
#
# [[0 2 3]
#  [7 5 6]
#  [1 4 8]]
#
# [[2 0 3]
#  [7 5 6]
#  [1 4 8]]
#
# [[2 5 3]
#  [7 0 6]
#  [1 4 8]]
#
# [[2 5 3]
#  [0 7 6]
#  [1 4 8]]
#
# [[2 5 3]
#  [1 7 6]
#  [0 4 8]]
#
# [[2 5 3]
#  [1 7 6]
#  [4 0 8]]
#
# [[2 5 3]
#  [1 0 6]
#  [4 7 8]]
#
# [[2 0 3]
#  [1 5 6]
#  [4 7 8]]
#
# [[0 2 3]
#  [1 5 6]
#  [4 7 8]]
#
# [[1 2 3]
#  [0 5 6]
#  [4 7 8]]
#
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
#
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]

# %%
#Creates the .txt Files

path = '/home/prachu/Desktop/UMD_Robotics/Courses/ENPM661_Planning/ENPM661_Projects/'

nodePath_filegen(notepad_path)
NodesInfo_filegen(ParentNodes)
Nodes_filegen(AllNodes)

# %%
notepad_path
# Out:
# [array([[7, 2, 3],
#         [1, 5, 6],
#         [4, 8, 0]]),
#  array([[7, 2, 3],
#         [1, 5, 6],
#         [4, 0, 8]]),
#  array([[7, 2, 3],
#         [1, 5, 6],
#         [0, 4, 8]]),
#  array([[7, 2, 3],
#         [0, 5, 6],
#         [1, 4, 8]]),
#  array([[0, 2, 3],
#         [7, 5, 6],
#         [1, 4, 8]]),
#  array([[2, 0, 3],
#         [7, 5, 6],
#         [1, 4, 8]]),
#  array([[2, 5, 3],
#         [7, 0, 6],
#         [1, 4, 8]]),
#  array([[2, 5, 3],
#         [0, 7, 6],
#         [1, 4, 8]]),
#  array([[2, 5, 3],
#         [1, 7, 6],
#         [0, 4, 8]]),
#  array([[2, 5, 3],
#         [1, 7, 6],
#         [4, 0, 8]]),
#  array([[2, 5, 3],
#         [1, 0, 6],
#         [4, 7, 8]]),
#  array([[2, 0, 3],
#         [1, 5, 6],
#         [4, 7, 8]]),
#  array([[0, 2, 3],
#         [1, 5, 6],
#         [4, 7, 8]]),
#  array([[1, 2, 3],
#         [0, 5, 6],
#         [4, 7, 8]]),
#  array([[1, 2, 3],
#         [4, 5, 6],
#         [0, 7, 8]]),
#  array([[1, 2, 3],
#         [4, 5, 6],
#         [7, 0, 8]]),
#  array([[1, 2, 3],
#         [4, 5, 6],
#         [7, 8, 0]])]

# %%
import numpy as np
#Node_State = np.array([[1,0,3],[4,2,5],[7,8,6]]) #working_instant
#Node_State = np.array([[2,8,3],[1,6,4],[7,0,5]]) #takes_lot_of_time
#Node_State = np.array([[2,4,3],[7,8,0],[6,1,5]])  #working_maybe_a_min
Node_State = np.array([[1,0,2],[4,6,8],[7,3,5]]) #working_instant
#Node_State = np.array([[4,8,1],[5,2,0],[7,6,3]]) #working_instant
#Node_State = np.array([[7,2,3],[1,5,6],[4,8,0]]) #working_maybe_a_min



Goal_Node = np.array([[1,2,3],[4,5,6],[7,8,0]])
ParentNodes = {}
ParentNodes = {1:0}
AllNodes ={}
AllNodes = {1:Node_State}
path = list()

NewNode1 = Node_State.copy()
NewNode2 = Node_State.copy()
NewNode3 = Node_State.copy()
NewNode4 = Node_State.copy()

a = 1
b = 1
next_node =1
flag = 1
clean =1

# %%
[i,j] = BlankTileLocation(Node_State)

# %%
[i,j]
# Out:
# [1, 2]

# %%
def BlankTileLocation(state):
    for i in range(0,len(Node_State[1])):
        for j in range(0,len(Node_State[1])):
            if state[i,j] == 0:
                return[i,j]
            
            
def ActionMoveLeft(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if j == 0:
                    print("cannot perform left movement")
                    return[0, state]
                else:
                    print("left movement performed")
                    New_state[i,j-1], New_state[i,j] = New_state[i,j], New_state[i,j-1]
                    return[1, New_state]
            
            
def ActionMoveRight(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if j == 2:
                    print("cannot perform Right movement")
                    return[0, state]
                    
                else:
                    print("right movement performed")
                    New_state[i,j+1], New_state[i,j] = New_state[i,j], New_state[i,j+1]
                    return[1, New_state]

def ActionMoveUp(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if i == 0:
                    print("cannot perform Up movement")
                    return[0, state]
                    
                else:
                    print("up movement performed")
                    New_state[i-1,j], New_state[i,j] = New_state[i,j], New_state[i-1,j]
                    return[1, New_state]
            
def ActionMoveDown(state):
    New_state = state.copy()
    for i in range(0,len(New_state[1])):
        for j in range(0,len(New_state[1])):
            if state[i,j] == 0:
                if i == 2:
                    print("cannot perform Down movement")
                    return[0, state]
                    
                else:
                    print("Down movement performed")
                    New_state[i+1,j], New_state[i,j] = New_state[i,j], New_state[i+1,j]
                    return[1, New_state]
                
            
            
def AddNode(New_N):
    global a
    global b
    global flag 
    flag = 1
    
    for values in AllNodes.values():
        if (values == New_N).all():
            flag = 0
            print("present_do not add")
    
    if(flag == 1):
        print("Not present_do add")
        a = a+1
        AllNodes[a] = New_N
        ParentNodes[a] = b

            

def Check_and_Add(state1):
    global b
    global NewNode1
    global NewNode2
    global NewNode3
    global NewNode4
    [Status, NewNode] = ActionMoveLeft(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode1 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveUp(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode2 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveRight(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    NewNode3 = NewNode.copy()
    
    [Status, NewNode] = ActionMoveDown(state1)
    print(NewNode)
    AddNode(NewNode)
    print("")
    print("Next Iteration")
    print("")
    NewNode4 = NewNode.copy()
    b = b+1

# %%
def get_key_AllNodes(val): 
    for key, value in AllNodes.items(): 
         if (val == value).all(): 
             return key 
  
    return "key doesn't exist"


def get_key_ParentNodes(val): 
    for key, value in ParentNodes.items(): 
         if (val == value): 
             return key 
  
    return "key doesn't exist"


def clean_AllNodes(AllNodes):
    key = get_key_AllNodes(Goal_Node)
    length = len(AllNodes)
    while(key != length):
        key = key + 1
        AllNodes.pop(key, None)

# %%
def generate_path(p_nodes):
    
    Start_key = get_key_AllNodes(Node_State) 
    print("Start_key =")
    print(Start_key)
    print("")

    Goal_key = get_key_AllNodes(Goal_Node)
    print("Goal_key = ")
    print(Goal_key)
    print("") 
    
    Goal = 0
    
    path.insert(Goal, Goal_key)
    print("goal_path = ")
    
    while(path[Goal] != Start_key):
        Goal = Goal + 1
        path.insert(Goal, p_nodes[Goal_key])
        Goal_key = p_nodes[Goal_key]      
    path.sort()
    print(path)
    return(path)


def print_optimalpath(path):
    print("Optinal path from Start to Goal")
    for m in path:
        
        print(AllNodes[m])
        print("")

# %%
while((not(np.array_equal(NewNode1, Goal_Node))) and (not(np.array_equal(NewNode2, Goal_Node))) and (not(np.array_equal(NewNode3, Goal_Node))) and (not(np.array_equal(NewNode4, Goal_Node)))):
    global next_node 
    Check_and_Add(AllNodes[next_node])
    next_node = next_node +1
# Out:
# left movement performed
# [[0 1 2]
#  [4 6 8]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [4 6 8]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [4 0 8]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 1 2]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 1 2]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 0 2]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [0 6 8]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 2]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[1 2 0]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 0]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 6 0]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [0 4 8]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[1 0 2]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 6 2]
#  [4 8 0]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [4 3 8]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 2]
#  [0 6 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[0 1 2]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 1 2]
#  [6 0 8]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [7 6 8]
#  [0 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 0 6]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[1 2 0]
#  [4 6 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 8]
#  [4 6 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 6 5]
#  [7 3 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 4 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 4 8]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 0 8]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 4 8]
#  [0 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 0 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[1 6 0]
#  [4 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [4 8 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 8 5]
#  [7 3 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 3 8]
#  [0 7 5]]
# Not present_do add
#
# up movement performed
# [[1 6 2]
#  [4 0 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 6 2]
#  [4 3 8]
#  [7 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [0 6 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[4 0 2]
#  [6 1 8]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [6 8 0]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [6 3 8]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 2]
#  [7 6 8]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[4 1 2]
#  [0 6 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 1 2]
#  [7 6 8]
#  [3 0 5]]
# Not present_do add
#
# cannot perform Down movement
# [[4 1 2]
#  [7 6 8]
#  [0 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [0 4 6]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[1 0 8]
#  [4 2 6]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 6 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 3 6]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 6 5]
#  [7 0 3]]
# Not present_do add
#
# up movement performed
# [[1 2 8]
#  [4 6 0]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 8]
#  [4 6 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 8]
#  [4 6 5]
#  [7 3 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 6 2]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 6 2]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[6 0 2]
#  [1 4 8]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [0 4 8]
#  [7 3 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [7 4 8]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [0 4 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 6 2]
#  [7 4 8]
#  [3 0 5]]
# Not present_do add
#
# cannot perform Down movement
# [[1 6 2]
#  [7 4 8]
#  [0 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 0 6]
#  [4 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[1 6 0]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 6 0]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 8 0]
#  [7 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 8 5]
#  [7 0 3]]
# Not present_do add
#
# up movement performed
# [[1 6 2]
#  [4 8 0]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 6 2]
#  [4 8 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [4 8 5]
#  [7 3 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [4 3 8]
#  [0 7 5]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [0 3 8]
#  [4 7 5]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 3 8]
#  [7 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [4 3 8]
#  [0 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 3 8]
#  [7 0 5]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 4 2]
#  [6 1 8]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[4 0 2]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 2 0]
#  [6 1 8]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [6 0 8]
#  [7 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [6 0 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[4 1 0]
#  [6 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Right movement
# [[4 1 2]
#  [6 8 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [6 8 5]
#  [7 3 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [6 3 8]
#  [0 7 5]]
# Not present_do add
#
# up movement performed
# [[4 1 2]
#  [6 0 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[4 1 2]
#  [6 3 8]
#  [7 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [7 6 8]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[4 1 2]
#  [7 0 8]
#  [3 6 5]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [7 6 8]
#  [3 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[4 1 2]
#  [7 6 8]
#  [3 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [0 4 6]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[0 2 8]
#  [1 4 6]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 0 6]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [7 4 6]
#  [0 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 8]
#  [4 2 6]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 8]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 8 0]
#  [4 2 6]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [4 0 6]
#  [7 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 3 6]
#  [0 7 5]]
# Not present_do add
#
# up movement performed
# [[1 2 8]
#  [4 0 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 2 8]
#  [4 3 6]
#  [7 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 8]
#  [4 3 6]
#  [7 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 6 5]
#  [0 7 3]]
# Not present_do add
#
# up movement performed
# [[1 2 8]
#  [4 0 5]
#  [7 6 3]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 6 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 8]
#  [4 6 5]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 6 2]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[6 0 2]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[6 2 0]
#  [1 4 8]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[6 4 2]
#  [1 0 8]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 4 8]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [7 0 8]
#  [3 4 5]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [7 4 8]
#  [3 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 6 2]
#  [7 4 8]
#  [3 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 1 6]
#  [4 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 6]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 6 0]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 8 6]
#  [4 0 2]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 8 5]
#  [0 7 3]]
# Not present_do add
#
# up movement performed
# [[1 6 2]
#  [4 0 5]
#  [7 8 3]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 8 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [4 8 5]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 3 8]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 3 8]
#  [4 7 5]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [3 0 8]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [4 3 8]
#  [0 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
# Not present_do add
#
# up movement performed
# [[1 6 0]
#  [4 3 2]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 4 2]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 4 2]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 0 2]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 4 2]
#  [0 1 8]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 0 2]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[4 2 0]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 2 0]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 2 8]
#  [6 1 0]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 0 1]
#  [6 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[4 1 0]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 1 0]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [6 8 0]
#  [7 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [6 8 5]
#  [7 0 3]]
# Not present_do add
#
# up movement performed
# [[4 1 2]
#  [6 8 0]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 1 2]
#  [6 8 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [6 8 5]
#  [7 3 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 2]
#  [6 3 8]
#  [0 7 5]]
# present_do not add
#
# up movement performed
# [[4 1 2]
#  [0 3 8]
#  [6 7 5]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [6 3 8]
#  [7 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [6 3 8]
#  [0 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [6 3 8]
#  [7 0 5]]
# present_do not add
#
# up movement performed
# [[4 1 2]
#  [6 3 0]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [0 7 8]
#  [3 6 5]]
# Not present_do add
#
# up movement performed
# [[4 0 2]
#  [7 1 8]
#  [3 6 5]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [7 8 0]
#  [3 6 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [7 6 8]
#  [3 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [7 6 8]
#  [3 0 5]]
# present_do not add
#
# up movement performed
# [[4 1 2]
#  [7 6 0]
#  [3 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[4 1 2]
#  [7 6 8]
#  [3 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [7 6 8]
#  [3 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 8]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 8]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[2 0 8]
#  [1 4 6]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [0 4 6]
#  [7 3 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [7 4 6]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [0 4 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 2 8]
#  [7 4 6]
#  [3 0 5]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 8]
#  [7 4 6]
#  [0 3 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 1 8]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 1 8]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 0 8]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 1 8]
#  [0 2 6]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 8]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[1 8 0]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 8 0]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 8 6]
#  [4 2 0]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [4 3 6]
#  [0 7 5]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [0 3 6]
#  [4 7 5]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 3 6]
#  [7 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 8]
#  [4 3 6]
#  [0 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 3 6]
#  [7 0 5]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [4 3 0]
#  [7 5 6]]
# Not present_do add
#
# cannot perform Right movement
# [[1 2 8]
#  [4 3 6]
#  [7 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 8]
#  [4 3 6]
#  [7 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [4 6 5]
#  [0 7 3]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [0 6 5]
#  [4 7 3]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 6 5]
#  [7 0 3]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 8]
#  [4 6 5]
#  [0 7 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [0 4 5]
#  [7 6 3]]
# Not present_do add
#
# up movement performed
# [[1 0 8]
#  [4 2 5]
#  [7 6 3]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 5 0]
#  [7 6 3]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [4 6 5]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 0 2]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[6 2 0]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[6 2 0]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 2 8]
#  [1 4 0]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 4 2]
#  [0 1 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[6 0 2]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[6 4 2]
#  [1 8 0]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[6 4 2]
#  [1 3 8]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [0 7 8]
#  [3 4 5]]
# Not present_do add
#
# up movement performed
# [[1 0 2]
#  [7 6 8]
#  [3 4 5]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [7 8 0]
#  [3 4 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [7 4 8]
#  [3 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 4 8]
#  [3 0 5]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [7 4 0]
#  [3 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 4 8]
#  [3 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [7 4 8]
#  [3 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 1 6]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 1 6]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 0 6]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 1 6]
#  [0 8 2]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 8 6]
#  [0 4 2]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[1 0 6]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 8 6]
#  [4 2 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 8 6]
#  [4 3 2]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [4 8 5]
#  [0 7 3]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [0 8 5]
#  [4 7 3]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 8 5]
#  [7 0 3]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [4 8 5]
#  [0 7 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [0 4 5]
#  [7 8 3]]
# Not present_do add
#
# up movement performed
# [[1 0 2]
#  [4 6 5]
#  [7 8 3]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 5 0]
#  [7 8 3]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [4 8 5]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 6 2]
#  [1 3 8]
#  [4 7 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 6 2]
#  [1 3 8]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[6 0 2]
#  [1 3 8]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [0 3 8]
#  [4 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [0 3 8]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[1 0 2]
#  [3 6 8]
#  [4 7 5]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [3 8 0]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [3 7 8]
#  [4 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [0 4 3]
#  [7 5 8]]
# Not present_do add
#
# up movement performed
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 5 3]
#  [7 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 6]
#  [4 3 2]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 6 0]
#  [4 3 2]
#  [7 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[1 6 0]
#  [4 3 2]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[6 4 2]
#  [0 1 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[0 4 2]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[6 4 2]
#  [1 0 8]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 4 2]
#  [7 1 8]
#  [0 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 2 8]
#  [6 0 1]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[4 2 0]
#  [6 1 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 2 8]
#  [6 1 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 2 8]
#  [6 1 5]
#  [7 3 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 4 1]
#  [6 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[4 0 1]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 1 0]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 8 1]
#  [6 0 2]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [6 8 5]
#  [0 7 3]]
# Not present_do add
#
# up movement performed
# [[4 1 2]
#  [6 0 5]
#  [7 8 3]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [6 8 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [6 8 5]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 2]
#  [0 3 8]
#  [6 7 5]]
# present_do not add
#
# up movement performed
# [[0 1 2]
#  [4 3 8]
#  [6 7 5]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [3 0 8]
#  [6 7 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [6 3 8]
#  [0 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [6 0 3]
#  [7 5 8]]
# Not present_do add
#
# up movement performed
# [[4 1 0]
#  [6 3 2]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[4 1 2]
#  [6 3 0]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [6 3 8]
#  [7 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 2]
#  [0 7 8]
#  [3 6 5]]
# present_do not add
#
# up movement performed
# [[0 1 2]
#  [4 7 8]
#  [3 6 5]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [7 0 8]
#  [3 6 5]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [3 7 8]
#  [0 6 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 4 2]
#  [7 1 8]
#  [3 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[4 0 2]
#  [7 1 8]
#  [3 6 5]]
# present_do not add
#
# right movement performed
# [[4 2 0]
#  [7 1 8]
#  [3 6 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [7 0 8]
#  [3 6 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [7 0 8]
#  [3 6 5]]
# present_do not add
#
# up movement performed
# [[4 1 0]
#  [7 8 2]
#  [3 6 5]]
# Not present_do add
#
# cannot perform Right movement
# [[4 1 2]
#  [7 8 0]
#  [3 6 5]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [7 8 5]
#  [3 6 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [7 0 6]
#  [3 5 8]]
# Not present_do add
#
# up movement performed
# [[4 1 0]
#  [7 6 2]
#  [3 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[4 1 2]
#  [7 6 0]
#  [3 5 8]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [7 6 8]
#  [3 5 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 2 8]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[2 0 8]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[2 8 0]
#  [1 4 6]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[2 4 8]
#  [1 0 6]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [7 4 6]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [7 0 6]
#  [3 4 5]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [7 4 6]
#  [3 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 8]
#  [7 4 6]
#  [3 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 8]
#  [0 2 6]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[0 1 8]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 1 8]
#  [2 0 6]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 8]
#  [7 2 6]
#  [0 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 8 6]
#  [4 0 2]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[1 8 0]
#  [4 2 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 8 6]
#  [4 2 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 8 6]
#  [4 2 5]
#  [7 3 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [0 3 6]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[0 2 8]
#  [1 3 6]
#  [4 7 5]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [3 0 6]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [4 3 6]
#  [0 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 0 3]
#  [7 5 6]]
# Not present_do add
#
# up movement performed
# [[1 2 0]
#  [4 3 8]
#  [7 5 6]]
# Not present_do add
#
# cannot perform Right movement
# [[1 2 8]
#  [4 3 0]
#  [7 5 6]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 3 6]
#  [7 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [0 6 5]
#  [4 7 3]]
# present_do not add
#
# up movement performed
# [[0 2 8]
#  [1 6 5]
#  [4 7 3]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [6 0 5]
#  [4 7 3]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [4 6 5]
#  [0 7 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [0 4 5]
#  [7 6 3]]
# present_do not add
#
# up movement performed
# [[0 2 8]
#  [1 4 5]
#  [7 6 3]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 0 5]
#  [7 6 3]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [7 4 5]
#  [0 6 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 8]
#  [4 2 5]
#  [7 6 3]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 8]
#  [4 2 5]
#  [7 6 3]]
# present_do not add
#
# right movement performed
# [[1 8 0]
#  [4 2 5]
#  [7 6 3]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [4 0 5]
#  [7 6 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 0 5]
#  [7 6 3]]
# present_do not add
#
# up movement performed
# [[1 2 0]
#  [4 5 8]
#  [7 6 3]]
# Not present_do add
#
# cannot perform Right movement
# [[1 2 8]
#  [4 5 0]
#  [7 6 3]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 5 3]
#  [7 6 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 2 8]
#  [1 0 4]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[6 2 0]
#  [1 4 8]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[6 2 8]
#  [1 4 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 2 8]
#  [1 4 5]
#  [7 3 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 4 2]
#  [1 0 8]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[6 4 0]
#  [1 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Right movement
# [[6 4 2]
#  [1 8 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 4 2]
#  [1 8 5]
#  [7 3 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 4 2]
#  [1 3 8]
#  [0 7 5]]
# Not present_do add
#
# up movement performed
# [[6 4 2]
#  [1 0 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[6 4 2]
#  [1 3 8]
#  [7 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[6 4 2]
#  [1 3 8]
#  [7 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 7 8]
#  [3 4 5]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 7 8]
#  [3 4 5]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [7 0 8]
#  [3 4 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [3 7 8]
#  [0 4 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [7 6 8]
#  [3 4 5]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [7 6 8]
#  [3 4 5]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [7 6 8]
#  [3 4 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [7 0 8]
#  [3 4 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 0 8]
#  [3 4 5]]
# present_do not add
#
# up movement performed
# [[1 6 0]
#  [7 8 2]
#  [3 4 5]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 8 0]
#  [3 4 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 8 5]
#  [3 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 0 4]
#  [3 5 8]]
# Not present_do add
#
# up movement performed
# [[1 6 0]
#  [7 4 2]
#  [3 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 4 0]
#  [3 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 4 8]
#  [3 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 6]
#  [0 8 2]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[0 1 6]
#  [4 8 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 1 6]
#  [8 0 2]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 6]
#  [7 8 2]
#  [0 3 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 8 6]
#  [0 4 2]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[0 8 6]
#  [1 4 2]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[1 8 6]
#  [4 0 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[1 8 6]
#  [7 4 2]
#  [0 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 8 6]
#  [4 3 2]
#  [0 7 5]]
# Not present_do add
#
# up movement performed
# [[1 8 6]
#  [4 0 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[1 8 6]
#  [4 3 2]
#  [7 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 8 6]
#  [4 3 2]
#  [7 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 8 5]
#  [4 7 3]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 8 5]
#  [4 7 3]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [8 0 5]
#  [4 7 3]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [4 8 5]
#  [0 7 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 4 5]
#  [7 8 3]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 4 5]
#  [7 8 3]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 0 5]
#  [7 8 3]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 4 5]
#  [0 8 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [4 6 5]
#  [7 8 3]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [4 6 5]
#  [7 8 3]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [4 6 5]
#  [7 8 3]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [4 0 5]
#  [7 8 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 0 5]
#  [7 8 3]]
# present_do not add
#
# up movement performed
# [[1 6 0]
#  [4 5 2]
#  [7 8 3]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [4 5 0]
#  [7 8 3]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 5 3]
#  [7 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 6 2]
#  [1 3 8]
#  [4 7 5]]
# present_do not add
#
# cannot perform Up movement
# [[6 0 2]
#  [1 3 8]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[6 2 0]
#  [1 3 8]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[6 3 2]
#  [1 0 8]
#  [4 7 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [3 6 8]
#  [4 7 5]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [3 6 8]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [3 6 8]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [3 0 8]
#  [4 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [3 0 8]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[1 6 0]
#  [3 8 2]
#  [4 7 5]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [3 8 0]
#  [4 7 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [3 8 5]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [3 7 8]
#  [0 4 5]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [3 0 8]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[1 6 2]
#  [3 7 8]
#  [4 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 6 2]
#  [3 7 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 4 3]
#  [7 5 8]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 4 3]
#  [7 5 8]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 4 3]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [4 6 3]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [4 5 3]
#  [0 7 8]]
# Not present_do add
#
# up movement performed
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
# present_do not add
#
# right movement performed
# [[1 6 2]
#  [4 5 3]
#  [7 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [4 5 3]
#  [7 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 1 6]
#  [4 3 2]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 6]
#  [4 3 2]
#  [7 5 8]]
# present_do not add
#
# right movement performed
# [[1 6 0]
#  [4 3 2]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[1 3 6]
#  [4 0 2]
#  [7 5 8]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[6 4 2]
#  [7 1 8]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[6 4 2]
#  [0 1 8]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[6 4 2]
#  [7 1 8]
#  [3 0 5]]
# Not present_do add
#
# cannot perform Down movement
# [[6 4 2]
#  [7 1 8]
#  [0 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 2 8]
#  [0 6 1]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[4 0 8]
#  [6 2 1]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[4 2 8]
#  [6 1 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[4 2 8]
#  [6 3 1]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 2 8]
#  [6 1 5]
#  [7 0 3]]
# Not present_do add
#
# up movement performed
# [[4 2 8]
#  [6 1 0]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 2 8]
#  [6 1 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[4 2 8]
#  [6 1 5]
#  [7 3 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 4 1]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 4 1]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 0 1]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 4 1]
#  [0 8 2]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 8 1]
#  [0 6 2]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[4 0 1]
#  [6 8 2]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 8 1]
#  [6 2 0]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[4 8 1]
#  [6 3 2]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 2]
#  [6 8 5]
#  [0 7 3]]
# present_do not add
#
# up movement performed
# [[4 1 2]
#  [0 8 5]
#  [6 7 3]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [6 8 5]
#  [7 0 3]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [6 8 5]
#  [0 7 3]]
# present_do not add
#
# Next Iteration
# left movement performed
# [[4 1 2]
#  [0 6 5]
#  [7 8 3]]
# Not present_do add
#
# up movement performed
# [[4 0 2]
#  [6 1 5]
#  [7 8 3]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [6 5 0]
#  [7 8 3]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [6 8 5]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 1 2]
#  [4 3 8]
#  [6 7 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 1 2]
#  [4 3 8]
#  [6 7 5]]
# present_do not add
#
# right movement performed
# [[1 0 2]
#  [4 3 8]
#  [6 7 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [0 3 8]
#  [6 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [0 3 8]
#  [6 7 5]]
# present_do not add
#
# up movement performed
# [[4 0 2]
#  [3 1 8]
#  [6 7 5]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [3 8 0]
#  [6 7 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [3 7 8]
#  [6 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [0 6 3]
#  [7 5 8]]
# Not present_do add
#
# up movement performed
# [[4 0 2]
#  [6 1 3]
#  [7 5 8]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [6 3 0]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [6 5 3]
#  [7 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 0 1]
#  [6 3 2]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[4 1 0]
#  [6 3 2]
#  [7 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[4 1 0]
#  [6 3 2]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [6 3 0]
#  [7 5 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 1 2]
#  [4 7 8]
#  [3 6 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 1 2]
#  [4 7 8]
#  [3 6 5]]
# present_do not add
#
# right movement performed
# [[1 0 2]
#  [4 7 8]
#  [3 6 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 2]
#  [0 7 8]
#  [3 6 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 2]
#  [3 7 8]
#  [0 6 5]]
# present_do not add
#
# up movement performed
# [[4 1 2]
#  [0 7 8]
#  [3 6 5]]
# present_do not add
#
# right movement performed
# [[4 1 2]
#  [3 7 8]
#  [6 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [3 7 8]
#  [0 6 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 4 2]
#  [7 1 8]
#  [3 6 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 4 2]
#  [7 1 8]
#  [3 6 5]]
# present_do not add
#
# right movement performed
# [[4 0 2]
#  [7 1 8]
#  [3 6 5]]
# present_do not add
#
# Down movement performed
# [[7 4 2]
#  [0 1 8]
#  [3 6 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 0 2]
#  [7 1 8]
#  [3 6 5]]
# present_do not add
#
# cannot perform Up movement
# [[4 2 0]
#  [7 1 8]
#  [3 6 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 2 0]
#  [7 1 8]
#  [3 6 5]]
# present_do not add
#
# Down movement performed
# [[4 2 8]
#  [7 1 0]
#  [3 6 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 0 1]
#  [7 8 2]
#  [3 6 5]]
# Not present_do add
#
# cannot perform Up movement
# [[4 1 0]
#  [7 8 2]
#  [3 6 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 1 0]
#  [7 8 2]
#  [3 6 5]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [7 8 0]
#  [3 6 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [7 8 5]
#  [3 0 6]]
# Not present_do add
#
# up movement performed
# [[4 1 2]
#  [7 8 0]
#  [3 6 5]]
# present_do not add
#
# cannot perform Right movement
# [[4 1 2]
#  [7 8 5]
#  [3 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[4 1 2]
#  [7 8 5]
#  [3 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 2]
#  [0 7 6]
#  [3 5 8]]
# Not present_do add
#
# up movement performed
# [[4 0 2]
#  [7 1 6]
#  [3 5 8]]
# Not present_do add
#
# right movement performed
# [[4 1 2]
#  [7 6 0]
#  [3 5 8]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [7 5 6]
#  [3 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[4 0 1]
#  [7 6 2]
#  [3 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[4 1 0]
#  [7 6 2]
#  [3 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[4 1 0]
#  [7 6 2]
#  [3 5 8]]
# present_do not add
#
# Down movement performed
# [[4 1 2]
#  [7 6 0]
#  [3 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[2 0 8]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Up movement
# [[2 8 0]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[2 8 0]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[2 8 6]
#  [1 4 0]
#  [7 3 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[2 4 8]
#  [0 1 6]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[2 0 8]
#  [1 4 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[2 4 8]
#  [1 6 0]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[2 4 8]
#  [1 3 6]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [0 7 6]
#  [3 4 5]]
# Not present_do add
#
# up movement performed
# [[1 0 8]
#  [7 2 6]
#  [3 4 5]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [7 6 0]
#  [3 4 5]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [7 4 6]
#  [3 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [7 4 6]
#  [3 0 5]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [7 4 0]
#  [3 5 6]]
# Not present_do add
#
# cannot perform Right movement
# [[1 2 8]
#  [7 4 6]
#  [3 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 8]
#  [7 4 6]
#  [3 5 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 8]
#  [0 2 6]
#  [7 3 5]]
# present_do not add
#
# up movement performed
# [[4 0 8]
#  [2 1 6]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[4 1 8]
#  [2 6 0]
#  [7 3 5]]
# Not present_do add
#
# Down movement performed
# [[4 1 8]
#  [2 3 6]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 8]
#  [7 2 6]
#  [0 3 5]]
# present_do not add
#
# up movement performed
# [[4 1 8]
#  [0 2 6]
#  [7 3 5]]
# present_do not add
#
# right movement performed
# [[4 1 8]
#  [7 2 6]
#  [3 0 5]]
# Not present_do add
#
# cannot perform Down movement
# [[4 1 8]
#  [7 2 6]
#  [0 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 8 6]
#  [4 2 5]
#  [7 0 3]]
# Not present_do add
#
# up movement performed
# [[1 8 6]
#  [4 2 0]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 8 6]
#  [4 2 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 8 6]
#  [4 2 5]
#  [7 3 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 8]
#  [1 3 6]
#  [4 7 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 8]
#  [1 3 6]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[2 0 8]
#  [1 3 6]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [0 3 6]
#  [4 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [0 3 6]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[1 0 8]
#  [3 2 6]
#  [4 7 5]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [3 6 0]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [3 7 6]
#  [4 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [0 4 3]
#  [7 5 6]]
# Not present_do add
#
# up movement performed
# [[1 0 8]
#  [4 2 3]
#  [7 5 6]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [4 3 0]
#  [7 5 6]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 5 3]
#  [7 0 6]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 2]
#  [4 3 8]
#  [7 5 6]]
# Not present_do add
#
# cannot perform Up movement
# [[1 2 0]
#  [4 3 8]
#  [7 5 6]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 0]
#  [4 3 8]
#  [7 5 6]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 3 0]
#  [7 5 6]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 8]
#  [1 6 5]
#  [4 7 3]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 8]
#  [1 6 5]
#  [4 7 3]]
# present_do not add
#
# right movement performed
# [[2 0 8]
#  [1 6 5]
#  [4 7 3]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [0 6 5]
#  [4 7 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [0 6 5]
#  [4 7 3]]
# present_do not add
#
# up movement performed
# [[1 0 8]
#  [6 2 5]
#  [4 7 3]]
# Not present_do add
#
# right movement performed
# [[1 2 8]
#  [6 5 0]
#  [4 7 3]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [6 7 5]
#  [4 0 3]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[0 2 8]
#  [1 4 5]
#  [7 6 3]]
# present_do not add
#
# cannot perform Up movement
# [[0 2 8]
#  [1 4 5]
#  [7 6 3]]
# present_do not add
#
# right movement performed
# [[2 0 8]
#  [1 4 5]
#  [7 6 3]]
# Not present_do add
#
# Down movement performed
# [[1 2 8]
#  [0 4 5]
#  [7 6 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 8]
#  [7 4 5]
#  [0 6 3]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [0 4 5]
#  [7 6 3]]
# present_do not add
#
# right movement performed
# [[1 2 8]
#  [7 4 5]
#  [6 0 3]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 8]
#  [7 4 5]
#  [0 6 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 1 8]
#  [4 2 5]
#  [7 6 3]]
# present_do not add
#
# cannot perform Up movement
# [[0 1 8]
#  [4 2 5]
#  [7 6 3]]
# present_do not add
#
# right movement performed
# [[1 0 8]
#  [4 2 5]
#  [7 6 3]]
# present_do not add
#
# Down movement performed
# [[4 1 8]
#  [0 2 5]
#  [7 6 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 8]
#  [4 2 5]
#  [7 6 3]]
# present_do not add
#
# cannot perform Up movement
# [[1 8 0]
#  [4 2 5]
#  [7 6 3]]
# present_do not add
#
# cannot perform Right movement
# [[1 8 0]
#  [4 2 5]
#  [7 6 3]]
# present_do not add
#
# Down movement performed
# [[1 8 5]
#  [4 2 0]
#  [7 6 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 2]
#  [4 5 8]
#  [7 6 3]]
# Not present_do add
#
# cannot perform Up movement
# [[1 2 0]
#  [4 5 8]
#  [7 6 3]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 0]
#  [4 5 8]
#  [7 6 3]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [4 5 0]
#  [7 6 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 8]
#  [4 5 3]
#  [7 0 6]]
# present_do not add
#
# up movement performed
# [[1 2 8]
#  [4 5 0]
#  [7 6 3]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 8]
#  [4 5 3]
#  [7 6 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 8]
#  [4 5 3]
#  [7 6 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 2 8]
#  [0 1 4]
#  [7 3 5]]
# Not present_do add
#
# up movement performed
# [[6 0 8]
#  [1 2 4]
#  [7 3 5]]
# Not present_do add
#
# right movement performed
# [[6 2 8]
#  [1 4 0]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 2 8]
#  [1 3 4]
#  [7 0 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 2 8]
#  [1 4 5]
#  [7 0 3]]
# Not present_do add
#
# up movement performed
# [[6 2 8]
#  [1 4 0]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[6 2 8]
#  [1 4 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[6 2 8]
#  [1 4 5]
#  [7 3 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 0 4]
#  [1 8 2]
#  [7 3 5]]
# Not present_do add
#
# cannot perform Up movement
# [[6 4 0]
#  [1 8 2]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[6 4 0]
#  [1 8 2]
#  [7 3 5]]
# present_do not add
#
# Down movement performed
# [[6 4 2]
#  [1 8 0]
#  [7 3 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 4 2]
#  [1 8 5]
#  [7 0 3]]
# Not present_do add
#
# up movement performed
# [[6 4 2]
#  [1 8 0]
#  [7 3 5]]
# present_do not add
#
# cannot perform Right movement
# [[6 4 2]
#  [1 8 5]
#  [7 3 0]]
# present_do not add
#
# cannot perform Down movement
# [[6 4 2]
#  [1 8 5]
#  [7 3 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[6 4 2]
#  [1 3 8]
#  [0 7 5]]
# present_do not add
#
# up movement performed
# [[6 4 2]
#  [0 3 8]
#  [1 7 5]]
# Not present_do add
#
# right movement performed
# [[6 4 2]
#  [1 3 8]
#  [7 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[6 4 2]
#  [1 3 8]
#  [0 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 4 2]
#  [1 3 8]
#  [7 0 5]]
# present_do not add
#
# up movement performed
# [[6 4 2]
#  [1 3 0]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[6 4 2]
#  [1 3 8]
#  [7 5 0]]
# present_do not add
#
# cannot perform Down movement
# [[6 4 2]
#  [1 3 8]
#  [7 5 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 6 2]
#  [1 7 8]
#  [3 4 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 6 2]
#  [1 7 8]
#  [3 4 5]]
# present_do not add
#
# right movement performed
# [[6 0 2]
#  [1 7 8]
#  [3 4 5]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [0 7 8]
#  [3 4 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [3 7 8]
#  [0 4 5]]
# present_do not add
#
# up movement performed
# [[1 6 2]
#  [0 7 8]
#  [3 4 5]]
# present_do not add
#
# right movement performed
# [[1 6 2]
#  [3 7 8]
#  [4 0 5]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [3 7 8]
#  [0 4 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[0 1 2]
#  [7 6 8]
#  [3 4 5]]
# present_do not add
#
# cannot perform Up movement
# [[0 1 2]
#  [7 6 8]
#  [3 4 5]]
# present_do not add
#
# right movement performed
# [[1 0 2]
#  [7 6 8]
#  [3 4 5]]
# present_do not add
#
# Down movement performed
# [[7 1 2]
#  [0 6 8]
#  [3 4 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 2]
#  [7 6 8]
#  [3 4 5]]
# present_do not add
#
# cannot perform Up movement
# [[1 2 0]
#  [7 6 8]
#  [3 4 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 0]
#  [7 6 8]
#  [3 4 5]]
# present_do not add
#
# Down movement performed
# [[1 2 8]
#  [7 6 0]
#  [3 4 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 0 6]
#  [7 8 2]
#  [3 4 5]]
# Not present_do add
#
# cannot perform Up movement
# [[1 6 0]
#  [7 8 2]
#  [3 4 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 6 0]
#  [7 8 2]
#  [3 4 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 8 0]
#  [3 4 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 8 5]
#  [3 0 4]]
# Not present_do add
#
# up movement performed
# [[1 6 2]
#  [7 8 0]
#  [3 4 5]]
# present_do not add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 8 5]
#  [3 4 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [7 8 5]
#  [3 4 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [0 7 4]
#  [3 5 8]]
# Not present_do add
#
# up movement performed
# [[1 0 2]
#  [7 6 4]
#  [3 5 8]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [7 4 0]
#  [3 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 5 4]
#  [3 0 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 0 6]
#  [7 4 2]
#  [3 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 6 0]
#  [7 4 2]
#  [3 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[1 6 0]
#  [7 4 2]
#  [3 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 4 0]
#  [3 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[4 1 6]
#  [0 8 2]
# ...
# [[6 2 5]
#  [1 0 8]
#  [4 7 3]]
# Not present_do add
#
# up movement performed
# [[6 2 0]
#  [1 8 5]
#  [4 7 3]]
# present_do not add
#
# cannot perform Right movement
# [[6 2 5]
#  [1 8 0]
#  [4 7 3]]
# present_do not add
#
# Down movement performed
# [[6 2 5]
#  [1 8 3]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[6 8 2]
#  [0 1 5]
#  [4 7 3]]
# present_do not add
#
# up movement performed
# [[0 8 2]
#  [6 1 5]
#  [4 7 3]]
# Not present_do add
#
# right movement performed
# [[6 8 2]
#  [1 0 5]
#  [4 7 3]]
# present_do not add
#
# Down movement performed
# [[6 8 2]
#  [4 1 5]
#  [0 7 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 8 2]
#  [1 0 5]
#  [4 7 3]]
# present_do not add
#
# up movement performed
# [[6 8 0]
#  [1 5 2]
#  [4 7 3]]
# Not present_do add
#
# cannot perform Right movement
# [[6 8 2]
#  [1 5 0]
#  [4 7 3]]
# present_do not add
#
# Down movement performed
# [[6 8 2]
#  [1 5 3]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 8 2]
#  [1 7 5]
#  [0 4 3]]
# Not present_do add
#
# up movement performed
# [[6 8 2]
#  [1 0 5]
#  [4 7 3]]
# present_do not add
#
# right movement performed
# [[6 8 2]
#  [1 7 5]
#  [4 3 0]]
# Not present_do add
#
# cannot perform Down movement
# [[6 8 2]
#  [1 7 5]
#  [4 0 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[8 1 2]
#  [0 6 5]
#  [4 7 3]]
# present_do not add
#
# up movement performed
# [[0 1 2]
#  [8 6 5]
#  [4 7 3]]
# present_do not add
#
# right movement performed
# [[8 1 2]
#  [6 0 5]
#  [4 7 3]]
# Not present_do add
#
# Down movement performed
# [[8 1 2]
#  [4 6 5]
#  [0 7 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 2 5]
#  [8 0 6]
#  [4 7 3]]
# Not present_do add
#
# up movement performed
# [[1 2 0]
#  [8 6 5]
#  [4 7 3]]
# present_do not add
#
# cannot perform Right movement
# [[1 2 5]
#  [8 6 0]
#  [4 7 3]]
# present_do not add
#
# Down movement performed
# [[1 2 5]
#  [8 6 3]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 6]
#  [8 5 2]
#  [4 7 3]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 6]
#  [8 5 2]
#  [4 7 3]]
# present_do not add
#
# right movement performed
# [[1 6 0]
#  [8 5 2]
#  [4 7 3]]
# present_do not add
#
# Down movement performed
# [[1 5 6]
#  [8 0 2]
#  [4 7 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [8 5 3]
#  [0 4 7]]
# Not present_do add
#
# up movement performed
# [[1 6 2]
#  [8 0 3]
#  [4 5 7]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [8 5 3]
#  [4 7 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [8 5 3]
#  [4 0 7]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 7 5]
#  [8 4 3]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 7 5]
#  [8 4 3]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [7 0 5]
#  [8 4 3]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [8 7 5]
#  [0 4 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [8 0 7]
#  [4 3 5]]
# Not present_do add
#
# up movement performed
# [[1 6 0]
#  [8 7 2]
#  [4 3 5]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [8 7 0]
#  [4 3 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [8 7 5]
#  [4 3 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 2 5]
#  [1 0 4]
#  [7 8 3]]
# Not present_do add
#
# up movement performed
# [[6 2 0]
#  [1 4 5]
#  [7 8 3]]
# present_do not add
#
# cannot perform Right movement
# [[6 2 5]
#  [1 4 0]
#  [7 8 3]]
# present_do not add
#
# Down movement performed
# [[6 2 5]
#  [1 4 3]
#  [7 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [7 6 5]
#  [8 4 3]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [7 6 5]
#  [8 4 3]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [7 6 5]
#  [8 4 3]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [7 0 5]
#  [8 4 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 0 5]
#  [8 4 3]]
# present_do not add
#
# up movement performed
# [[1 6 0]
#  [7 5 2]
#  [8 4 3]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 5 0]
#  [8 4 3]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 5 3]
#  [8 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 0 4]
#  [8 3 5]]
# Not present_do add
#
# up movement performed
# [[1 6 0]
#  [7 4 2]
#  [8 3 5]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 4 0]
#  [8 3 5]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 4 5]
#  [8 3 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 5]
#  [0 4 6]
#  [7 8 3]]
# present_do not add
#
# up movement performed
# [[0 2 5]
#  [1 4 6]
#  [7 8 3]]
# Not present_do add
#
# right movement performed
# [[1 2 5]
#  [4 0 6]
#  [7 8 3]]
# present_do not add
#
# Down movement performed
# [[1 2 5]
#  [7 4 6]
#  [0 8 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 5]
#  [4 2 6]
#  [7 8 3]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 5]
#  [4 2 6]
#  [7 8 3]]
# present_do not add
#
# right movement performed
# [[1 5 0]
#  [4 2 6]
#  [7 8 3]]
# Not present_do add
#
# Down movement performed
# [[1 2 5]
#  [4 0 6]
#  [7 8 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 5]
#  [4 8 6]
#  [0 7 3]]
# Not present_do add
#
# up movement performed
# [[1 2 5]
#  [4 0 6]
#  [7 8 3]]
# present_do not add
#
# right movement performed
# [[1 2 5]
#  [4 8 6]
#  [7 3 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 5]
#  [4 8 6]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 5]
#  [4 6 3]
#  [0 7 8]]
# Not present_do add
#
# up movement performed
# [[1 2 5]
#  [4 0 3]
#  [7 6 8]]
# Not present_do add
#
# right movement performed
# [[1 2 5]
#  [4 6 3]
#  [7 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 2 5]
#  [4 6 3]
#  [7 0 8]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[4 1 6]
#  [0 5 2]
#  [7 8 3]]
# present_do not add
#
# up movement performed
# [[0 1 6]
#  [4 5 2]
#  [7 8 3]]
# present_do not add
#
# right movement performed
# [[4 1 6]
#  [5 0 2]
#  [7 8 3]]
# Not present_do add
#
# Down movement performed
# [[4 1 6]
#  [7 5 2]
#  [0 8 3]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 5 6]
#  [0 4 2]
#  [7 8 3]]
# present_do not add
#
# up movement performed
# [[0 5 6]
#  [1 4 2]
#  [7 8 3]]
# Not present_do add
#
# right movement performed
# [[1 5 6]
#  [4 0 2]
#  [7 8 3]]
# present_do not add
#
# Down movement performed
# [[1 5 6]
#  [7 4 2]
#  [0 8 3]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 5 6]
#  [4 0 2]
#  [7 8 3]]
# present_do not add
#
# up movement performed
# [[1 5 0]
#  [4 2 6]
#  [7 8 3]]
# present_do not add
#
# cannot perform Right movement
# [[1 5 6]
#  [4 2 0]
#  [7 8 3]]
# present_do not add
#
# Down movement performed
# [[1 5 6]
#  [4 2 3]
#  [7 8 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 5 6]
#  [4 8 2]
#  [0 7 3]]
# Not present_do add
#
# up movement performed
# [[1 5 6]
#  [4 0 2]
#  [7 8 3]]
# present_do not add
#
# right movement performed
# [[1 5 6]
#  [4 8 2]
#  [7 3 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 5 6]
#  [4 8 2]
#  [7 0 3]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[6 2 8]
#  [0 1 3]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[0 2 8]
#  [6 1 3]
#  [4 7 5]]
# Not present_do add
#
# right movement performed
# [[6 2 8]
#  [1 0 3]
#  [4 7 5]]
# present_do not add
#
# Down movement performed
# [[6 2 8]
#  [4 1 3]
#  [0 7 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 6 8]
#  [1 2 3]
#  [4 7 5]]
# Not present_do add
#
# cannot perform Up movement
# [[6 0 8]
#  [1 2 3]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[6 8 0]
#  [1 2 3]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[6 2 8]
#  [1 0 3]
#  [4 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 2 8]
#  [1 7 3]
#  [0 4 5]]
# Not present_do add
#
# up movement performed
# [[6 2 8]
#  [1 0 3]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[6 2 8]
#  [1 7 3]
#  [4 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[6 2 8]
#  [1 7 3]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 2 8]
#  [1 3 5]
#  [0 4 7]]
# Not present_do add
#
# up movement performed
# [[6 2 8]
#  [1 0 5]
#  [4 3 7]]
# Not present_do add
#
# right movement performed
# [[6 2 8]
#  [1 3 5]
#  [4 7 0]]
# present_do not add
# cannot perform Down movement
# [[6 2 8]
#  [1 3 5]
#  [4 0 7]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 3 2]
#  [6 1 8]
#  [4 7 5]]
# present_do not add
#
# cannot perform Up movement
# [[3 0 2]
#  [6 1 8]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[3 2 0]
#  [6 1 8]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[3 1 2]
#  [6 0 8]
#  [4 7 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 3 2]
#  [4 1 8]
#  [0 7 5]]
# present_do not add
#
# up movement performed
# [[6 3 2]
#  [4 0 8]
#  [7 1 5]]
# Not present_do add
#
# right movement performed
# [[6 3 2]
#  [4 1 8]
#  [7 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[6 3 2]
#  [4 1 8]
#  [7 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 6 3]
#  [1 8 2]
#  [4 7 5]]
# Not present_do add
#
# cannot perform Up movement
# [[6 0 3]
#  [1 8 2]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[6 3 0]
#  [1 8 2]
#  [4 7 5]]
# present_do not add
#
# Down movement performed
# [[6 8 3]
#  [1 0 2]
#  [4 7 5]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 3 2]
#  [1 8 5]
#  [0 4 7]]
# Not present_do add
#
# up movement performed
# [[6 3 2]
#  [1 0 5]
#  [4 8 7]]
# Not present_do add
#
# right movement performed
# [[6 3 2]
#  [1 8 5]
#  [4 7 0]]
# present_do not add
#
# cannot perform Down movement
# [[6 3 2]
#  [1 8 5]
#  [4 0 7]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[6 3 2]
#  [0 7 8]
#  [1 4 5]]
# present_do not add
#
# up movement performed
# [[0 3 2]
#  [6 7 8]
#  [1 4 5]]
# Not present_do add
#
# right movement performed
# [[6 3 2]
#  [7 0 8]
#  [1 4 5]]
# Not present_do add
#
# Down movement performed
# [[6 3 2]
#  [1 7 8]
#  [0 4 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[6 3 2]
#  [1 0 7]
#  [4 5 8]]
# Not present_do add
#
# up movement performed
# [[6 3 0]
#  [1 7 2]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Right movement
# [[6 3 2]
#  [1 7 0]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[6 3 2]
#  [1 7 8]
#  [4 5 0]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[3 1 2]
#  [6 0 8]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[3 1 0]
#  [6 8 2]
#  [4 7 5]]
# Not present_do add
#
# cannot perform Right movement
# [[3 1 2]
#  [6 8 0]
#  [4 7 5]]
# present_do not add
#
# Down movement performed
# [[3 1 2]
#  [6 8 5]
#  [4 7 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[3 1 2]
#  [6 7 8]
#  [0 4 5]]
# Not present_do add
#
# up movement performed
# [[3 1 2]
#  [6 0 8]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[3 1 2]
#  [6 7 8]
#  [4 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[3 1 2]
#  [6 7 8]
#  [4 0 5]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[3 1 2]
#  [4 6 8]
#  [0 7 5]]
# present_do not add
#
# up movement performed
# [[3 1 2]
#  [4 0 8]
#  [7 6 5]]
# Not present_do add
#
# right movement performed
# [[3 1 2]
#  [4 6 8]
#  [7 5 0]]
# Not present_do add
#
# cannot perform Down movement
# [[3 1 2]
#  [4 6 8]
#  [7 0 5]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[3 1 6]
#  [0 8 2]
#  [4 7 5]]
# present_do not add
#
# up movement performed
# [[0 1 6]
#  [3 8 2]
#  [4 7 5]]
# present_do not add
#
# right movement performed
# [[3 1 6]
#  [8 0 2]
#  [4 7 5]]
# Not present_do add
#
# Down movement performed
# [[3 1 6]
#  [4 8 2]
#  [0 7 5]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 8 5]
#  [3 4 7]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 8 5]
#  [3 4 7]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [8 0 5]
#  [3 4 7]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [3 8 5]
#  [0 4 7]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 3 5]
#  [4 8 7]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 3 5]
#  [4 8 7]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [3 0 5]
#  [4 8 7]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 3 5]
#  [0 8 7]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [3 6 5]
#  [4 8 7]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [3 6 5]
#  [4 8 7]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [3 6 5]
#  [4 8 7]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [3 0 5]
#  [4 8 7]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [3 0 5]
#  [4 8 7]]
# present_do not add
#
# up movement performed
# [[1 6 0]
#  [3 5 2]
#  [4 8 7]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [3 5 0]
#  [4 8 7]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [3 5 7]
#  [4 8 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 3 7]
#  [4 5 8]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 3 7]
#  [4 5 8]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [3 0 7]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [4 3 7]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [3 6 7]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [3 6 7]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [3 6 7]
#  [4 5 8]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [3 0 7]
#  [4 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [3 5 7]
#  [0 4 8]]
# Not present_do add
#
# up movement performed
# [[1 6 2]
#  [3 0 7]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 6 2]
#  [3 5 7]
#  [4 8 0]]
# present_do not add
#
# cannot perform Down movement
# [[1 6 2]
#  [3 5 7]
#  [4 0 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[0 1 6]
#  [3 7 2]
#  [4 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 6]
#  [3 7 2]
#  [4 5 8]]
# present_do not add
#
# right movement performed
# [[1 6 0]
#  [3 7 2]
#  [4 5 8]]
# present_do not add
#
# Down movement performed
# [[1 7 6]
#  [3 0 2]
#  [4 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[6 2 3]
#  [1 0 4]
#  [7 5 8]]
# Not present_do add
#
# up movement performed
# [[6 2 0]
#  [1 4 3]
#  [7 5 8]]
# present_do not add
#
# cannot perform Right movement
# [[6 2 3]
#  [1 4 0]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[6 2 3]
#  [1 4 8]
#  [7 5 0]]
# Not present_do add
#
# Next Iteration
#
# cannot perform left movement
# [[1 6 2]
#  [0 7 3]
#  [5 4 8]]
# present_do not add
#
# up movement performed
# [[0 6 2]
#  [1 7 3]
#  [5 4 8]]
# Not present_do add
#
# right movement performed
# [[1 6 2]
#  [7 0 3]
#  [5 4 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [5 7 3]
#  [0 4 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 2]
#  [7 6 3]
#  [5 4 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 2]
#  [7 6 3]
#  [5 4 8]]
# present_do not add
#
# right movement performed
# [[1 2 0]
#  [7 6 3]
#  [5 4 8]]
# Not present_do add
#
# Down movement performed
# [[1 6 2]
#  [7 0 3]
#  [5 4 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 0 3]
#  [5 4 8]]
# present_do not add
#
# up movement performed
# [[1 6 0]
#  [7 3 2]
#  [5 4 8]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 3 0]
#  [5 4 8]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 3 8]
#  [5 4 0]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[1 6 2]
#  [7 0 4]
#  [5 8 3]]
# Not present_do add
#
# up movement performed
# [[1 6 0]
#  [7 4 2]
#  [5 8 3]]
# Not present_do add
#
# cannot perform Right movement
# [[1 6 2]
#  [7 4 0]
#  [5 8 3]]
# present_do not add
#
# Down movement performed
# [[1 6 2]
#  [7 4 3]
#  [5 8 0]]
# present_do not add
#
# Next Iteration
#
# cannot perform left movement
# [[1 2 3]
#  [0 4 6]
#  [7 5 8]]
# present_do not add
#
# up movement performed
# [[0 2 3]
#  [1 4 6]
#  [7 5 8]]
# Not present_do add
#
# right movement performed
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[1 2 3]
#  [7 4 6]
#  [0 5 8]]
# Not present_do add
#
# Next Iteration
#
# left movement performed
# [[0 1 3]
#  [4 2 6]
#  [7 5 8]]
# Not present_do add
#
# cannot perform Up movement
# [[1 0 3]
#  [4 2 6]
#  [7 5 8]]
# present_do not add
#
# right movement performed
# [[1 3 0]
#  [4 2 6]
#  [7 5 8]]
# present_do not add
#
# Down movement performed
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
# present_do not add
#
# Next Iteration
#
# left movement performed
# [[1 2 3]
#  [4 5 6]
#  [0 7 8]]
# Not present_do add
#
# up movement performed
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
# present_do not add
#
# right movement performed
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
# Not present_do add
#
# cannot perform Down movement
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
# present_do not add
#
# Next Iteration

# %%
clean_AllNodes(AllNodes)

# %%
print(ParentNodes)
# Out:
# {1: 0, 2: 1, 3: 1, 4: 1, 5: 2, 6: 3, 7: 4, 8: 4, 9: 4, 10: 5, 11: 5, 12: 6, 13: 6, 14: 7, 15: 7, 16: 8, 17: 8, 18: 9, 19: 9, 20: 10, 21: 10, 22: 10, 23: 11, 24: 12, 25: 12, 26: 12, 27: 13, 28: 14, 29: 15, 30: 16, 31: 17, 32: 18, 33: 19, 34: 20, 35: 20, 36: 21, 37: 21, 38: 22, 39: 22, 40: 23, 41: 23, 42: 24, 43: 24, 44: 25, 45: 25, 46: 26, 47: 26, 48: 27, 49: 27, 50: 28, 51: 28, 52: 29, 53: 29, 54: 30, 55: 30, 56: 31, 57: 31, 58: 32, 59: 32, 60: 33, 61: 33, 62: 34, 63: 35, 64: 36, 65: 37, 66: 38, 67: 39, 68: 40, 69: 40, 70: 40, 71: 41, 72: 42, 73: 43, 74: 44, 75: 45, 76: 46, 77: 47, 78: 48, 79: 49, 80: 49, 81: 49, 82: 50, 83: 51, 84: 51, 85: 52, 86: 52, 87: 52, 88: 53, 89: 54, 90: 55, 91: 55, 92: 56, 93: 57, 94: 57, 95: 57, 96: 58, 97: 59, 98: 59, 99: 59, 100: 60, 101: 60, 102: 60, 103: 61, 104: 62, 105: 63, 106: 63, 107: 64, 108: 64, 109: 65, 110: 65, 111: 66, 112: 66, 113: 67, 114: 67, 115: 68, 116: 68, 117: 69, 118: 69, 119: 70, 120: 70, 121: 71, 122: 71, 123: 72, 124: 72, 125: 73, 126: 73, 127: 74, 128: 74, 129: 75, 130: 76, 131: 76, 132: 77, 133: 77, 134: 78, 135: 78, 136: 79, 137: 79, 138: 80, 139: 80, 140: 81, 141: 81, 142: 82, 143: 82, 144: 83, 145: 83, 146: 84, 147: 84, 148: 85, 149: 85, 150: 86, 151: 86, 152: 87, 153: 87, 154: 88, 155: 88, 156: 89, 157: 89, 158: 90, 159: 90, 160: 91, 161: 91, 162: 92, 163: 92, 164: 93, 165: 93, 166: 94, 167: 94, 168: 95, 169: 95, 170: 96, 171: 96, 172: 97, 173: 97, 174: 98, 175: 98, 176: 99, 177: 100, 178: 100, 179: 101, 180: 101, 181: 102, 182: 103, 183: 103, 184: 104, 185: 105, 186: 105, 187: 105, 188: 106, 189: 107, 190: 108, 191: 108, 192: 108, 193: 109, 194: 110, 195: 110, 196: 110, 197: 111, 198: 112, 199: 112, 200: 112, 201: 113, 202: 113, 203: 113, 204: 114, 205: 115, 206: 117, 207: 118, 208: 119, 209: 120, 210: 121, 211: 121, 212: 121, 213: 122, 214: 123, 215: 124, 216: 124, 217: 124, 218: 125, 219: 125, 220: 125, 221: 126, 222: 127, 223: 127, 224: 127, 225: 128, 226: 129, 227: 130, 228: 131, 229: 131, 230: 131, 231: 132, 232: 132, 233: 132, 234: 133, 235: 134, 236: 135, 237: 135, 238: 135, 239: 136, 240: 137, 241: 138, 242: 139, 243: 140, 244: 142, 245: 142, 246: 142, 247: 143, 248: 144, 249: 145, 250: 146, 251: 147, 252: 148, 253: 150, 254: 152, 255: 153, 256: 154, 257: 154, 258: 154, 259: 155, 260: 156, 261: 156, 262: 156, 263: 157, 264: 158, 265: 159, 266: 160, 267: 161, 268: 162, 269: 163, 270: 163, 271: 163, 272: 164, 273: 165, 274: 167, 275: 168, 276: 170, 277: 171, 278: 171, 279: 171, 280: 172, 281: 174, 282: 175, 283: 176, 284: 177, 285: 178, 286: 180, 287: 181, 288: 182, 289: 183, 290: 183, 291: 183, 292: 184, 293: 184, 294: 185, 295: 185, 296: 186, 297: 186, 298: 187, 299: 187, 300: 188, 301: 188, 302: 189, 303: 189, 304: 190, 305: 190, 306: 191, 307: 192, 308: 192, 309: 193, 310: 193, 311: 194, 312: 195, 313: 195, 314: 196, 315: 196, 316: 197, 317: 197, 318: 198, 319: 198, 320: 199, 321: 199, 322: 200, 323: 201, 324: 202, 325: 202, 326: 203, 327: 204, 328: 204, 329: 205, 330: 205, 331: 206, 332: 206, 333: 207, 334: 207, 335: 208, 336: 208, 337: 209, 338: 209, 339: 210, 340: 210, 341: 211, 342: 211, 343: 212, 344: 212, 345: 213, 346: 213, 347: 214, 348: 214, 349: 215, 350: 215, 351: 216, 352: 216, 353: 217, 354: 217, 355: 218, 356: 218, 357: 219, 358: 219, 359: 220, 360: 221, 361: 221, 362: 222, 363: 223, 364: 223, 365: 224, 366: 224, 367: 225, 368: 225, 369: 226, 370: 226, 371: 227, 372: 227, 373: 228, 374: 228, 375: 229, 376: 230, 377: 231, 378: 231, 379: 232, 380: 232, 381: 233, 382: 234, 383: 234, 384: 235, 385: 235, 386: 236, 387: 236, 388: 237, 389: 237, 390: 238, 391: 238, 392: 239, 393: 239, 394: 240, 395: 240, 396: 241, 397: 241, 398: 242, 399: 242, 400: 243, 401: 243, 402: 244, 403: 244, 404: 245, 405: 245, 406: 246, 407: 246, 408: 247, 409: 247, 410: 248, 411: 248, 412: 249, 413: 249, 414: 250, 415: 250, 416: 251, 417: 251, 418: 252, 419: 252, 420: 253, 421: 253, 422: 254, 423: 254, 424: 255, 425: 255, 426: 256, 427: 256, 428: 257, 429: 257, 430: 258, 43 ...

# %%
print(AllNodes)
# Out:
# {1: array([[1, 0, 2],
#        [4, 6, 8],
#        [7, 3, 5]]), 2: array([[0, 1, 2],
#        [4, 6, 8],
#        [7, 3, 5]]), 3: array([[1, 2, 0],
#        [4, 6, 8],
#        [7, 3, 5]]), 4: array([[1, 6, 2],
#        [4, 0, 8],
#        [7, 3, 5]]), 5: array([[4, 1, 2],
#        [0, 6, 8],
#        [7, 3, 5]]), 6: array([[1, 2, 8],
#        [4, 6, 0],
#        [7, 3, 5]]), 7: array([[1, 6, 2],
#        [0, 4, 8],
#        [7, 3, 5]]), 8: array([[1, 6, 2],
#        [4, 8, 0],
#        [7, 3, 5]]), 9: array([[1, 6, 2],
#        [4, 3, 8],
#        [7, 0, 5]]), 10: array([[4, 1, 2],
#        [6, 0, 8],
#        [7, 3, 5]]), 11: array([[4, 1, 2],
#        [7, 6, 8],
#        [0, 3, 5]]), 12: array([[1, 2, 8],
#        [4, 0, 6],
#        [7, 3, 5]]), 13: array([[1, 2, 8],
#        [4, 6, 5],
#        [7, 3, 0]]), 14: array([[0, 6, 2],
#        [1, 4, 8],
#        [7, 3, 5]]), 15: array([[1, 6, 2],
#        [7, 4, 8],
#        [0, 3, 5]]), 16: array([[1, 6, 0],
#        [4, 8, 2],
#        [7, 3, 5]]), 17: array([[1, 6, 2],
#        [4, 8, 5],
#        [7, 3, 0]]), 18: array([[1, 6, 2],
#        [4, 3, 8],
#        [0, 7, 5]]), 19: array([[1, 6, 2],
#        [4, 3, 8],
#        [7, 5, 0]]), 20: array([[4, 0, 2],
#        [6, 1, 8],
#        [7, 3, 5]]), 21: array([[4, 1, 2],
#        [6, 8, 0],
#        [7, 3, 5]]), 22: array([[4, 1, 2],
#        [6, 3, 8],
#        [7, 0, 5]]), 23: array([[4, 1, 2],
#        [7, 6, 8],
#        [3, 0, 5]]), 24: array([[1, 2, 8],
#        [0, 4, 6],
#        [7, 3, 5]]), 25: array([[1, 0, 8],
#        [4, 2, 6],
#        [7, 3, 5]]), 26: array([[1, 2, 8],
#        [4, 3, 6],
#        [7, 0, 5]]), 27: array([[1, 2, 8],
#        [4, 6, 5],
#        [7, 0, 3]]), 28: array([[6, 0, 2],
#        [1, 4, 8],
#        [7, 3, 5]]), 29: array([[1, 6, 2],
#        [7, 4, 8],
#        [3, 0, 5]]), 30: array([[1, 0, 6],
#        [4, 8, 2],
#        [7, 3, 5]]), 31: array([[1, 6, 2],
#        [4, 8, 5],
#        [7, 0, 3]]), 32: array([[1, 6, 2],
#        [0, 3, 8],
#        [4, 7, 5]]), 33: array([[1, 6, 2],
#        [4, 3, 0],
#        [7, 5, 8]]), 34: array([[0, 4, 2],
#        [6, 1, 8],
#        [7, 3, 5]]), 35: array([[4, 2, 0],
#        [6, 1, 8],
#        [7, 3, 5]]), 36: array([[4, 1, 0],
#        [6, 8, 2],
#        [7, 3, 5]]), 37: array([[4, 1, 2],
#        [6, 8, 5],
#        [7, 3, 0]]), 38: array([[4, 1, 2],
#        [6, 3, 8],
#        [0, 7, 5]]), 39: array([[4, 1, 2],
#        [6, 3, 8],
#        [7, 5, 0]]), 40: array([[4, 1, 2],
#        [7, 0, 8],
#        [3, 6, 5]]), 41: array([[4, 1, 2],
#        [7, 6, 8],
#        [3, 5, 0]]), 42: array([[0, 2, 8],
#        [1, 4, 6],
#        [7, 3, 5]]), 43: array([[1, 2, 8],
#        [7, 4, 6],
#        [0, 3, 5]]), 44: array([[0, 1, 8],
#        [4, 2, 6],
#        [7, 3, 5]]), 45: array([[1, 8, 0],
#        [4, 2, 6],
#        [7, 3, 5]]), 46: array([[1, 2, 8],
#        [4, 3, 6],
#        [0, 7, 5]]), 47: array([[1, 2, 8],
#        [4, 3, 6],
#        [7, 5, 0]]), 48: array([[1, 2, 8],
#        [4, 6, 5],
#        [0, 7, 3]]), 49: array([[1, 2, 8],
#        [4, 0, 5],
#        [7, 6, 3]]), 50: array([[6, 2, 0],
#        [1, 4, 8],
#        [7, 3, 5]]), 51: array([[6, 4, 2],
#        [1, 0, 8],
#        [7, 3, 5]]), 52: array([[1, 6, 2],
#        [7, 0, 8],
#        [3, 4, 5]]), 53: array([[1, 6, 2],
#        [7, 4, 8],
#        [3, 5, 0]]), 54: array([[0, 1, 6],
#        [4, 8, 2],
#        [7, 3, 5]]), 55: array([[1, 8, 6],
#        [4, 0, 2],
#        [7, 3, 5]]), 56: array([[1, 6, 2],
#        [4, 8, 5],
#        [0, 7, 3]]), 57: array([[1, 6, 2],
#        [4, 0, 5],
#        [7, 8, 3]]), 58: array([[0, 6, 2],
#        [1, 3, 8],
#        [4, 7, 5]]), 59: array([[1, 6, 2],
#        [3, 0, 8],
#        [4, 7, 5]]), 60: array([[1, 6, 2],
#        [4, 0, 3],
#        [7, 5, 8]]), 61: array([[1, 6, 0],
#        [4, 3, 2],
#        [7, 5, 8]]), 62: array([[6, 4, 2],
#        [0, 1, 8],
#        [7, 3, 5]]), 63: array([[4, 2, 8],
#        [6, 1, 0],
#        [7, 3, 5]]), 64: array([[4, 0, 1],
#        [6, 8, 2],
#        [7, 3, 5]]), 65: array([[4, 1, 2],
#        [6, 8, 5],
#        [7, 0, 3]]), 66: array([[4, 1, 2],
#        [0, 3, 8],
#        [6, 7, 5]]), 67: array([[4, 1, 2],
#        [6, 3, 0],
#        [7, 5, 8]]), 68: array([[4, 1, 2],
#        [0, 7, 8],
#        [3, 6, 5]]), 69: array([[4, 0, 2],
#        [7, 1, 8],
#        [3, 6, 5]]), 70: array([[4, 1, 2],
#        [7, 8, 0],
#        [3, 6, 5]]), 71: array([[4, 1, 2],
#        [7, 6, 0],
#        [3, 5, 8]]), 72: array([[2, 0, 8],
#        [1, 4, 6],
#        [7, 3, 5]]), 73: array([[1, 2, 8],
#        [7, 4, 6],
#        [3, 0, 5]]), 74: array([[4, 1, 8],
#        [0, 2, 6],
#        [7, 3, 5]]), 75: array([[1, 8, 6],
#        [4, 2, 0],
#        [7, 3, 5]]), 76: array([[1, 2, 8],
#        [0, 3, 6],
#        [4, 7, 5]]), 77: array([[1, 2, 8],
#        [4, 3, 0],
#        [7, 5, 6]]), 78: array([[1, 2, 8],
#        [0, 6, 5],
#        [4, 7, 3]]), 79: array([[1, 2, 8],
#        [0, 4, 5],
#        [7, 6, 3]]), 80: array([[1, 0, 8],
#        [4, 2, 5],
#        [7, 6, 3]]), 81: array([[1, 2, 8],
#        [4, 5, 0],
#        [7, 6, 3]]), 82: array([[6, 2, 8],
#        [1, 4, 0],
#        [7, 3, 5]]), 83: array([[6, 4, 2],
#        [1, 8, 0],
#        [7, 3, 5]]), 84: array([[6, 4, 2],
#        [1, 3, 8],
#        [7, 0, 5]]), 85: array([[1, 6, 2],
#        [0, 7, 8],
#        [3, 4, 5]]), 86: array([[1, 0, 2],
#        [7, 6, 8],
#        [3, 4, 5]]), 87: array([[1, 6, 2],
#        [7, 8, 0],
#        [3, 4, 5]]), 88: array([[1, 6, 2],
#        [7, 4, 0],
#        [3, 5, 8]]), 89: array([[4, 1, 6],
#        [0, 8, 2],
#        [7, 3, 5]]), 90: array([[1, 8, 6],
#        [0, 4, 2],
#        [7, 3, 5]]), 91: array([[1, 8, 6],
#        [4, 3, 2],
#        [7, 0, 5]]), 92: array([[1, 6, 2],
#        [0, 8, 5],
#        [4, 7, 3]]), 93: array([[1, 6, 2],
#        [0, 4, 5],
#        [7, 8, 3]]), 94: array([[1, 0, 2],
#        [4, 6, 5],
#        [7, 8, 3]]), 95: array([[1, 6, 2],
#        [4, 5, 0],
#        [7, 8, 3]]), 96: array([[6, 0, 2],
#        [1, 3, 8],
#        [4, 7, 5]]), 97: array([[1, 0, 2],
#        [3, 6, 8],
#        [4, 7, 5]]), 98: array([[1, 6, 2],
#        [3, 8, 0],
#        [4, 7, 5]]), 99: array([[1, 6, 2],
#        [3, 7, 8],
#        [4, 0, 5]]), 100: array([[1, 6, 2],
#        [0, 4, 3],
#        [7, 5, 8]]), 101: array([[1, 0, 2],
#        [4, 6, 3],
#        [7, 5, 8]]), 102: array([[1, 6, 2],
#        [4, 5, 3],
#        [7, 0, 8]]), 103: array([[1, 0, 6],
#        [4, 3, 2],
#        [7, 5, 8]]), 104: array([[6, 4, 2],
#        [7, 1, 8],
#        [0, 3, 5]]), 105: array([[4, 2, 8],
#        [6, 0, 1],
#        [7, 3, 5]]), 106: array([[4, 2, 8],
#        [6, 1, 5],
#        [7, 3, 0]]), 107: array([[0, 4, 1],
#        [6, 8, 2],
#        [7, 3, 5]]), 108: array([[4, 8, 1],
#        [6, 0, 2],
#        [7, 3, 5]]), 109: array([[4, 1, 2],
#        [6, 8, 5],
#        [0, 7, 3]]), 110: array([[4, 1, 2],
#        [6, 0, 5],
#        [7, 8, 3]]), 111: array([[0, 1, 2],
#        [4, 3, 8],
#        [6, 7, 5]]), 112: array([[4, 1, 2],
#        [3, 0, 8],
#        [6, 7, 5]]), 113: array([[4, 1, 2],
#        [6, 0, 3],
#        [7, 5, 8]]), 114: array([[4, 1, 0],
#        [6, 3, 2],
#        [7, 5, 8]]), 115: array([[0, 1, 2],
#        [4, 7, 8],
#        [3, 6, 5]]), 116: array([[4, 1, 2],
#        [3, 7, 8],
#        [0, 6, 5]]), 117: array([[0, 4, 2],
#        [7, 1, 8],
#        [3, 6, 5]]), 118: array([[4, 2, 0],
#        [7, 1, 8],
#        [3, 6, 5]]), 119: array([[4, 1, 0],
#        [7, 8, 2],
#        [3, 6, 5]]), 120: array([[4, 1, 2],
#        [7, 8, 5],
#        [3, 6, 0]]), 121: array([[4, 1, 2],
#        [7, 0, 6],
#        [3, 5, 8]]), 122: array([[4, 1, 0],
#        [7, 6, 2],
#        [3, 5, 8]]), 123: array([[2, 8, 0],
#        [1, 4, 6],
#        [7, 3, 5]]), 124: array([[2, 4, 8],
#        [1, 0, 6],
#        [7, 3, 5]]), 125: array([[1, 2, 8],
#        [7, 0, 6],
#        [3, 4, 5]]), 126: array([[1, 2, 8],
#        [7, 4, 6],
#        [3, 5, 0]]), 127: array([[4, 1, 8],
#        [2, 0, 6],
#        [7, 3, 5]]), 128: array([[4, 1, 8],
#        [7, 2, 6],
#        [0, 3, 5]]), 129: array([[1, 8, 6],
#        [4, 2, 5],
#        [7, 3, 0]]), 130: array([[0, 2, 8],
#        [1, 3, 6],
#        [4, 7, 5]]), 131: array([[1, 2, 8],
#        [3, 0, 6],
#        [4, 7, 5]]), 132: array([[1, 2, 8],
#        [4, 0, 3],
#        [7, 5, 6]]), 133: array([[1, 2, 0],
#        [4, 3, 8],
#        [7, 5, 6]]), 134: array([[0, 2, 8],
#        [1, 6, 5],
#        [4, 7, 3]]), 135: array([[1, 2, 8],
#        [6, 0, 5],
#        [4, 7, 3]]), 136: array([[0, 2, 8],
#        [1, 4, 5],
#        [7, 6, 3]]), 137: array([[1, 2, 8],
#        [7, 4, 5],
#        [0, 6, 3]]), 138: array([[0, 1, 8],
#        [4, 2, 5],
#        [7, 6, 3]]), 139: array([[1, 8, 0],
#        [4, 2, 5],
#        [7, 6, 3]]), 140: array([[1, 2, 0],
#        [4, 5, 8],
#        [7, 6, 3]]), 141: array([[1, 2, 8],
#        [4, 5, 3],
#        [7, 6, 0]]), 142: array([[6, 2, 8],
#        [1, 0, 4],
#        [7, 3, 5]]), 143: array([[6, 2, 8],
#        [1, 4, 5],
#        [7, 3, 0]]), 144: array([[6, 4, 0],
#        [1, 8, 2],
#        [7, 3, 5]]), 145: array([[6, 4, 2],
#        [1, 8, 5],
#        [7, 3, 0]]), 146: array([[6, 4, 2],
#        [1, 3, 8],
#        [0, 7, 5]]), 147: array([[6, 4, 2],
#        [1, 3, 8],
#        [7, 5, 0]]), 148: array([[0, 6, 2],
#        [1, 7, 8],
#        [3, 4, 5]]), 149: array([[1, 6, 2],
#        [3, 7, 8],
#        [0, 4, 5]]), 150: array([[0, 1, 2],
#        [7, 6, 8],
#        [3, 4, 5]]), 151: array([[1, 2, 0],
#        [7, 6, 8],
#        [3, 4, 5]]), 152: array([[1, 6, 0],
#        [7, 8, 2],
#        [3, 4, 5]]), 153: array([[1, 6, 2],
#        [7, 8, 5],
#        [3, 4, 0]]), 154: array([[1, 6, 2],
#        [7, 0, 4],
#        [3, 5, 8]]), 155: array([[1, 6, 0],
#        [7, 4, 2],
#        [3, 5, 8]]), 156: array([[4, 1, 6],
#        [8, 0, 2],
#        [7, 3, 5]]), 157: array([[4, 1, 6],
#        [7, 8, 2],
#        [0, 3, 5]]), 158: array([[0, 8, 6],
#        [1, 4, 2],
#        [7, 3, 5]]), 159: array([[1, 8, 6],
#        [7, 4, 2],
#        [0, 3, 5]]), 160: array([[1, 8, 6],
#        [4, 3, 2],
#        [0, 7, 5]]), 161: array([[1, 8, 6],
#        [4, 3, 2],
#        [7, 5, 0]]), 162: array([[0, 6, 2],
#        [1, 8, 5],
#        [4, 7, 3]]), 163: array([[1, 6, 2],
#        [8, 0, 5],
#        [4, 7, 3]]), 164: array([[0, 6, 2],
#        [1, 4, 5],
#        [7, 8, 3]]), 165: array([[1, 6, 2],
#        [7, 4, 5],
#        [0, 8, 3]]), 166: array([[0, 1, 2],
#        [4, 6, 5],
#        [7, 8, 3]]), 167: array([[1, 2, 0],
#        [4, 6, 5],
#        [7, 8, 3]]), 168: array([[1, 6, 0],
#        [4, 5, 2],
#        [7, 8, 3]]), 169: array([[1, 6, 2],
#        [4, 5, 3],
#        [7, 8, 0]]), 170: array([[6, 2, 0],
#        [1, 3, 8],
#        [4, 7, 5]]), 171: array([[6, 3, 2],
#        [1, 0, 8],
#        [4, 7, 5]]), 172: array([[0, 1, 2],
#        [3, 6, 8],
#        [4, 7, 5]]), 173: array([[1, 2, 0],
#        [3, 6, 8],
#        [4, 7, 5]]), 174: array([[1, 6, 0],
#        [3, 8, 2],
#        [4, 7, 5]]), 175: array([[1, 6, 2],
#        [3, 8, 5],
#        [4, 7, 0]]), 176: array([[1, 6, 2],
#        [3, 7, 8],
#        [4, 5, 0]]), 177: array([[0, 6, 2],
#        [1, 4, 3],
#        [7, 5, 8]]), 178: array([[1, 6, 2],
#        [7, 4, 3],
#        [0, 5, 8]]), 179: array([[0, 1, 2],
#        [4, 6, 3],
#        [7, 5, 8]]), 180: array([[1, 2, 0],
#        [4, 6, 3],
#        [7, 5, 8]]), 181: array([[1, 6, 2],
#        [4, 5, 3],
#        [0, 7, 8]]), 182: array([[0, 1, 6],
#        [4, 3, 2],
#        [7, 5, 8]]), 183: array([[1, 3, 6],
#        [4, 0, 2],
#        [7, 5, 8]]), 184: array([[6, 4, 2],
#        [7, 1, 8],
#        [3, 0, 5]]), 185: array([[4, 2, 8],
#        [0, 6, 1],
#        [7, 3, 5]]), 186: array([[4, 0, 8],
#        [6, 2, 1],
#        [7, 3, 5]]), 187: array([[4, 2, 8],
#        [6, 3, 1],
#        [7, 0, 5]]), 188: array([[4, 2, 8],
#        [6, 1, 5],
#        [7, 0, 3]]), 189: array([[6, 4, 1],
#        [0, 8, 2],
#        [7, 3, 5]]), 190: array([[4, 8, 1],
#        [0, 6, 2],
#        [7, 3, 5]]), 191: array([[4, 8, 1],
#        [6, 2, 0],
#        [7, 3, 5]]), 192: array([[4, 8, 1],
#        [6, 3, 2],
#        [7, 0, 5]]), 193: array([[4, 1, 2],
#        [0, 8, 5],
#        [6, 7, 3]]), 194: array([[4, 1, 2],
#        [0, 6, 5],
#        [7, 8, 3]]), 195: array([[4, 0, 2],
#        [6, 1, 5],
#        [7, 8, 3]]), 196: array([[4, 1, 2],
#        [6, 5, 0],
#        [7, 8, 3]]), 197: array([[1, 0, 2],
#        [4, 3, 8],
#        [6, 7, 5]]), 198: array([[4, 0, 2],
#        [3, 1, 8],
#        [6, 7, 5]]), 199: array([[4, 1, 2],
#        [3, 8, 0],
#        [6, 7, 5]]), 200: array([[4, 1, 2],
#        [3, 7, 8],
#        [6, 0, 5]]), 201: array([[4, 1, 2],
#        [0, 6, 3],
#        [7, 5, 8]]), 202: array([[4, 0, 2],
#        [6, 1, 3],
#        [7, 5, 8]]), 203: array([[4, 1, 2],
#        [6, 5, 3],
#        [7, 0, 8]]), 204: array([[4, 0, 1],
#        [6, 3, 2],
#        [7, 5, 8]]), 205: array([[1, 0, 2],
#        [4, 7, 8],
#        [3, 6, 5]]), 206: array([[7, 4, 2],
#        [0, 1, 8],
#        [3, 6, 5]]), 207: array([[4, 2, 8],
#        [7, 1, 0],
#        [3, 6, 5]]), 208: array([[4, 0, 1],
#        [7, 8, 2],
#        [3, 6, 5]]), 209: array([[4, 1, 2],
#        [7, 8, 5],
#        [3, 0, 6]]), 210: array([[4, 1, 2],
#        [0, 7, 6],
#        [3, 5, 8]]), 211: array([[4, 0, 2],
#        [7, 1, 6],
#        [3, 5, 8]]), 212: array([[4, 1, 2],
#        [7, 5, 6],
#        [3, 0, 8]]), 213: array([[4, 0, 1],
#        [7, 6, 2],
#        [3, 5, 8]]), 214: array([[2, 8, 6],
#        [1, 4, 0],
#        [7, 3, 5]]), 215: array([[2, 4, 8],
#        [0, 1, 6],
#        [7, 3, 5]]), 216: array([[2, 4, 8],
#        [1, 6, 0],
#        [7, 3, 5]]), 217: array([[2, 4, 8],
#        [1, 3, 6],
#        [7, 0, 5]]), 218: array([[1, 2, 8],
#        [0, 7, 6],
#        [3, 4, 5]]), 219: array([[1, 0, 8],
#        [7, 2, 6],
#        [3, 4, 5]]), 220: array([[1, 2, 8],
#        [7, 6, 0],
#        [3, 4, 5]]), 221: array([[1, 2, 8],
#        [7, 4, 0],
#        [3, 5, 6]]), 222: array([[4, 0, 8],
#        [2, 1, 6],
#        [7, 3, 5]]), 223: array([[4, 1, 8],
#        [2, 6, 0],
#        [7, 3, 5]]), 224: array([[4, 1, 8],
#        [2, 3, 6],
#        [7, 0, 5]]), 225: array([[4, 1, 8],
#        [7, 2, 6],
#        [3, 0, 5]]), 226: array([[1, 8, 6],
#        [4, 2, 5],
#        [7, 0, 3]]), 227: array([[2, 0, 8],
#        [1, 3, 6],
#        [4, 7, 5]]), 228: array([[1, 0, 8],
#        [3, 2, 6],
#        [4, 7, 5]]), 229: array([[1, 2, 8],
#        [3, 6, 0],
#        [4, 7, 5]]), 230: array([[1, 2, 8],
#        [3, 7, 6],
#        [4, 0, 5]]), 231: array([[1, 2, 8],
#        [0, 4, 3],
#        [7, 5, 6]]), 232: array([[1, 0, 8],
#        [4, 2, 3],
#        [7, 5, 6]]), 233: array([[1, 2, 8],
#        [4, 5, 3],
#        [7, 0, 6]]), 234: array([[1, 0, 2],
#        [4, 3, 8],
#        [7, 5, 6]]), 235: array([[2, 0, 8],
#        [1, 6, 5],
#        [4, 7, 3]]), 236: array([[1, 0, 8],
#        [6, 2, 5],
#        [4, 7, 3]]), 237: array([[1, 2, 8],
#        [6, 5, 0],
#        [4, 7, 3]]), 238: array([[1, 2, 8],
#        [6, 7, 5],
#        [4, 0, 3]]), 239: array([[2, 0, 8],
#        [1, 4, 5],
#        [7, 6, 3]]), 240: array([[1, 2, 8],
#        [7, 4, 5],
#        [6, 0, 3]]), 241: array([[4, 1, 8],
#        [0, 2, 5],
#        [7, 6, 3]]), 242: array([[1, 8, 5],
#        [4, 2, 0],
#        [7, 6, 3]]), 243: array([[1, 0, 2],
#        [4, 5, 8],
#        [7, 6, 3]]), 244: array([[6, 2, 8],
#        [0, 1, 4],
#        [7, 3, 5]]), 245: array([[6, 0, 8],
#        [1, 2, 4],
#        [7, 3, 5]]), 246: array([[6, 2, 8],
#        [1, 3, 4],
#        [7, 0, 5]]), 247: array([[6, 2, 8],
#        [1, 4, 5],
#        [7, 0, 3]]), 248: array([[6, 0, 4],
#        [1, 8, 2],
#        [7, 3, 5]]), 249: array([[6, 4, 2],
#        [1, 8, 5],
#        [7, 0, 3]]), 250: array([[6, 4, 2],
#        [0, 3, 8],
#        [1, 7, 5]]), 251: array([[6, 4, 2],
#        [1, 3, 0],
#        [7, 5, 8]]), 252: array([[6, 0, 2],
#        [1, 7, 8],
#        [3, 4, 5]]), 253: array([[7, 1, 2],
#        [0, 6, 8],
#        [3, 4, 5]]), 254: array([[1, 0, 6],
#        [7, 8, 2],
#        [3, 4, 5]]), 255: array([[1, 6, 2],
#        [7, 8, 5],
#        [3, 0, 4]]), 256: array([[1, 6, 2],
#        [0, 7, 4],
#        [3, 5, 8]]), 257: array([[1, 0, 2],
#        [7, 6, 4],
#        [3, 5, 8]]), 258: array([[1, 6, 2],
#        [7, 5, 4],
#        [3, 0, 8]]), 259: array([[1, 0, 6],
#        [7, 4, 2],
#        [3, 5, 8]]), 260: array([[4, 0, 6],
#        [8, 1, 2],
#        [7, 3, 5]]), 261: array([[4, 1, 6],
#        [8, 2, 0],
#        [7, 3, 5]]), 262: array([[4, 1, 6],
#        [8, 3, 2],
#        [7, 0, 5]]), 263: array([[4, 1, 6],
#        [7, 8, 2],
#        [3, 0, 5]]), 264: array([[8, 0, 6],
#        [1, 4, 2],
#        [7, 3, 5]]), 265: array([[1, 8, 6],
#        [7, 4, 2],
#        [3, 0, 5]]), 266: array([[1, 8, 6],
#        [0, 3, 2],
#        [4, 7, 5]]), 267: array([[1, 8, 6],
#        [4, 3, 0],
#        [7, 5, 2]]), 268: array([[6, 0, 2],
#        [1, 8, 5],
#        [4, 7, 3]]), 269: array([[1, 0, 2],
#        [8, 6, 5],
#        [4, 7, 3]]), 270: array([[1, 6, 2],
#        [8, 5, 0],
#        [4, 7, 3]]), 271: array([[1, 6, 2],
#        [8, 7, 5],
#        [4, 0, 3]]), 272: array([[6, 0, 2],
#        [1, 4, 5],
#        [7, 8, 3]]), 273: array([[1, 6, 2],
#        [7, 4, 5],
#        [8, 0, 3]]), 274: array([[1, 2, 5],
#        [4, 6, 0],
#        [7, 8, 3]]), 275: array([[1, 0, 6],
#        [4, 5, 2],
#        [7, 8, 3]]), 276: array([[6, 2, 8],
#        [1, 3, 0],
#        [4, 7, 5]]), 277: array([[6, 3, 2],
#        [0, 1, 8],
#        [4, 7, 5]]), 278: array([[6, 3, 2],
#        [1, 8, 0],
#        [4, 7, 5]]), 279: array([[6, 3, 2],
#        [1, 7, 8],
#        [4, 0, 5]]), 280: array([[3, 1, 2],
#        [0, 6, 8],
#        [4, 7, 5]]), 281: array([[1, 0, 6],
#        [3, 8, 2],
#        [4, 7, 5]]), 282: array([[1, 6, 2],
#        [3, 8, 5],
#        [4, 0, 7]]), 283: array([[1, 6, 2],
#        [3, 7, 0],
#        [4, 5, 8]]), 284: array([[6, 0, 2],
#        [1, 4, 3],
#        [7, 5, 8]]), 285: array([[1, 6, 2],
#        [7, 4, 3],
#        [5, 0, 8]]), 286: array([[1, 2, 3],
#        [4, 6, 0],
#        [7, 5, 8]]), 287: array([[1, 6, 2],
#        [0, 5, 3],
#        [4, 7, 8]]), 288: array([[4, 1, 6],
#        [0, 3, 2],
#        [7, 5, 8]]), 289: array([[1, 3, 6],
#        [0, 4, 2],
#        [7, 5, 8]]), 290: array([[1, 3, 6],
#        [4, 2, 0],
#        [7, 5, 8]]), 291: array([[1, 3, 6],
#        [4, 5, 2],
#        [7, 0, 8]]), 292: array([[6, 4, 2],
#        [7, 0, 8],
#        [3, 1, 5]]), 293: array([[6, 4, 2],
#        [7, 1, 8],
#        [3, 5, 0]]), 294: array([[0, 2, 8],
#        [4, 6, 1],
#        [7, 3, 5]]), 295: array([[4, 2, 8],
#        [7, 6, 1],
#        [0, 3, 5]]), 296: array([[0, 4, 8],
#        [6, 2, 1],
#        [7, 3, 5]]), 297: array([[4, 8, 0],
#        [6, 2, 1],
#        [7, 3, 5]]), 298: array([[4, 2, 8],
#        [6, 3, 1],
#        [0, 7, 5]]), 299: array([[4, 2, 8],
#        [6, 3, 1],
#        [7, 5, 0]]), 300: array([[4, 2, 8],
#        [6, 1, 5],
#        [0, 7, 3]]), 301: array([[4, 2, 8],
#        [6, 0, 5],
#        [7, 1, 3]]), 302: array([[6, 4, 1],
#        [8, 0, 2],
#        [7, 3, 5]]), 303: array([[6, 4, 1],
#        [7, 8, 2],
#        [0, 3, 5]]), 304: array([[0, 8, 1],
#        [4, 6, 2],
#        [7, 3, 5]]), 305: array([[4, 8, 1],
#        [7, 6, 2],
#        [0, 3, 5]]), 306: array([[4, 8, 1],
#        [6, 2, 5],
#        [7, 3, 0]]), 307: array([[4, 8, 1],
#        [6, 3, 2],
#        [0, 7, 5]]), 308: array([[4, 8, 1],
#        [6, 3, 2],
#        [7, 5, 0]]), 309: array([[0, 1, 2],
#        [4, 8, 5],
#        [6, 7, 3]]), 310: array([[4, 1, 2],
#        [8, 0, 5],
#        [6, 7, 3]]), 311: array([[4, 1, 2],
#        [7, 6, 5],
#        [0, 8, 3]]), 312: array([[0, 4, 2],
#        [6, 1, 5],
#        [7, 8, 3]]), 313: array([[4, 2, 0],
#        [6, 1, 5],
#        [7, 8, 3]]), 314: array([[4, 1, 0],
#        [6, 5, 2],
#        [7, 8, 3]]), 315: array([[4, 1, 2],
#        [6, 5, 3],
#        [7, 8, 0]]), 316: array([[1, 2, 0],
#        [4, 3, 8],
#        [6, 7, 5]]), 317: array([[1, 3, 2],
#        [4, 0, 8],
#        [6, 7, 5]]), 318: array([[0, 4, 2],
#        [3, 1, 8],
#        [6, 7, 5]]), 319: array([[4, 2, 0],
#        [3, 1, 8],
#        [6, 7, 5]]), 320: array([[4, 1, 0],
#        [3, 8, 2],
#        [6, 7, 5]]), 321: array([[4, 1, 2],
#        [3, 8, 5],
#        [6, 7, 0]]), 322: array([[4, 1, 2],
#        [3, 7, 8],
#        [6, 5, 0]]), 323: array([[4, 1, 2],
#        [7, 6, 3],
#        [0, 5, 8]]), 324: array([[0, 4, 2],
#        [6, 1, 3],
#        [7, 5, 8]]), 325: array([[4, 2, 0],
#        [6, 1, 3],
#        [7, 5, 8]]), 326: array([[4, 1, 2],
#        [6, 5, 3],
#        [0, 7, 8]]), 327: array([[0, 4, 1],
#        [6, 3, 2],
#        [7, 5, 8]]), 328: array([[4, 3, 1],
#        [6, 0, 2],
#        [7, 5, 8]]), 329: array([[1, 2, 0],
#        [4, 7, 8],
#        [3, 6, 5]]), 330: array([[1, 7, 2],
#        [4, 0, 8],
#        [3, 6, 5]]), 331: array([[7, 4, 2],
#        [1, 0, 8],
#        [3, 6, 5]]), 332: array([[7, 4, 2],
#        [3, 1, 8],
#        [0, 6, 5]]), 333: array([[4, 2, 8],
#        [7, 0, 1],
#        [3, 6, 5]]), 334: array([[4, 2, 8],
#        [7, 1, 5],
#        [3, 6, 0]]), 335: array([[0, 4, 1],
#        [7, 8, 2],
#        [3, 6, 5]]), 336: array([[4, 8, 1],
#        [7, 0, 2],
#        [3, 6, 5]]), 337: array([[4, 1, 2],
#        [7, 8, 5],
#        [0, 3, 6]]), 338: array([[4, 1, 2],
#        [7, 0, 5],
#        [3, 8, 6]]), 339: array([[0, 1, 2],
#        [4, 7, 6],
#        [3, 5, 8]]), 340: array([[4, 1, 2],
#        [3, 7, 6],
#        [0, 5, 8]]), 341: array([[0, 4, 2],
#        [7, 1, 6],
#        [3, 5, 8]]), 342: array([[4, 2, 0],
#        [7, 1, 6],
#        [3, 5, 8]]), 343: array([[4, 1, 2],
#        [7, 5, 6],
#        [0, 3, 8]]), 344: array([[4, 1, 2],
#        [7, 5, 6],
#        [3, 8, 0]]), 345: array([[0, 4, 1],
#        [7, 6, 2],
#        [3, 5, 8]]), 346: array([[4, 6, 1],
#        [7, 0, 2],
#        [3, 5, 8]]), 347: array([[2, 8, 6],
#        [1, 0, 4],
#        [7, 3, 5]]), 348: array([[2, 8, 6],
#        [1, 4, 5],
#        [7, 3, 0]]), 349: array([[0, 4, 8],
#        [2, 1, 6],
#        [7, 3, 5]]), 350: array([[2, 4, 8],
#        [7, 1, 6],
#        [0, 3, 5]]), 351: array([[2, 4, 0],
#        [1, 6, 8],
#        [7, 3, 5]]), 352: array([[2, 4, 8],
#        [1, 6, 5],
#        [7, 3, 0]]), 353: array([[2, 4, 8],
#        [1, 3, 6],
#        [0, 7, 5]]), 354: array([[2, 4, 8],
#        [1, 3, 6],
#        [7, 5, 0]]), 355: array([[0, 2, 8],
#        [1, 7, 6],
#        [3, 4, 5]]), 356: array([[1, 2, 8],
#        [3, 7, 6],
#        [0, 4, 5]]), 357: array([[0, 1, 8],
#        [7, 2, 6],
#        [3, 4, 5]]), 358: array([[1, 8, 0],
#        [7, 2, 6],
#        [3, 4, 5]]), 359: array([[1, 2, 8],
#        [7, 6, 5],
#        [3, 4, 0]]), 360: array([[1, 2, 8],
#        [7, 0, 4],
#        [3, 5, 6]]), 361: array([[1, 2, 0],
#        [7, 4, 8],
#        [3, 5, 6]]), 362: array([[4, 8, 0],
#        [2, 1, 6],
#        [7, 3, 5]]), 363: array([[4, 1, 0],
#        [2, 6, 8],
#        [7, 3, 5]]), 364: array([[4, 1, 8],
#        [2, 6, 5],
#        [7, 3, 0]]), 365: array([[4, 1, 8],
#        [2, 3, 6],
#        [0, 7, 5]]), 366: array([[4, 1, 8],
#        [2, 3, 6],
#        [7, 5, 0]]), 367: array([[4, 1, 8],
#        [7, 0, 6],
#        [3, 2, 5]]), 368: array([[4, 1, 8],
#        [7, 2, 6],
#        [3, 5, 0]]), 369: array([[1, 8, 6],
#        [4, 2, 5],
#        [0, 7, 3]]), 370: array([[1, 8, 6],
#        [4, 0, 5],
#        [7, 2, 3]]), 371: array([[2, 8, 0],
#        [1, 3, 6],
#        [4, 7, 5]]), 372: array([[2, 3, 8],
#        [1, 0, 6],
#        [4, 7, 5]]), 373: array([[0, 1, 8],
#        [3, 2, 6],
#        [4, 7, 5]]), 374: array([[1, 8, 0],
#        [3, 2, 6],
#        [4, 7, 5]]), 375: array([[1, 2, 8],
#        [3, 6, 5],
#        [4, 7, 0]]), 376: array([[1, 2, 8],
#        [3, 7, 6],
#        [4, 5, 0]]), 377: array([[0, 2, 8],
#        [1, 4, 3],
#        [7, 5, 6]]), 378: array([[1, 2, 8],
#        [7, 4, 3],
#        [0, 5, 6]]), 379: array([[0, 1, 8],
#        [4, 2, 3],
#        [7, 5, 6]]), 380: array([[1, 8, 0],
#        [4, 2, 3],
#        [7, 5, 6]]), 381: array([[1, 2, 8],
#        [4, 5, 3],
#        [0, 7, 6]]), 382: array([[0, 1, 2],
#        [4, 3, 8],
#        [7, 5, 6]]), 383: array([[1, 3, 2],
#        [4, 0, 8],
#        [7, 5, 6]]), 384: array([[2, 8, 0],
#        [1, 6, 5],
#        [4, 7, 3]]), 385: array([[2, 6, 8],
#        [1, 0, 5],
#        [4, 7, 3]]), 386: array([[0, 1, 8],
#        [6, 2, 5],
#        [4, 7, 3]]), 387: array([[1, 8, 0],
#        [6, 2, 5],
#        [4, 7, 3]]), 388: array([[1, 2, 0],
#        [6, 5, 8],
#        [4, 7, 3]]), 389: array([[1, 2, 8],
#        [6, 5, 3],
#        [4, 7, 0]]), 390: array([[1, 2, 8],
#        [6, 7, 5],
#        [0, 4, 3]]), 391: array([[1, 2, 8],
#        [6, 7, 5],
#        [4, 3, 0]]), 392: array([[2, 8, 0],
#        [1, 4, 5],
#        [7, 6, 3]]), 393: array([[2, 4, 8],
#        [1, 0, 5],
#        [7, 6, 3]]), 394: array([[1, 2, 8],
#        [7, 0, 5],
#        [6, 4, 3]]), 395: array([[1, 2, 8],
#        [7, 4, 5],
#        [6, 3, 0]]), 396: array([[4, 1, 8],
#        [2, 0, 5],
#        [7, 6, 3]]), 397: array([[4, 1, 8],
#        [7, 2, 5],
#        [0, 6, 3]]), 398: array([[1, 8, 5],
#        [4, 0, 2],
#        [7, 6, 3]]), 399: array([[1, 8, 5],
#        [4, 2, 3],
#        [7, 6, 0]]), 400: array([[0, 1, 2],
#        [4, 5, 8],
#        [7, 6, 3]]), 401: array([[1, 5, 2],
#        [4, 0, 8],
#        [7, 6, 3]]), 402: array([[0, 2, 8],
#        [6, 1, 4],
#        [7, 3, 5]]), 403: array([[6, 2, 8],
#        [7, 1, 4],
#        [0, 3, 5]]), 404: array([[0, 6, 8],
#        [1, 2, 4],
#        [7, 3, 5]]), 405: array([[6, 8, 0],
#        [1, 2, 4],
#        [7, 3, 5]]), 406: array([[6, 2, 8],
#        [1, 3, 4],
#        [0, 7, 5]]), 407: array([[6, 2, 8],
#        [1, 3, 4],
#        [7, 5, 0]]), 408: array([[6, 2, 8],
#        [1, 4, 5],
#        [0, 7, 3]]), 409: array([[6, 2, 8],
#        [1, 0, 5],
#        [7, 4, 3]]), 410: array([[0, 6, 4],
#        [1, 8, 2],
#        [7, 3, 5]]), 411: array([[6, 8, 4],
#        [1, 0, 2],
#        [7, 3, 5]]), 412: array([[6, 4, 2],
#        [1, 8, 5],
#        [0, 7, 3]]), 413: array([[6, 4, 2],
#        [1, 0, 5],
#        [7, 8, 3]]), 414: array([[0, 4, 2],
#        [6, 3, 8],
#        [1, 7, 5]]), 415: array([[6, 4, 2],
#        [3, 0, 8],
#        [1, 7, 5]]), 416: array([[6, 4, 2],
#        [1, 0, 3],
#        [7, 5, 8]]), 417: array([[6, 4, 0],
#        [1, 3, 2],
#        [7, 5, 8]]), 418: array([[6, 2, 0],
#        [1, 7, 8],
#        [3, 4, 5]]), 419: array([[6, 7, 2],
#        [1, 0, 8],
#        [3, 4, 5]]), 420: array([[7, 1, 2],
#        [6, 0, 8],
#        [3, 4, 5]]), 421: array([[7, 1, 2],
#        [3, 6, 8],
#        [0, 4, 5]]), 422: array([[0, 1, 6],
#        [7, 8, 2],
#        [3, 4, 5]]), 423: array([[1, 8, 6],
#        [7, 0, 2],
#        [3, 4, 5]]), 424: array([[1, 6, 2],
#        [7, 8, 5],
#        [0, 3, 4]]), 425: array([[1, 6, 2],
#        [7, 0, 5],
#        [3, 8, 4]]), 426: array([[0, 6, 2],
#        [1, 7, 4],
#        [3, 5, 8]]), 427: array([[1, 6, 2],
#        [3, 7, 4],
#        [0, 5, 8]]), 428: array([[0, 1, 2],
#        [7, 6, 4],
#        [3, 5, 8]]), 429: array([[1, 2, 0],
#        [7, 6, 4],
#        [3, 5, 8]]), 430: array([[1, 6, 2],
#        [7, 5, 4],
#        [0, 3, 8]]), 431: array([[1, 6, 2],
#        [7, 5, 4],
#        [3, 8, 0]]), 432: array([[0, 1, 6],
#        [7, 4, 2],
#        [3, 5, 8]]), 433: array([[1, 4, 6],
#        [7, 0, 2],
#        [3, 5, 8]]), 434: array([[0, 4, 6],
#        [8, 1, 2],
#        [7, 3, 5]]), 435: array([[4, 6, 0],
#        [8, 1, 2],
#        [7, 3, 5]]), 436: array([[4, 1, 0],
#        [8, 2, 6],
#        [7, 3, 5]]), 437: array([[4, 1, 6],
#        [8, 2, 5],
#        [7, 3, 0]]), 438: array([[4, 1, 6],
#        [8, 3, 2],
#        [0, 7, 5]]), 439: array([[4, 1, 6],
#        [8, 3, 2],
#        [7, 5, 0]]), 440: array([[4, 1, 6],
#        [7, 0, 2],
#        [3, 8, 5]]), 441: array([[4, 1, 6],
#        [7, 8, 2],
#        [3, 5, 0]]), 442: array([[8, 6, 0],
#        [1, 4, 2],
#        [7, 3, 5]]), 443: array([[8, 4, 6],
#        [1, 0, 2],
#        [7, 3, 5]]), 444: array([[1, 8, 6],
#        [7, 4, 2],
#        [3, 5, 0]]), 445: array([[0, 8, 6],
#        [1, 3, 2],
#        [4, 7, 5]]), 446: array([[1, 8, 6],
#        [3, 0, 2],
#        [4, 7, 5]]), 447: array([[1, 8, 6],
#        [4, 0, 3],
#        [7, 5, 2]]), 448: array([[1, 8, 0],
#        [4, 3, 6],
#        [7, 5, 2]]), 449: array([[6, 2, 0],
#        [1, 8, 5],
#        [4, 7, 3]]), 450: array([[6, 8, 2],
#        [1, 0, 5],
#        [4, 7, 3]]), 451: array([[0, 1, 2],
#        [8, 6, 5],
#        [4, 7, 3]]), 452: array([[1, 2, 0],
#        [8, 6, 5],
#        [4, 7, 3]]), 453: array([[1, 6, 0],
#        [8, 5, 2],
#        [4, 7, 3]]), 454: array([[1, 6, 2],
#        [8, 5, 3],
#        [4, 7, 0]]), 455: array([[1, 6, 2],
#        [8, 7, 5],
#        [0, 4, 3]]), 456: array([[1, 6, 2],
#        [8, 7, 5],
#        [4, 3, 0]]), 457: array([[6, 2, 0],
#        [1, 4, 5],
#        [7, 8, 3]]), 458: array([[1, 6, 2],
#        [7, 0, 5],
#        [8, 4, 3]]), 459: array([[1, 6, 2],
#        [7, 4, 5],
#        [8, 3, 0]]), 460: array([[1, 2, 5],
#        [4, 0, 6],
#        [7, 8, 3]]), 461: array([[1, 2, 5],
#        [4, 6, 3],
#        [7, 8, 0]]), 462: array([[0, 1, 6],
#        [4, 5, 2],
#        [7, 8, 3]]), 463: array([[1, 5, 6],
#        [4, 0, 2],
#        [7, 8, 3]]), 464: array([[6, 2, 8],
#        [1, 0, 3],
#        [4, 7, 5]]), 465: array([[6, 2, 8],
#        [1, 3, 5],
#        [4, 7, 0]]), 466: array([[0, 3, 2],
#        [6, 1, 8],
#        [4, 7, 5]]), 467: array([[6, 3, 2],
#        [4, 1, 8],
#        [0, 7, 5]]), 468: array([[6, 3, 0],
#        [1, 8, 2],
#        [4, 7, 5]]), 469: array([[6, 3, 2],
#        [1, 8, 5],
#        [4, 7, 0]]), 470: array([[6, 3, 2],
#        [1, 7, 8],
#        [0, 4, 5]]), 471: array([[6, 3, 2],
#        [1, 7, 8],
#        [4, 5, 0]]), 472: array([[3, 1, 2],
#        [6, 0, 8],
#        [4, 7, 5]]), 473: array([[3, 1, 2],
#        [4, 6, 8],
#        [0, 7, 5]]), 474: array([[0, 1, 6],
#        [3, 8, 2],
#        [4, 7, 5]]), 475: array([[1, 6, 2],
#        [3, 8, 5],
#        [0, 4, 7]]), 476: array([[1, 6, 2],
#        [3, 0, 5],
#        [4, 8, 7]]), 477: array([[1, 6, 2],
#        [3, 0, 7],
#        [4, 5, 8]]), 478: array([[1, 6, 0],
#        [3, 7, 2],
#        [4, 5, 8]]), 479: array([[6, 2, 0],
#        [1, 4, 3],
#        [7, 5, 8]]), 480: array([[1, 6, 2],
#        [7, 0, 3],
#        [5, 4, 8]]), 481: array([[1, 6, 2],
#        [7, 4, 3],
#        [5, 8, 0]]), 482: array([[1, 2, 3],
#        [4, 0, 6],
#        [7, 5, 8]]), 483: array([[1, 2, 3],
#        [4, 6, 8],
#        [7, 5, 0]]), 484: array([[0, 6, 2],
#        [1, 5, 3],
#        [4, 7, 8]]), 485: array([[1, 6, 2],
#        [5, 0, 3],
#        [4, 7, 8]]), 486: array([[4, 1, 6],
#        [3, 0, 2],
#        [7, 5, 8]]), 487: array([[4, 1, 6],
#        [7, 3, 2],
#        [0, 5, 8]]), 488: array([[0, 3, 6],
#        [1, 4, 2],
#        [7, 5, 8]]), 489: array([[1, 3, 6],
#        [7, 4, 2],
#        [0, 5, 8]]), 490: array([[1, 3, 0],
#        [4, 2, 6],
#        [7, 5, 8]]), 491: array([[1, 3, 6],
#        [4, 2, 8],
#        [7, 5, 0]]), 492: array([[1, 3, 6],
#        [4, 5, 2],
#        [0, 7, 8]]), 493: array([[1, 3, 6],
#        [4, 5, 2],
#        [7, 8, 0]]), 494: array([[6, 4, 2],
#        [0, 7, 8],
#        [3, 1, 5]]), 495: array([[6, 0, 2],
#        [7, 4, 8],
#        [3, 1, 5]]), 496: array([[6, 4, 2],
#        [7, 8, 0],
#        [3, 1, 5]]), 497: array([[6, 4, 2],
#        [7, 1, 0],
#        [3, 5, 8]]), 498: array([[2, 0, 8],
#        [4, 6, 1],
#        [7, 3, 5]]), 499: array([[4, 2, 8],
#        [7, 6, 1],
#        [3, 0, 5]]), 500: array([[6, 4, 8],
#        [0, 2, 1],
#        [7, 3, 5]]), 501: array([[4, 2, 8],
#        [0, 3, 1],
#        [6, 7, 5]]), 502: array([[4, 2, 8],
#        [6, 3, 0],
#        [7, 5, 1]]), 503: array([[4, 2, 8],
#        [0, 1, 5],
#        [6, 7, 3]]), 504: array([[4, 2, 8],
#        [0, 6, 5],
#        [7, 1, 3]]), 505: array([[4, 0, 8],
#        [6, 2, 5],
#        [7, 1, 3]]), 506: array([[4, 2, 8],
#        [6, 5, 0],
#        [7, 1, 3]]), 507: array([[6, 0, 1],
#        [8, 4, 2],
#        [7, 3, 5]]), 508: array([[6, 4, 1],
#        [8, 2, 0],
#        [7, 3, 5]]), 509: array([[6, 4, 1],
#        [8, 3, 2],
#        [7, 0, 5]]), 510: array([[6, 4, 1],
#        [7, 8, 2],
#        [3, 0, 5]]), 511: array([[8, 0, 1],
#        [4, 6, 2],
#        [7, 3, 5]]), 512: array([[4, 8, 1],
#        [7, 6, 2],
#        [3, 0, 5]]), 513: array([[4, 8, 1],
#        [6, 2, 5],
#        [7, 0, 3]]), 514: array([[4, 8, 1],
#        [0, 3, 2],
#        [6, 7, 5]]), 515: array([[4, 8, 1],
#        [6, 3, 0],
#        [7, 5, 2]]), 516: array([[1, 0, 2],
#        [4, 8, 5],
#        [6, 7, 3]]), 517: array([[4, 0, 2],
#        [8, 1, 5],
#        [6, 7, 3]]), 518: array([[4, 1, 2],
#        [8, 5, 0],
#        [6, 7, 3]]), 519: array([[4, 1, 2],
#        [8, 7, 5],
#        [6, 0, 3]]), 520: array([[4, 1, 2],
#        [7, 6, 5],
#        [8, 0, 3]]), 521: array([[6, 4, 2],
#        [0, 1, 5],
#        [7, 8, 3]]), 522: array([[4, 2, 5],
#        [6, 1, 0],
#        [7, 8, 3]]), 523: array([[4, 0, 1],
#        [6, 5, 2],
#        [7, 8, 3]]), 524: array([[1, 2, 8],
#        [4, 3, 0],
#        [6, 7, 5]]), 525: array([[1, 3, 2],
#        [0, 4, 8],
#        [6, 7, 5]]), 526: array([[1, 3, 2],
#        [4, 8, 0],
#        [6, 7, 5]]), 527: array([[1, 3, 2],
#        [4, 7, 8],
#        [6, 0, 5]]), 528: array([[3, 4, 2],
#        [0, 1, 8],
#        [6, 7, 5]]), 529: array([[4, 2, 8],
#        [3, 1, 0],
#        [6, 7, 5]]), 530: array([[4, 0, 1],
#        [3, 8, 2],
#        [6, 7, 5]]), 531: array([[4, 1, 2],
#        [3, 8, 5],
#        [6, 0, 7]]), 532: array([[4, 1, 2],
#        [3, 7, 0],
#        [6, 5, 8]]), 533: array([[4, 1, 2],
#        [7, 6, 3],
#        [5, 0, 8]]), 534: array([[6, 4, 2],
#        [0, 1, 3],
#        [7, 5, 8]]), 535: array([[4, 2, 3],
#        [6, 1, 0],
#        [7, 5, 8]]), 536: array([[4, 1, 2],
#        [0, 5, 3],
#        [6, 7, 8]]), 537: array([[6, 4, 1],
#        [0, 3, 2],
#        [7, 5, 8]]), 538: array([[4, 3, 1],
#        [0, 6, 2],
#        [7, 5, 8]]), 539: array([[4, 3, 1],
#        [6, 2, 0],
#        [7, 5, 8]]), 540: array([[4, 3, 1],
#        [6, 5, 2],
#        [7, 0, 8]]), 541: array([[1, 2, 8],
#        [4, 7, 0],
#        [3, 6, 5]]), 542: array([[1, 7, 2],
#        [0, 4, 8],
#        [3, 6, 5]]), 543: array([[1, 7, 2],
#        [4, 8, 0],
#        [3, 6, 5]]), 544: array([[1, 7, 2],
#        [4, 6, 8],
#        [3, 0, 5]]), 545: array([[7, 0, 2],
#        [1, 4, 8],
#        [3, 6, 5]]), 546: array([[7, 4, 2],
#        [1, 8, 0],
#        [3, 6, 5]]), 547: array([[7, 4, 2],
#        [1, 6, 8],
#        [3, 0, 5]]), 548: array([[7, 4, 2],
#        [3, 1, 8],
#        [6, 0, 5]]), 549: array([[4, 2, 8],
#        [0, 7, 1],
#        [3, 6, 5]]), 550: array([[4, 0, 8],
#        [7, 2, 1],
#        [3, 6, 5]]), 551: array([[4, 2, 8],
#        [7, 1, 5],
#        [3, 0, 6]]), 552: array([[7, 4, 1],
#        [0, 8, 2],
#        [3, 6, 5]]), 553: array([[4, 8, 1],
#        [0, 7, 2],
#        [3, 6, 5]]), 554: array([[4, 8, 1],
#        [7, 2, 0],
#        [3, 6, 5]]), 555: array([[4, 1, 2],
#        [0, 8, 5],
#        [7, 3, 6]]), 556: array([[4, 1, 2],
#        [0, 7, 5],
#        [3, 8, 6]]), 557: array([[4, 0, 2],
#        [7, 1, 5],
#        [3, 8, 6]]), 558: array([[4, 1, 2],
#        [7, 5, 0],
#        [3, 8, 6]]), 559: array([[1, 0, 2],
#        [4, 7, 6],
#        [3, 5, 8]]), 560: array([[4, 1, 2],
#        [3, 7, 6],
#        [5, 0, 8]]), 561: array([[7, 4, 2],
#        [0, 1, 6],
#        [3, 5, 8]]), 562: array([[4, 2, 6],
#        [7, 1, 0],
#        [3, 5, 8]]), 563: array([[4, 1, 2],
#        [0, 5, 6],
#        [7, 3, 8]]), 564: array([[7, 4, 1],
#        [0, 6, 2],
#        [3, 5, 8]]), 565: array([[4, 6, 1],
#        [0, 7, 2],
#        [3, 5, 8]]), 566: array([[4, 6, 1],
#        [7, 2, 0],
#        [3, 5, 8]]), 567: array([[4, 6, 1],
#        [7, 5, 2],
#        [3, 0, 8]]), 568: array([[2, 8, 6],
#        [0, 1, 4],
#        [7, 3, 5]]), 569: array([[2, 0, 6],
#        [1, 8, 4],
#        [7, 3, 5]]), 570: array([[2, 8, 6],
#        [1, 3, 4],
#        [7, 0, 5]]), 571: array([[2, 8, 6],
#        [1, 4, 5],
#        [7, 0, 3]]), 572: array([[2, 4, 8],
#        [7, 1, 6],
#        [3, 0, 5]]), 573: array([[2, 0, 4],
#        [1, 6, 8],
#        [7, 3, 5]]), 574: array([[2, 4, 8],
#        [1, 6, 5],
#        [7, 0, 3]]), 575: array([[2, 4, 8],
#        [0, 3, 6],
#        [1, 7, 5]]), 576: array([[2, 4, 8],
#        [1, 3, 0],
#        [7, 5, 6]]), 577: array([[2, 0, 8],
#        [1, 7, 6],
#        [3, 4, 5]]), 578: array([[7, 1, 8],
#        [0, 2, 6],
#        [3, 4, 5]]), 579: array([[1, 8, 6],
#        [7, 2, 0],
#        [3, 4, 5]]), 580: array([[1, 2, 8],
#        [7, 6, 5],
#        [3, 0, 4]]), 581: array([[1, 2, 8],
#        [0, 7, 4],
#        [3, 5, 6]]), 582: array([[1, 0, 8],
#        [7, 2, 4],
#        [3, 5, 6]]), 583: array([[1, 2, 8],
#        [7, 5, 4],
#        [3, 0, 6]]), 584: array([[1, 0, 2],
#        [7, 4, 8],
#        [3, 5, 6]]), 585: array([[4, 8, 6],
#        [2, 1, 0],
#        [7, 3, 5]]), 586: array([[4, 0, 1],
#        [2, 6, 8],
#        [7, 3, 5]]), 587: array([[4, 1, 8],
#        [2, 6, 5],
#        [7, 0, 3]]), 588: array([[4, 1, 8],
#        [0, 3, 6],
#        [2, 7, 5]]), 589: array([[4, 1, 8],
#        [2, 3, 0],
#        [7, 5, 6]]), 590: array([[4, 1, 8],
#        [0, 7, 6],
#        [3, 2, 5]]), 591: array([[4, 0, 8],
#        [7, 1, 6],
#        [3, 2, 5]]), 592: array([[4, 1, 8],
#        [7, 6, 0],
#        [3, 2, 5]]), 593: array([[4, 1, 8],
#        [7, 2, 0],
#        [3, 5, 6]]), 594: array([[1, 8, 6],
#        [0, 2, 5],
#        [4, 7, 3]]), 595: array([[1, 8, 6],
#        [0, 4, 5],
#        [7, 2, 3]]), 596: array([[1, 0, 6],
#        [4, 8, 5],
#        [7, 2, 3]]), 597: array([[1, 8, 6],
#        [4, 5, 0],
#        [7, 2, 3]]), 598: array([[2, 8, 6],
#        [1, 3, 0],
#        [4, 7, 5]]), 599: array([[2, 3, 8],
#        [0, 1, 6],
#        [4, 7, 5]]), 600: array([[2, 3, 8],
#        [1, 6, 0],
#        [4, 7, 5]]), 601: array([[2, 3, 8],
#        [1, 7, 6],
#        [4, 0, 5]]), 602: array([[3, 1, 8],
#        [0, 2, 6],
#        [4, 7, 5]]), 603: array([[1, 8, 6],
#        [3, 2, 0],
#        [4, 7, 5]]), 604: array([[1, 2, 8],
#        [3, 6, 5],
#        [4, 0, 7]]), 605: array([[1, 2, 8],
#        [3, 7, 0],
#        [4, 5, 6]]), 606: array([[2, 0, 8],
#        [1, 4, 3],
#        [7, 5, 6]]), 607: array([[1, 2, 8],
#        [7, 4, 3],
#        [5, 0, 6]]), 608: array([[4, 1, 8],
#        [0, 2, 3],
#        [7, 5, 6]]), 609: array([[1, 8, 3],
#        [4, 2, 0],
#        [7, 5, 6]]), 610: array([[1, 2, 8],
#        [0, 5, 3],
#        [4, 7, 6]]), 611: array([[4, 1, 2],
#        [0, 3, 8],
#        [7, 5, 6]]), 612: array([[1, 3, 2],
#        [0, 4, 8],
#        [7, 5, 6]]), 613: array([[1, 3, 2],
#        [4, 8, 0],
#        [7, 5, 6]]), 614: array([[1, 3, 2],
#        [4, 5, 8],
#        [7, 0, 6]]), 615: array([[2, 8, 5],
#        [1, 6, 0],
#        [4, 7, 3]]), 616: array([[2, 6, 8],
#        [0, 1, 5],
#        [4, 7, 3]]), 617: array([[2, 6, 8],
#        [1, 5, 0],
#        [4, 7, 3]]), 618: array([[2, 6, 8],
#        [1, 7, 5],
#        [4, 0, 3]]), 619: array([[6, 1, 8],
#        [0, 2, 5],
#        [4, 7, 3]]), 620: array([[1, 8, 5],
#        [6, 2, 0],
#        [4, 7, 3]]), 621: array([[1, 0, 2],
#        [6, 5, 8],
#        [4, 7, 3]]), 622: array([[1, 2, 8],
#        [6, 5, 3],
#        [4, 0, 7]]), 623: array([[1, 2, 8],
#        [0, 7, 5],
#        [6, 4, 3]]), 624: array([[1, 2, 8],
#        [6, 7, 0],
#        [4, 3, 5]]), 625: array([[2, 8, 5],
#        [1, 4, 0],
#        [7, 6, 3]]), 626: array([[2, 4, 8],
#        [0, 1, 5],
#        [7, 6, 3]]), 627: array([[2, 4, 8],
#        [1, 5, 0],
#        [7, 6, 3]]), 628: array([[1, 0, 8],
#        [7, 2, 5],
#        [6, 4, 3]]), 629: array([[1, 2, 8],
#        [7, 5, 0],
#        [6, 4, 3]]), 630: array([[1, 2, 8],
#        [7, 4, 0],
#        [6, 3, 5]]), 631: array([[4, 0, 8],
#        [2, 1, 5],
#        [7, 6, 3]]), 632: array([[4, 1, 8],
#        [2, 5, 0],
#        [7, 6, 3]]), 633: array([[4, 1, 8],
#        [7, 2, 5],
#        [6, 0, 3]]), 634: array([[1, 8, 5],
#        [0, 4, 2],
#        [7, 6, 3]]), 635: array([[1, 0, 5],
#        [4, 8, 2],
#        [7, 6, 3]]), 636: array([[1, 8, 5],
#        [4, 6, 2],
#        [7, 0, 3]]), 637: array([[1, 8, 5],
#        [4, 2, 3],
#        [7, 0, 6]]), 638: array([[4, 1, 2],
#        [0, 5, 8],
#        [7, 6, 3]]), 639: array([[1, 5, 2],
#        [0, 4, 8],
#        [7, 6, 3]]), 640: array([[1, 5, 2],
#        [4, 8, 0],
#        [7, 6, 3]]), 641: array([[1, 5, 2],
#        [4, 6, 8],
#        [7, 0, 3]]), 642: array([[2, 0, 8],
#        [6, 1, 4],
#        [7, 3, 5]]), 643: array([[6, 2, 8],
#        [7, 1, 4],
#        [3, 0, 5]]), 644: array([[1, 6, 8],
#        [0, 2, 4],
#        [7, 3, 5]]), 645: array([[6, 8, 4],
#        [1, 2, 0],
#        [7, 3, 5]]), 646: array([[6, 2, 8],
#        [0, 3, 4],
#        [1, 7, 5]]), 647: array([[6, 2, 8],
#        [1, 3, 0],
#        [7, 5, 4]]), 648: array([[6, 2, 8],
#        [0, 4, 5],
#        [1, 7, 3]]), 649: array([[6, 2, 8],
#        [0, 1, 5],
#        [7, 4, 3]]), 650: array([[6, 0, 8],
#        [1, 2, 5],
#        [7, 4, 3]]), 651: array([[6, 2, 8],
#        [1, 5, 0],
#        [7, 4, 3]]), 652: array([[1, 6, 4],
#        [0, 8, 2],
#        [7, 3, 5]]), 653: array([[6, 8, 4],
#        [0, 1, 2],
#        [7, 3, 5]]), 654: array([[6, 8, 4],
#        [1, 3, 2],
#        [7, 0, 5]]), 655: array([[6, 4, 2],
#        [0, 8, 5],
#        [1, 7, 3]]), 656: array([[6, 4, 2],
#        [1, 5, 0],
#        [7, 8, 3]]), 657: array([[4, 0, 2],
#        [6, 3, 8],
#        [1, 7, 5]]), 658: array([[6, 0, 2],
#        [3, 4, 8],
#        [1, 7, 5]]), 659: array([[6, 4, 2],
#        [3, 8, 0],
#        [1, 7, 5]]), 660: array([[6, 4, 2],
#        [3, 7, 8],
#        [1, 0, 5]]), 661: array([[6, 4, 2],
#        [1, 5, 3],
#        [7, 0, 8]]), 662: array([[6, 0, 4],
#        [1, 3, 2],
#        [7, 5, 8]]), 663: array([[6, 2, 8],
#        [1, 7, 0],
#        [3, 4, 5]]), 664: array([[6, 7, 2],
#        [0, 1, 8],
#        [3, 4, 5]]), 665: array([[6, 7, 2],
#        [1, 8, 0],
#        [3, 4, 5]]), 666: array([[6, 7, 2],
#        [1, 4, 8],
#        [3, 0, 5]]), 667: array([[7, 0, 2],
#        [6, 1, 8],
#        [3, 4, 5]]), 668: array([[7, 1, 2],
#        [6, 8, 0],
#        [3, 4, 5]]), 669: array([[7, 1, 2],
#        [6, 4, 8],
#        [3, 0, 5]]), 670: array([[7, 1, 2],
#        [3, 6, 8],
#        [4, 0, 5]]), 671: array([[7, 1, 6],
#        [0, 8, 2],
#        [3, 4, 5]]), 672: array([[1, 8, 6],
#        [0, 7, 2],
#        [3, 4, 5]]), 673: array([[1, 6, 2],
#        [0, 8, 5],
#        [7, 3, 4]]), 674: array([[1, 6, 2],
#        [0, 7, 5],
#        [3, 8, 4]]), 675: array([[1, 0, 2],
#        [7, 6, 5],
#        [3, 8, 4]]), 676: array([[1, 6, 2],
#        [7, 5, 0],
#        [3, 8, 4]]), 677: array([[6, 0, 2],
#        [1, 7, 4],
#        [3, 5, 8]]), 678: array([[1, 6, 2],
#        [3, 7, 4],
#        [5, 0, 8]]), 679: array([[7, 1, 2],
#        [0, 6, 4],
#        [3, 5, 8]]), 680: array([[1, 2, 4],
#        [7, 6, 0],
#        [3, 5, 8]]), 681: array([[1, 6, 2],
#        [0, 5, 4],
#        [7, 3, 8]]), 682: array([[7, 1, 6],
#        [0, 4, 2],
#        [3, 5, 8]]), 683: array([[1, 4, 6],
#        [0, 7, 2],
#        [3, 5, 8]]), 684: array([[1, 4, 6],
#        [7, 2, 0],
#        [3, 5, 8]]), 685: array([[1, 4, 6],
#        [7, 5, 2],
#        [3, 0, 8]]), 686: array([[8, 4, 6],
#        [0, 1, 2],
#        [7, 3, 5]]), 687: array([[4, 6, 2],
#        [8, 1, 0],
#        [7, 3, 5]]), 688: array([[4, 0, 1],
#        [8, 2, 6],
#        [7, 3, 5]]), 689: array([[4, 1, 6],
#        [8, 2, 5],
#        [7, 0, 3]]), 690: array([[4, 1, 6],
#        [0, 3, 2],
#        [8, 7, 5]]), 691: array([[4, 1, 6],
#        [8, 3, 0],
#        [7, 5, 2]]), 692: array([[4, 1, 6],
#        [0, 7, 2],
#        [3, 8, 5]]), 693: array([[4, 0, 6],
#        [7, 1, 2],
#        [3, 8, 5]]), 694: array([[4, 1, 6],
#        [7, 2, 0],
#        [3, 8, 5]]), 695: array([[4, 1, 6],
#        [7, 8, 0],
#        [3, 5, 2]]), 696: array([[8, 6, 2],
#        [1, 4, 0],
#        [7, 3, 5]]), 697: array([[8, 4, 6],
#        [1, 2, 0],
#        [7, 3, 5]]), 698: array([[8, 4, 6],
#        [1, 3, 2],
#        [7, 0, 5]]), 699: array([[1, 8, 6],
#        [7, 4, 0],
#        [3, 5, 2]]), 700: array([[8, 0, 6],
#        [1, 3, 2],
#        [4, 7, 5]]), 701: array([[1, 8, 6],
#        [3, 7, 2],
#        [4, 0, 5]]), 702: array([[1, 8, 6],
#        [0, 4, 3],
#        [7, 5, 2]]), 703: array([[1, 0, 6],
#        [4, 8, 3],
#        [7, 5, 2]]), 704: array([[1, 8, 6],
#        [4, 5, 3],
#        [7, 0, 2]]), 705: array([[1, 0, 8],
#        [4, 3, 6],
#        [7, 5, 2]]), 706: array([[6, 2, 5],
#        [1, 8, 0],
#        [4, 7, 3]]), 707: array([[6, 8, 2],
#        [0, 1, 5],
#        [4, 7, 3]]), 708: array([[6, 8, 2],
#        [1, 5, 0],
#        [4, 7, 3]]), 709: array([[6, 8, 2],
#        [1, 7, 5],
#        [4, 0, 3]]), 710: array([[8, 1, 2],
#        [0, 6, 5],
#        [4, 7, 3]]), 711: array([[1, 2, 5],
#        [8, 6, 0],
#        [4, 7, 3]]), 712: array([[1, 0, 6],
#        [8, 5, 2],
#        [4, 7, 3]]), 713: array([[1, 6, 2],
#        [8, 5, 3],
#        [4, 0, 7]]), 714: array([[1, 6, 2],
#        [0, 7, 5],
#        [8, 4, 3]]), 715: array([[1, 6, 2],
#        [8, 7, 0],
#        [4, 3, 5]]), 716: array([[6, 2, 5],
#        [1, 4, 0],
#        [7, 8, 3]]), 717: array([[1, 0, 2],
#        [7, 6, 5],
#        [8, 4, 3]]), 718: array([[1, 6, 2],
#        [7, 5, 0],
#        [8, 4, 3]]), 719: array([[1, 6, 2],
#        [7, 4, 0],
#        [8, 3, 5]]), 720: array([[1, 2, 5],
#        [0, 4, 6],
#        [7, 8, 3]]), 721: array([[1, 0, 5],
#        [4, 2, 6],
#        [7, 8, 3]]), 722: array([[1, 2, 5],
#        [4, 8, 6],
#        [7, 0, 3]]), 723: array([[1, 2, 5],
#        [4, 6, 3],
#        [7, 0, 8]]), 724: array([[4, 1, 6],
#        [0, 5, 2],
#        [7, 8, 3]]), 725: array([[1, 5, 6],
#        [0, 4, 2],
#        [7, 8, 3]]), 726: array([[1, 5, 6],
#        [4, 2, 0],
#        [7, 8, 3]]), 727: array([[1, 5, 6],
#        [4, 8, 2],
#        [7, 0, 3]]), 728: array([[6, 2, 8],
#        [0, 1, 3],
#        [4, 7, 5]]), 729: array([[6, 0, 8],
#        [1, 2, 3],
#        [4, 7, 5]]), 730: array([[6, 2, 8],
#        [1, 7, 3],
#        [4, 0, 5]]), 731: array([[6, 2, 8],
#        [1, 3, 5],
#        [4, 0, 7]]), 732: array([[3, 0, 2],
#        [6, 1, 8],
#        [4, 7, 5]]), 733: array([[6, 3, 2],
#        [4, 1, 8],
#        [7, 0, 5]]), 734: array([[6, 0, 3],
#        [1, 8, 2],
#        [4, 7, 5]]), 735: array([[6, 3, 2],
#        [1, 8, 5],
#        [4, 0, 7]]), 736: array([[6, 3, 2],
#        [0, 7, 8],
#        [1, 4, 5]]), 737: array([[6, 3, 2],
#        [1, 7, 0],
#        [4, 5, 8]]), 738: array([[3, 1, 2],
#        [6, 8, 0],
#        [4, 7, 5]]), 739: array([[3, 1, 2],
#        [6, 7, 8],
#        [4, 0, 5]]), 740: array([[3, 1, 2],
#        [4, 6, 8],
#        [7, 0, 5]]), 741: array([[3, 1, 6],
#        [0, 8, 2],
#        [4, 7, 5]]), 742: array([[1, 6, 2],
#        [0, 8, 5],
#        [3, 4, 7]]), 743: array([[1, 6, 2],
#        [0, 3, 5],
#        [4, 8, 7]]), 744: array([[1, 0, 2],
#        [3, 6, 5],
#        [4, 8, 7]]), 745: array([[1, 6, 2],
#        [3, 5, 0],
#        [4, 8, 7]]), 746: array([[1, 6, 2],
#        [0, 3, 7],
#        [4, 5, 8]]), 747: array([[1, 0, 2],
#        [3, 6, 7],
#        [4, 5, 8]]), 748: array([[1, 6, 2],
#        [3, 5, 7],
#        [4, 0, 8]]), 749: array([[1, 0, 6],
#        [3, 7, 2],
#        [4, 5, 8]]), 750: array([[6, 2, 3],
#        [1, 4, 0],
#        [7, 5, 8]]), 751: array([[1, 6, 2],
#        [0, 7, 3],
#        [5, 4, 8]]), 752: array([[1, 0, 2],
#        [7, 6, 3],
#        [5, 4, 8]]), 753: array([[1, 6, 2],
#        [7, 3, 0],
#        [5, 4, 8]]), 754: array([[1, 6, 2],
#        [7, 4, 0],
#        [5, 8, 3]]), 755: array([[1, 2, 3],
#        [0, 4, 6],
#        [7, 5, 8]]), 756: array([[1, 0, 3],
#        [4, 2, 6],
#        [7, 5, 8]]), 757: array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 0, 8]]), 758: array([[1, 2, 3],
#        [4, 6, 8],
#        [7, 0, 5]]), 759: array([[6, 0, 2],
#        [1, 5, 3],
#        [4, 7, 8]]), 760: array([[1, 0, 2],
#        [5, 6, 3],
#        [4, 7, 8]]), 761: array([[1, 6, 2],
#        [5, 3, 0],
#        [4, 7, 8]]), 762: array([[1, 6, 2],
#        [5, 7, 3],
#        [4, 0, 8]]), 763: array([[4, 0, 6],
#        [3, 1, 2],
#        [7, 5, 8]]), 764: array([[4, 1, 6],
#        [3, 2, 0],
#        [7, 5, 8]]), 765: array([[4, 1, 6],
#        [3, 5, 2],
#        [7, 0, 8]]), 766: array([[4, 1, 6],
#        [7, 3, 2],
#        [5, 0, 8]]), 767: array([[3, 0, 6],
#        [1, 4, 2],
#        [7, 5, 8]]), 768: array([[1, 3, 6],
#        [7, 4, 2],
#        [5, 0, 8]]), 769: array([[1, 3, 6],
#        [4, 2, 8],
#        [7, 0, 5]]), 770: array([[1, 3, 6],
#        [0, 5, 2],
#        [4, 7, 8]]), 771: array([[1, 3, 6],
#        [4, 5, 0],
#        [7, 8, 2]]), 772: array([[0, 4, 2],
#        [6, 7, 8],
#        [3, 1, 5]]), 773: array([[6, 4, 2],
#        [3, 7, 8],
#        [0, 1, 5]]), 774: array([[0, 6, 2],
#        [7, 4, 8],
#        [3, 1, 5]]), 775: array([[6, 2, 0],
#        [7, 4, 8],
#        [3, 1, 5]]), 776: array([[6, 4, 0],
#        [7, 8, 2],
#        [3, 1, 5]]), 777: array([[6, 4, 2],
#        [7, 8, 5],
#        [3, 1, 0]]), 778: array([[6, 4, 2],
#        [7, 0, 1],
#        [3, 5, 8]]), 779: array([[6, 4, 0],
#        [7, 1, 2],
#        [3, 5, 8]]), 780: array([[2, 8, 0],
#        [4, 6, 1],
#        [7, 3, 5]]), 781: array([[2, 6, 8],
#        [4, 0, 1],
#        [7, 3, 5]]), 782: array([[4, 2, 8],
#        [7, 6, 1],
#        [3, 5, 0]]), 783: array([[6, 4, 8],
#        [2, 0, 1],
#        [7, 3, 5]]), 784: array([[6, 4, 8],
#        [7, 2, 1],
#        [0, 3, 5]]), 785: array([[0, 2, 8],
#        [4, 3, 1],
#        [6, 7, 5]]), 786: array([[4, 2, 8],
#        [3, 0, 1],
#        [6, 7, 5]]), 787: array([[4, 2, 8],
#        [6, 0, 3],
#        [7, 5, 1]]), 788: array([[4, 2, 0],
#        [6, 3, 8],
#        [7, 5, 1]]), 789: array([[0, 2, 8],
# ...
#        [6, 5, 8],
#        [4, 7, 3]]), 1012: array([[1, 5, 2],
#        [6, 0, 8],
#        [4, 7, 3]]), 1013: array([[1, 2, 8],
#        [6, 5, 3],
#        [0, 4, 7]]), 1014: array([[1, 2, 8],
#        [6, 0, 3],
#        [4, 5, 7]]), 1015: array([[0, 2, 8],
#        [1, 7, 5],
#        [6, 4, 3]]), 1016: array([[1, 2, 8],
#        [6, 0, 7],
#        [4, 3, 5]]), 1017: array([[1, 2, 0],
#        [6, 7, 8],
#        [4, 3, 5]]), 1018: array([[2, 8, 5],
#        [1, 0, 4],
#        [7, 6, 3]]), 1019: array([[2, 8, 5],
#        [1, 4, 3],
#        [7, 6, 0]]), 1020: array([[0, 4, 8],
#        [2, 1, 5],
#        [7, 6, 3]]), 1021: array([[2, 4, 8],
#        [7, 1, 5],
#        [0, 6, 3]]), 1022: array([[2, 4, 0],
#        [1, 5, 8],
#        [7, 6, 3]]), 1023: array([[2, 4, 8],
#        [1, 5, 3],
#        [7, 6, 0]]), 1024: array([[0, 1, 8],
#        [7, 2, 5],
#        [6, 4, 3]]), 1025: array([[1, 8, 0],
#        [7, 2, 5],
#        [6, 4, 3]]), 1026: array([[1, 2, 0],
#        [7, 5, 8],
#        [6, 4, 3]]), 1027: array([[1, 2, 8],
#        [7, 5, 3],
#        [6, 4, 0]]), 1028: array([[1, 2, 8],
#        [7, 0, 4],
#        [6, 3, 5]]), 1029: array([[1, 2, 0],
#        [7, 4, 8],
#        [6, 3, 5]]), 1030: array([[4, 8, 0],
#        [2, 1, 5],
#        [7, 6, 3]]), 1031: array([[4, 1, 0],
#        [2, 5, 8],
#        [7, 6, 3]]), 1032: array([[4, 1, 8],
#        [2, 5, 3],
#        [7, 6, 0]]), 1033: array([[4, 1, 8],
#        [7, 0, 5],
#        [6, 2, 3]]), 1034: array([[4, 1, 8],
#        [7, 2, 5],
#        [6, 3, 0]]), 1035: array([[0, 8, 5],
#        [1, 4, 2],
#        [7, 6, 3]]), 1036: array([[1, 8, 5],
#        [7, 4, 2],
#        [0, 6, 3]]), 1037: array([[0, 1, 5],
#        [4, 8, 2],
#        [7, 6, 3]]), 1038: array([[1, 5, 0],
#        [4, 8, 2],
#        [7, 6, 3]]), 1039: array([[1, 8, 5],
#        [4, 6, 2],
#        [0, 7, 3]]), 1040: array([[1, 8, 5],
#        [4, 6, 2],
#        [7, 3, 0]]), 1041: array([[1, 8, 5],
#        [4, 2, 3],
#        [0, 7, 6]]), 1042: array([[1, 8, 5],
#        [4, 0, 3],
#        [7, 2, 6]]), 1043: array([[4, 1, 2],
#        [5, 0, 8],
#        [7, 6, 3]]), 1044: array([[4, 1, 2],
#        [7, 5, 8],
#        [0, 6, 3]]), 1045: array([[0, 5, 2],
#        [1, 4, 8],
#        [7, 6, 3]]), 1046: array([[1, 5, 2],
#        [7, 4, 8],
#        [0, 6, 3]]), 1047: array([[1, 5, 2],
#        [4, 8, 3],
#        [7, 6, 0]]), 1048: array([[1, 5, 2],
#        [4, 6, 8],
#        [0, 7, 3]]), 1049: array([[1, 5, 2],
#        [4, 6, 8],
#        [7, 3, 0]]), 1050: array([[2, 8, 0],
#        [6, 1, 4],
#        [7, 3, 5]]), 1051: array([[2, 1, 8],
#        [6, 0, 4],
#        [7, 3, 5]]), 1052: array([[6, 2, 8],
#        [7, 0, 4],
#        [3, 1, 5]]), 1053: array([[6, 2, 8],
#        [7, 1, 4],
#        [3, 5, 0]]), 1054: array([[1, 6, 8],
#        [2, 0, 4],
#        [7, 3, 5]]), 1055: array([[1, 6, 8],
#        [7, 2, 4],
#        [0, 3, 5]]), 1056: array([[6, 8, 4],
#        [1, 2, 5],
#        [7, 3, 0]]), 1057: array([[0, 2, 8],
#        [6, 3, 4],
#        [1, 7, 5]]), 1058: array([[6, 2, 8],
#        [3, 0, 4],
#        [1, 7, 5]]), 1059: array([[6, 2, 8],
#        [1, 0, 3],
#        [7, 5, 4]]), 1060: array([[6, 2, 0],
#        [1, 3, 8],
#        [7, 5, 4]]), 1061: array([[0, 2, 8],
#        [6, 4, 5],
#        [1, 7, 3]]), 1062: array([[6, 2, 8],
#        [4, 0, 5],
#        [1, 7, 3]]), 1063: array([[0, 2, 8],
#        [6, 1, 5],
#        [7, 4, 3]]), 1064: array([[6, 2, 8],
#        [7, 1, 5],
#        [0, 4, 3]]), 1065: array([[0, 6, 8],
#        [1, 2, 5],
#        [7, 4, 3]]), 1066: array([[6, 8, 0],
#        [1, 2, 5],
#        [7, 4, 3]]), 1067: array([[6, 2, 0],
#        [1, 5, 8],
#        [7, 4, 3]]), 1068: array([[6, 2, 8],
#        [1, 5, 3],
#        [7, 4, 0]]), 1069: array([[1, 6, 4],
#        [8, 0, 2],
#        [7, 3, 5]]), 1070: array([[1, 6, 4],
#        [7, 8, 2],
#        [0, 3, 5]]), 1071: array([[0, 8, 4],
#        [6, 1, 2],
#        [7, 3, 5]]), 1072: array([[6, 8, 4],
#        [7, 1, 2],
#        [0, 3, 5]]), 1073: array([[6, 8, 4],
#        [1, 3, 2],
#        [0, 7, 5]]), 1074: array([[6, 8, 4],
#        [1, 3, 2],
#        [7, 5, 0]]), 1075: array([[0, 4, 2],
#        [6, 8, 5],
#        [1, 7, 3]]), 1076: array([[6, 4, 2],
#        [8, 0, 5],
#        [1, 7, 3]]), 1077: array([[6, 4, 0],
#        [1, 5, 2],
#        [7, 8, 3]]), 1078: array([[6, 4, 2],
#        [1, 5, 3],
#        [7, 8, 0]]), 1079: array([[4, 2, 0],
#        [6, 3, 8],
#        [1, 7, 5]]), 1080: array([[4, 3, 2],
#        [6, 0, 8],
#        [1, 7, 5]]), 1081: array([[0, 6, 2],
#        [3, 4, 8],
#        [1, 7, 5]]), 1082: array([[6, 2, 0],
#        [3, 4, 8],
#        [1, 7, 5]]), 1083: array([[6, 4, 0],
#        [3, 8, 2],
#        [1, 7, 5]]), 1084: array([[6, 4, 2],
#        [3, 8, 5],
#        [1, 7, 0]]), 1085: array([[6, 4, 2],
#        [3, 7, 8],
#        [1, 5, 0]]), 1086: array([[6, 4, 2],
#        [1, 5, 3],
#        [0, 7, 8]]), 1087: array([[0, 6, 4],
#        [1, 3, 2],
#        [7, 5, 8]]), 1088: array([[6, 3, 4],
#        [1, 0, 2],
#        [7, 5, 8]]), 1089: array([[6, 2, 8],
#        [1, 0, 7],
#        [3, 4, 5]]), 1090: array([[6, 2, 8],
#        [1, 7, 5],
#        [3, 4, 0]]), 1091: array([[0, 7, 2],
#        [6, 1, 8],
#        [3, 4, 5]]), 1092: array([[6, 7, 2],
#        [3, 1, 8],
#        [0, 4, 5]]), 1093: array([[6, 7, 0],
#        [1, 8, 2],
#        [3, 4, 5]]), 1094: array([[6, 7, 2],
#        [1, 8, 5],
#        [3, 4, 0]]), 1095: array([[6, 7, 2],
#        [1, 4, 8],
#        [0, 3, 5]]), 1096: array([[6, 7, 2],
#        [1, 4, 8],
#        [3, 5, 0]]), 1097: array([[7, 2, 0],
#        [6, 1, 8],
#        [3, 4, 5]]), 1098: array([[7, 1, 0],
#        [6, 8, 2],
#        [3, 4, 5]]), 1099: array([[7, 1, 2],
#        [6, 8, 5],
#        [3, 4, 0]]), 1100: array([[7, 1, 2],
#        [6, 4, 8],
#        [0, 3, 5]]), 1101: array([[7, 1, 2],
#        [6, 4, 8],
#        [3, 5, 0]]), 1102: array([[7, 1, 2],
#        [3, 0, 8],
#        [4, 6, 5]]), 1103: array([[7, 1, 2],
#        [3, 6, 8],
#        [4, 5, 0]]), 1104: array([[7, 1, 6],
#        [8, 0, 2],
#        [3, 4, 5]]), 1105: array([[7, 1, 6],
#        [3, 8, 2],
#        [0, 4, 5]]), 1106: array([[0, 8, 6],
#        [1, 7, 2],
#        [3, 4, 5]]), 1107: array([[1, 8, 6],
#        [3, 7, 2],
#        [0, 4, 5]]), 1108: array([[0, 6, 2],
#        [1, 8, 5],
#        [7, 3, 4]]), 1109: array([[1, 6, 2],
#        [8, 0, 5],
#        [7, 3, 4]]), 1110: array([[0, 6, 2],
#        [1, 7, 5],
#        [3, 8, 4]]), 1111: array([[1, 6, 2],
#        [3, 7, 5],
#        [0, 8, 4]]), 1112: array([[0, 1, 2],
#        [7, 6, 5],
#        [3, 8, 4]]), 1113: array([[1, 2, 0],
#        [7, 6, 5],
#        [3, 8, 4]]), 1114: array([[1, 6, 0],
#        [7, 5, 2],
#        [3, 8, 4]]), 1115: array([[6, 2, 0],
#        [1, 7, 4],
#        [3, 5, 8]]), 1116: array([[6, 7, 2],
#        [1, 0, 4],
#        [3, 5, 8]]), 1117: array([[1, 6, 2],
#        [3, 0, 4],
#        [5, 7, 8]]), 1118: array([[1, 6, 2],
#        [3, 7, 4],
#        [5, 8, 0]]), 1119: array([[7, 1, 2],
#        [6, 0, 4],
#        [3, 5, 8]]), 1120: array([[7, 1, 2],
#        [3, 6, 4],
#        [0, 5, 8]]), 1121: array([[1, 2, 4],
#        [7, 0, 6],
#        [3, 5, 8]]), 1122: array([[1, 2, 4],
#        [7, 6, 8],
#        [3, 5, 0]]), 1123: array([[0, 6, 2],
#        [1, 5, 4],
#        [7, 3, 8]]), 1124: array([[1, 6, 2],
#        [5, 0, 4],
#        [7, 3, 8]]), 1125: array([[7, 1, 6],
#        [4, 0, 2],
#        [3, 5, 8]]), 1126: array([[7, 1, 6],
#        [3, 4, 2],
#        [0, 5, 8]]), 1127: array([[0, 4, 6],
#        [1, 7, 2],
#        [3, 5, 8]]), 1128: array([[1, 4, 6],
#        [3, 7, 2],
#        [0, 5, 8]]), 1129: array([[1, 4, 0],
#        [7, 2, 6],
#        [3, 5, 8]]), 1130: array([[1, 4, 6],
#        [7, 2, 8],
#        [3, 5, 0]]), 1131: array([[1, 4, 6],
#        [7, 5, 2],
#        [0, 3, 8]]), 1132: array([[1, 4, 6],
#        [7, 5, 2],
#        [3, 8, 0]]), 1133: array([[8, 4, 6],
#        [7, 1, 2],
#        [0, 3, 5]]), 1134: array([[4, 6, 2],
#        [8, 0, 1],
#        [7, 3, 5]]), 1135: array([[4, 6, 2],
#        [8, 1, 5],
#        [7, 3, 0]]), 1136: array([[0, 4, 1],
#        [8, 2, 6],
#        [7, 3, 5]]), 1137: array([[4, 2, 1],
#        [8, 0, 6],
#        [7, 3, 5]]), 1138: array([[4, 1, 6],
#        [8, 2, 5],
#        [0, 7, 3]]), 1139: array([[4, 1, 6],
#        [8, 0, 5],
#        [7, 2, 3]]), 1140: array([[0, 1, 6],
#        [4, 3, 2],
#        [8, 7, 5]]), 1141: array([[4, 1, 6],
#        [3, 0, 2],
#        [8, 7, 5]]), 1142: array([[4, 1, 6],
#        [8, 0, 3],
#        [7, 5, 2]]), 1143: array([[4, 1, 0],
#        [8, 3, 6],
#        [7, 5, 2]]), 1144: array([[0, 1, 6],
#        [4, 7, 2],
#        [3, 8, 5]]), 1145: array([[4, 1, 6],
#        [3, 7, 2],
#        [0, 8, 5]]), 1146: array([[0, 4, 6],
#        [7, 1, 2],
#        [3, 8, 5]]), 1147: array([[4, 6, 0],
#        [7, 1, 2],
#        [3, 8, 5]]), 1148: array([[4, 1, 0],
#        [7, 2, 6],
#        [3, 8, 5]]), 1149: array([[4, 1, 6],
#        [7, 2, 5],
#        [3, 8, 0]]), 1150: array([[4, 1, 6],
#        [7, 0, 8],
#        [3, 5, 2]]), 1151: array([[4, 1, 0],
#        [7, 8, 6],
#        [3, 5, 2]]), 1152: array([[8, 6, 2],
#        [1, 0, 4],
#        [7, 3, 5]]), 1153: array([[8, 6, 2],
#        [1, 4, 5],
#        [7, 3, 0]]), 1154: array([[8, 4, 0],
#        [1, 2, 6],
#        [7, 3, 5]]), 1155: array([[8, 4, 6],
#        [1, 2, 5],
#        [7, 3, 0]]), 1156: array([[8, 4, 6],
#        [1, 3, 2],
#        [0, 7, 5]]), 1157: array([[8, 4, 6],
#        [1, 3, 2],
#        [7, 5, 0]]), 1158: array([[1, 8, 6],
#        [7, 0, 4],
#        [3, 5, 2]]), 1159: array([[1, 8, 0],
#        [7, 4, 6],
#        [3, 5, 2]]), 1160: array([[8, 6, 0],
#        [1, 3, 2],
#        [4, 7, 5]]), 1161: array([[8, 3, 6],
#        [1, 0, 2],
#        [4, 7, 5]]), 1162: array([[1, 8, 6],
#        [3, 7, 2],
#        [4, 5, 0]]), 1163: array([[0, 8, 6],
#        [1, 4, 3],
#        [7, 5, 2]]), 1164: array([[1, 8, 6],
#        [7, 4, 3],
#        [0, 5, 2]]), 1165: array([[0, 1, 6],
#        [4, 8, 3],
#        [7, 5, 2]]), 1166: array([[1, 6, 0],
#        [4, 8, 3],
#        [7, 5, 2]]), 1167: array([[1, 8, 6],
#        [4, 5, 3],
#        [0, 7, 2]]), 1168: array([[0, 1, 8],
#        [4, 3, 6],
#        [7, 5, 2]]), 1169: array([[1, 3, 8],
#        [4, 0, 6],
#        [7, 5, 2]]), 1170: array([[6, 2, 5],
#        [1, 0, 8],
#        [4, 7, 3]]), 1171: array([[6, 2, 5],
#        [1, 8, 3],
#        [4, 7, 0]]), 1172: array([[0, 8, 2],
#        [6, 1, 5],
#        [4, 7, 3]]), 1173: array([[6, 8, 2],
#        [4, 1, 5],
#        [0, 7, 3]]), 1174: array([[6, 8, 0],
#        [1, 5, 2],
#        [4, 7, 3]]), 1175: array([[6, 8, 2],
#        [1, 5, 3],
#        [4, 7, 0]]), 1176: array([[6, 8, 2],
#        [1, 7, 5],
#        [0, 4, 3]]), 1177: array([[6, 8, 2],
#        [1, 7, 5],
#        [4, 3, 0]]), 1178: array([[8, 1, 2],
#        [6, 0, 5],
#        [4, 7, 3]]), 1179: array([[8, 1, 2],
#        [4, 6, 5],
#        [0, 7, 3]]), 1180: array([[1, 2, 5],
#        [8, 0, 6],
#        [4, 7, 3]]), 1181: array([[1, 2, 5],
#        [8, 6, 3],
#        [4, 7, 0]]), 1182: array([[0, 1, 6],
#        [8, 5, 2],
#        [4, 7, 3]]), 1183: array([[1, 5, 6],
#        [8, 0, 2],
#        [4, 7, 3]]), 1184: array([[1, 6, 2],
#        [8, 5, 3],
#        [0, 4, 7]]), 1185: array([[1, 6, 2],
#        [8, 0, 3],
#        [4, 5, 7]]), 1186: array([[0, 6, 2],
#        [1, 7, 5],
#        [8, 4, 3]]), 1187: array([[1, 6, 2],
#        [8, 0, 7],
#        [4, 3, 5]]), 1188: array([[1, 6, 0],
#        [8, 7, 2],
#        [4, 3, 5]]), 1189: array([[6, 2, 5],
#        [1, 0, 4],
#        [7, 8, 3]]), 1190: array([[6, 2, 5],
#        [1, 4, 3],
#        [7, 8, 0]]), 1191: array([[0, 1, 2],
#        [7, 6, 5],
#        [8, 4, 3]]), 1192: array([[1, 2, 0],
#        [7, 6, 5],
#        [8, 4, 3]]), 1193: array([[1, 6, 0],
#        [7, 5, 2],
#        [8, 4, 3]]), 1194: array([[1, 6, 2],
#        [7, 5, 3],
#        [8, 4, 0]]), 1195: array([[1, 6, 2],
#        [7, 0, 4],
#        [8, 3, 5]]), 1196: array([[1, 6, 0],
#        [7, 4, 2],
#        [8, 3, 5]]), 1197: array([[0, 2, 5],
#        [1, 4, 6],
#        [7, 8, 3]]), 1198: array([[1, 2, 5],
#        [7, 4, 6],
#        [0, 8, 3]]), 1199: array([[0, 1, 5],
#        [4, 2, 6],
#        [7, 8, 3]]), 1200: array([[1, 5, 0],
#        [4, 2, 6],
#        [7, 8, 3]]), 1201: array([[1, 2, 5],
#        [4, 8, 6],
#        [0, 7, 3]]), 1202: array([[1, 2, 5],
#        [4, 8, 6],
#        [7, 3, 0]]), 1203: array([[1, 2, 5],
#        [4, 6, 3],
#        [0, 7, 8]]), 1204: array([[1, 2, 5],
#        [4, 0, 3],
#        [7, 6, 8]]), 1205: array([[4, 1, 6],
#        [5, 0, 2],
#        [7, 8, 3]]), 1206: array([[4, 1, 6],
#        [7, 5, 2],
#        [0, 8, 3]]), 1207: array([[0, 5, 6],
#        [1, 4, 2],
#        [7, 8, 3]]), 1208: array([[1, 5, 6],
#        [7, 4, 2],
#        [0, 8, 3]]), 1209: array([[1, 5, 6],
#        [4, 2, 3],
#        [7, 8, 0]]), 1210: array([[1, 5, 6],
#        [4, 8, 2],
#        [0, 7, 3]]), 1211: array([[1, 5, 6],
#        [4, 8, 2],
#        [7, 3, 0]]), 1212: array([[0, 2, 8],
#        [6, 1, 3],
#        [4, 7, 5]]), 1213: array([[6, 2, 8],
#        [4, 1, 3],
#        [0, 7, 5]]), 1214: array([[0, 6, 8],
#        [1, 2, 3],
#        [4, 7, 5]]), 1215: array([[6, 8, 0],
#        [1, 2, 3],
#        [4, 7, 5]]), 1216: array([[6, 2, 8],
#        [1, 7, 3],
#        [0, 4, 5]]), 1217: array([[6, 2, 8],
#        [1, 7, 3],
#        [4, 5, 0]]), 1218: array([[6, 2, 8],
#        [1, 3, 5],
#        [0, 4, 7]]), 1219: array([[6, 2, 8],
#        [1, 0, 5],
#        [4, 3, 7]]), 1220: array([[3, 2, 0],
#        [6, 1, 8],
#        [4, 7, 5]]), 1221: array([[6, 3, 2],
#        [4, 0, 8],
#        [7, 1, 5]]), 1222: array([[6, 3, 2],
#        [4, 1, 8],
#        [7, 5, 0]]), 1223: array([[0, 6, 3],
#        [1, 8, 2],
#        [4, 7, 5]]), 1224: array([[6, 8, 3],
#        [1, 0, 2],
#        [4, 7, 5]]), 1225: array([[6, 3, 2],
#        [1, 8, 5],
#        [0, 4, 7]]), 1226: array([[6, 3, 2],
#        [1, 0, 5],
#        [4, 8, 7]]), 1227: array([[0, 3, 2],
#        [6, 7, 8],
#        [1, 4, 5]]), 1228: array([[6, 3, 2],
#        [7, 0, 8],
#        [1, 4, 5]]), 1229: array([[6, 3, 2],
#        [1, 0, 7],
#        [4, 5, 8]]), 1230: array([[6, 3, 0],
#        [1, 7, 2],
#        [4, 5, 8]]), 1231: array([[3, 1, 0],
#        [6, 8, 2],
#        [4, 7, 5]]), 1232: array([[3, 1, 2],
#        [6, 8, 5],
#        [4, 7, 0]]), 1233: array([[3, 1, 2],
#        [6, 7, 8],
#        [0, 4, 5]]), 1234: array([[3, 1, 2],
#        [6, 7, 8],
#        [4, 5, 0]]), 1235: array([[3, 1, 2],
#        [4, 0, 8],
#        [7, 6, 5]]), 1236: array([[3, 1, 2],
#        [4, 6, 8],
#        [7, 5, 0]]), 1237: array([[3, 1, 6],
#        [8, 0, 2],
#        [4, 7, 5]]), 1238: array([[3, 1, 6],
#        [4, 8, 2],
#        [0, 7, 5]]), 1239: array([[0, 6, 2],
#        [1, 8, 5],
#        [3, 4, 7]]), 1240: array([[1, 6, 2],
#        [8, 0, 5],
#        [3, 4, 7]]), 1241: array([[0, 6, 2],
#        [1, 3, 5],
#        [4, 8, 7]]), 1242: array([[1, 6, 2],
#        [4, 3, 5],
#        [0, 8, 7]]), 1243: array([[0, 1, 2],
#        [3, 6, 5],
#        [4, 8, 7]]), 1244: array([[1, 2, 0],
#        [3, 6, 5],
#        [4, 8, 7]]), 1245: array([[1, 6, 0],
#        [3, 5, 2],
#        [4, 8, 7]]), 1246: array([[1, 6, 2],
#        [3, 5, 7],
#        [4, 8, 0]]), 1247: array([[0, 6, 2],
#        [1, 3, 7],
#        [4, 5, 8]]), 1248: array([[1, 6, 2],
#        [4, 3, 7],
#        [0, 5, 8]]), 1249: array([[0, 1, 2],
#        [3, 6, 7],
#        [4, 5, 8]]), 1250: array([[1, 2, 0],
#        [3, 6, 7],
#        [4, 5, 8]]), 1251: array([[1, 6, 2],
#        [3, 5, 7],
#        [0, 4, 8]]), 1252: array([[0, 1, 6],
#        [3, 7, 2],
#        [4, 5, 8]]), 1253: array([[1, 7, 6],
#        [3, 0, 2],
#        [4, 5, 8]]), 1254: array([[6, 2, 3],
#        [1, 0, 4],
#        [7, 5, 8]]), 1255: array([[6, 2, 3],
#        [1, 4, 8],
#        [7, 5, 0]]), 1256: array([[0, 6, 2],
#        [1, 7, 3],
#        [5, 4, 8]]), 1257: array([[1, 6, 2],
#        [5, 7, 3],
#        [0, 4, 8]]), 1258: array([[0, 1, 2],
#        [7, 6, 3],
#        [5, 4, 8]]), 1259: array([[1, 2, 0],
#        [7, 6, 3],
#        [5, 4, 8]]), 1260: array([[1, 6, 0],
#        [7, 3, 2],
#        [5, 4, 8]]), 1261: array([[1, 6, 2],
#        [7, 3, 8],
#        [5, 4, 0]]), 1262: array([[1, 6, 2],
#        [7, 0, 4],
#        [5, 8, 3]]), 1263: array([[1, 6, 0],
#        [7, 4, 2],
#        [5, 8, 3]]), 1264: array([[0, 2, 3],
#        [1, 4, 6],
#        [7, 5, 8]]), 1265: array([[1, 2, 3],
#        [7, 4, 6],
#        [0, 5, 8]]), 1266: array([[0, 1, 3],
#        [4, 2, 6],
#        [7, 5, 8]]), 1267: array([[1, 2, 3],
#        [4, 5, 6],
#        [0, 7, 8]]), 1268: array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 0]])}

# %%
goal_path = generate_path(ParentNodes)
# Out:
# Start_key =
# 1
#
# Goal_key =
# 1268
#
# goal_path =
# [1, 4, 9, 19, 33, 60, 101, 180, 286, 482, 757, 1268]

# %%
print_optimalpath(goal_path)
# Out:
# Optinal path from Start to Goal
# [[1 0 2]
#  [4 6 8]
#  [7 3 5]]
#
# [[1 6 2]
#  [4 0 8]
#  [7 3 5]]
#
# [[1 6 2]
#  [4 3 8]
#  [7 0 5]]
#
# [[1 6 2]
#  [4 3 8]
#  [7 5 0]]
#
# [[1 6 2]
#  [4 3 0]
#  [7 5 8]]
#
# [[1 6 2]
#  [4 0 3]
#  [7 5 8]]
#
# [[1 0 2]
#  [4 6 3]
#  [7 5 8]]
#
# [[1 2 0]
#  [4 6 3]
#  [7 5 8]]
#
# [[1 2 3]
#  [4 6 0]
#  [7 5 8]]
#
# [[1 2 3]
#  [4 0 6]
#  [7 5 8]]
#
# [[1 2 3]
#  [4 5 6]
#  [7 0 8]]
#
# [[1 2 3]
#  [4 5 6]
#  [7 8 0]]
